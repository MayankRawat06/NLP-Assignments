# %% [markdown]
# <a href="https://colab.research.google.com/github/MayankRawat06/NLP-Assignments/blob/main/NLP_in_Python_6_(Text_Generation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('/content/drive/MyDrive/NLP in Python/pickle/corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bill     [cheers and applause] All right, thank you! Th...         Bill Burr
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# dave     This is Dave. He tells dirty jokes for a livin...    Dave Chappelle
# hasan    [theme music: orchestral hip-hop] [crowd roars...      Hasan Minhaj
# jim      [Car horn honks] [Audience cheering] [Announce...     Jim Jefferies
# joe      [rock music playing] [audience cheering] [anno...         Joe Rogan
# john     All right, Petunia. Wish me luck out there. Yo...      John Mulaney
# louis    Intro\nFade the music out. Let’s roll. Hold th...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# ricky    Hello. Hello! How you doing? Great. Thank you....     Ricky Gervais

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'Ladies and gentlemen, please welcome to the stage: Ali Wong! Hi. Hello! Welcome! Thank you! Thank you for coming. Hello! Hello. We are gonna have to get this shit over with, ’cause I have to pee in, l'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'Ladies': ['and'],
#  'and': ['gentlemen,',
#   'foremost,',
#   'then',
#   'have',
#   'there’s',
#   'resentment',
#   'get',
#   'get',
#   'says,',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'she',
#   'I',
#   'I',
#   'I',
#   'we',
#   'watched',
#   'I',
#   'have',
#   'that',
#   'recycling,',
#   'disturbing',
#   'it’s',
#   'all',
#   'just…',
#   'be',
#   'half-Vietnamese.',
#   'his',
#   'slide.',
#   'your',
#   'inflamed',
#   'you’re',
#   'I',
#   'half-Japanese',
#   'I’m',
#   'half-Vietnamese.',
#   'playing',
#   'rugby.',
#   'foremost,',
#   'a',
#   'emotionally',
#   'I',
#   '20',
#   'neither',
#   'I',
#   'I–',
#   'then',
#   'it’s',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'very',
#   'for',
#   'I',
#   'she',
#   'rise',
#   'be',
#   'eat',
#   'watch',
#   'be',
#   'now',
#   'most',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say,',
#   'my',
#   'he',
#   'when',
#   'I’m',
#   'sicker,',
#   'sicker.',
#   'sicker,',
#   'sicker,',
#   'posted',
#   'that’s',
#   'lies.',
#   'as',
#   'treat',
#   'you’ll',
#   'succeed,',
#   'they',
#   'that’s',
#   'be',
#   'just',
#   'sisters.',
#   'a',
#   'unusual',
#   'they’ll',
#   'boring.”',
#   'wearing',
#   'famous',
#   'you’re',
#   'just',
#   'therefore,',
#   'ignore',
#   'the',
#   'Biggie',
#   'your',
#   'there',
#   'I',
#   'Push',
#   'then,',
#   'melt',
#   'I',
#   'then',
#   'sniff',
#   'I',
#   'you’ve',
#   'outside',
#   'as',
#   'rapey',
#   'most',
#   'see',
#   'I’d',
#   'I',
#   'he',
#   'instead',
#   'remember',
#   'hold',
#   'I',
#   'do',
#   'to',
#   'a',
#   'terrible.',
#   'I',
#   'when',
#   'I',
#   'held',
#   'got',
#   'I',
#   'your',
#   'he',
#   'I',
#   'leaves',
#   'dark.',
#   'naked,',
#   'a',
#   'my',
#   'then',
#   'recently',
#   'a'],
#  'gentlemen,': ['please'],
#  'please': ['welcome'],
#  'welcome': ['to'],
#  'to': ['the',
#   'get',
#   'pee',
#   'sleep,',
#   'sleep.',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'Deepak-Oprah,',
#   'achieve',
#   'trap',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women.',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work.',
#   'earn',
#   'shit',
#   'seat.',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'make',
#   'just',
#   'the',
#   'podcasts.',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'you.\nI',
#   'put',
#   'do',
#   'help',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do.',
#   'her,',
#   'use',
#   'say,',
#   'get',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me.',
#   'me',
#   'live',
#   'die.',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go.',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be.',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish,',
#   'finish.',
#   'come',
#   'make',
#   'be',
#   'be…',
#   'be',
#   'me,',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'Keyser',
#   'freak',
#   'freak',
#   'it.”',
#   'cleanse.',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me.',
#   'Harvard'],
#  'the': ['stage:',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'center',
#   'hoarding',
#   'HPV',
#   'country',
#   'third',
#   'Communists.\nThe',
#   'worst',
#   'calculator',
#   'future.',
#   'Tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside,',
#   'inside.',
#   'first',
#   'time,',
#   'fifth',
#   'back',
#   'park.”',
#   'middle',
#   'money',
#   'colonizer!”',
#   'time.',
#   'sexiest.',
#   'sexiest.',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference.',
#   'Chinese,',
#   'Japanese.',
#   'East',
#   'west',
#   'name,',
#   'bathroom.',
#   'bathroom',
#   'corner.',
#   'wait',
#   'wall…',
#   'fuck',
#   'house.',
#   'idea',
#   'man’s',
#   'message,',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'C.O.O.',
#   'table',
#   'top.',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret.”',
#   'phrase,',
#   'street.',
#   'Boat',
#   'best',
#   'desert.',
#   'stall.',
#   'end',
#   'day',
#   'Goonies.',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet.',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'Internet',
#   'back.',
#   'Internet',
#   'Jewish',
#   'universe',
#   'pain.”',
#   'pain.',
#   'pain.',
#   'dick.',
#   'butt,',
#   'tush-tush.',
#   'man',
#   'look',
#   'man’s',
#   'first',
#   'woman,',
#   'Lord',
#   'Rim,',
#   'most',
#   'most',
#   'woman',
#   'time,',
#   'boss.',
#   'boss',
#   'time,',
#   'bedroom,',
#   'boss.',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'baby’s',
#   'dream.”',
#   'point.',
#   'ultimate',
#   'world',
#   'rest',
#   'Galapagos,',
#   'phrase',
#   'women,',
#   'side',
#   'hood,',
#   'movie,',
#   'park,',
#   'sun.',
#   'sun',
#   'Tupac',
#   'time?',
#   'time,',
#   'peace',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood.',
#   'eggs',
#   'month,',
#   "Kraken!'”",
#   'time,',
#   'smiley',
#   'ovulation',
#   'time,',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'size',
#   'twins',
#   'toilet,',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table?”',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house.',
#   'dishes?”',
#   'plants?”',
#   'channel.”',
#   'star',
#   'show.',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same.',
#   'escrow',
#   'one',
#   'epicenter'],
#  'stage:': ['Ali'],
#  'Ali': ['Wong!', 'Wong.'],
#  'Wong!': ['Hi.'],
#  'Hi.': ['Hello!'],
#  'Hello!': ['Welcome!', 'Hello.'],
#  'Welcome!': ['Thank'],
#  'Thank': ['you!', 'you', 'you,', 'you.'],
#  'you!': ['Thank'],
#  'you': ['for',
#   'don’t',
#   'go',
#   'can',
#   'never',
#   'better',
#   'under',
#   'might',
#   'die.”',
#   'wanna',
#   'gotta',
#   'a',
#   'drop',
#   'know,',
#   'know,',
#   'feel',
#   'know.',
#   'know,',
#   'about',
#   'to',
#   'know,',
#   'right',
#   'get',
#   'like!',
#   'know?\nMy',
#   'know?',
#   'know,',
#   'can',
#   'eat',
#   'queef',
#   'know,',
#   'know',
#   'marry',
#   'something.',
#   'would',
#   'don’t',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry,',
#   'never',
#   'dare',
#   'know,',
#   'deep,',
#   'not',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know…',
#   'now.',
#   'gotta',
#   'don’t',
#   'put',
#   'know?',
#   'haven’t',
#   'know,',
#   'stick',
#   'know?',
#   'just',
#   'as',
#   'know?',
#   'OK?',
#   'all',
#   'respect',
#   'need',
#   'know?',
#   'what',
#   'be',
#   'so,',
#   'know?',
#   'know',
#   'guys',
#   'gonna',
#   'know?\nAnother',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know?',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'scratch',
#   'can',
#   'urgently',
#   'gotta',
#   'need',
#   'do',
#   'when',
#   'when',
#   'to',
#   'know?',
#   'that–',
#   'know',
#   'push,',
#   'push,',
#   'push,',
#   'think',
#   'wash',
#   'water',
#   'makin’',
#   'about',
#   'get',
#   'know?',
#   'know,',
#   'see',
#   'know?',
#   'know,',
#   'think'],
#  'for': ['coming.',
#   'coming.',
#   'me.',
#   'me.',
#   'me',
#   'my',
#   'fashion',
#   'warmth?',
#   'marriage,',
#   'them.',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us,',
#   'Fresh',
#   'me',
#   'them.',
#   'his',
#   'the',
#   'once.',
#   'the',
#   'all',
#   'the',
#   'me',
#   'me,',
#   'me',
#   'a',
#   'granted',
#   'a',
#   'a',
#   'me.',
#   'a',
#   '30',
#   'coming',
#   'the',
#   'playing',
#   'being'],
#  'coming.': ['Hello!', 'Um…', 'You'],
#  'Hello.': ['We'],
#  'We': ['are',
#   'were',
#   'were',
#   'had',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'do',
#   'eat',
#   'got',
#   'had',
#   'could',
#   'don’t',
#   'could',
#   'all',
#   'don’t'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'C.E.O.s,',
#   'never',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin’.',
#   'in'],
#  'gonna': ['have',
#   'turn',
#   'die…',
#   'overtake',
#   'have',
#   'trap',
#   'propose…',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live.',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear,',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be.',
#   'recycle…',
#   'burn',
#   'be.',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'HPV',
#   'it',
#   'HPV',
#   'HPV,',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to,',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex,',
#   'to',
#   'had',
#   'to',
#   'the'],
#  'get': ['this',
#   'it.',
#   'it.',
#   'rid',
#   'it,',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker,',
#   'sicker,',
#   'really,',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant.',
#   'pregnant,',
#   'up',
#   'into',
#   'older.',
#   'as',
#   'a',
#   'pregnant.',
#   'pregnant',
#   'that…',
#   'my',
#   'pregnant,',
#   'huge',
#   'dark',
#   'big–',
#   'big,',
#   'all',
#   'pregnant.'],
#  'this': ['shit',
#   'year.',
#   'doctor,',
#   'shit',
#   'shit',
#   'calculator',
#   'Judy',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'restaurant',
#   'restaurant',
#   'hippy-dippy',
#   'sneaking',
#   'wacky',
#   'dude,',
#   'dude,',
#   'huge',
#   'shit?',
#   'conversation.',
#   'is',
#   'fucking',
#   'relatable',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit.”',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   'and',
#   'around?',
#   'around?',
#   'up',
#   'is',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'was',
#   'together',
#   'together.”',
#   'turns',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore.',
#   'that'],
#  'over': ['with,', 'again.', 'again.', 'by', 'his'],
#  'with,': ['’cause'],
#  '’cause': ['I',
#   'it',
#   'it',
#   'my',
#   'you’re',
#   'when',
#   'her',
#   'it’s',
#   'you',
#   'I'],
#  'I': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'don’t',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am,',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'grew',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew,',
#   'was',
#   'dropped',
#   'was',
#   'don’t',
#   'get',
#   'mean,',
#   'just',
#   'could',
#   'think',
#   'was',
#   'don’t',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee,',
#   'need',
#   'grew',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted.',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'was.',
#   'did',
#   'don’t',
#   'don’t.',
#   'straight',
#   'don’t',
#   'do',
#   'don’t',
#   'don’t',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said,',
#   'really',
#   'don’t',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'don’t',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was,',
#   'got',
#   'just',
#   'don’t–',
#   'don’t!',
#   'don’t!',
#   'like',
#   'respect',
#   'know',
#   'don’t',
#   'also',
#   'just',
#   'can’t',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want?',
#   'wanna',
#   'have',
#   'don’t',
#   'am',
#   'dare',
#   'just',
#   'identify.”',
#   'don’t',
#   'was',
#   'won,',
#   'was',
#   'really',
#   'changed',
#   'get',
#   'need',
#   'don’t',
#   'need',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'also',
#   'know,',
#   'slime',
#   'don’t',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'don’t',
#   'had',
#   'can’t',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'don’t',
#   'was',
#   'lost.',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'can’t',
#   'can',
#   'am',
#   'didn’t',
#   'can',
#   'can’t',
#   'get',
#   'do',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didn’t',
#   'didn’t',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'don’t'],
#  'pee': ['in,', 'on'],
#  'in,': ['like,', 'OK?'],
#  'like,': ['ten',
#   '“You',
#   '“But…',
#   '“Oh,',
#   '“Oh,',
#   '“All',
#   'we',
#   '“Hey,',
#   '“Wassup?”',
#   '“Hey,',
#   '“Where?”',
#   '“At',
#   '“Oh,',
#   'you',
#   '“I',
#   '“Hold',
#   '“I',
#   '“It’s',
#   '“It’s',
#   'private',
#   '“Oh,',
#   '“I’m',
#   '“Shut',
#   '“Oh,',
#   'very',
#   '“We’re',
#   '“We',
#   '“But,',
#   '“Look',
#   '“That',
#   '“Oh,',
#   '“You',
#   '“Hey,',
#   '“Why',
#   '“Uh,',
#   '“Oh,',
#   '“Oh,',
#   '“Yes,',
#   'become',
#   'a',
#   '“Guys,',
#   '“That’s',
#   '“Ali,',
#   '“Yeah,',
#   '“Why',
#   '“Yeah,',
#   '“Yeah!',
#   '“Oh,',
#   '“I’m',
#   '“Oh,',
#   'only',
#   '“We’re',
#   '‘Release',
#   'we',
#   '“OK,',
#   '“Hey,',
#   '“Oh,',
#   '“Uh,',
#   '“No!”',
#   '“Yes!”',
#   '“You',
#   '“Yeah,',
#   'that',
#   'this',
#   'I',
#   'a',
#   'a',
#   'really',
#   '“Why',
#   'way'],
#  'ten': ['minutes.', 'gallons'],
#  'minutes.': ['But'],
#  'But': ['thank',
#   'my',
#   'I',
#   'he',
#   'sometimes,',
#   'don’t',
#   'I',
#   'he’s',
#   'mostly',
#   'I’m',
#   'it’s'],
#  'thank': ['you,'],
#  'you,': ['everybody,', 'five', 'but', 'right?”', 'I', '’cause', 'boom,'],
#  'everybody,': ['so'],
#  'so': ['much',
#   'emotional.',
#   'emotional',
#   'much',
#   'vulnerable',
#   'smooth,',
#   'that',
#   'good.',
#   'many',
#   'that',
#   'that',
#   'in',
#   'that',
#   'do',
#   'annoying',
#   'that',
#   'lonely.',
#   'juicy.',
#   'hot.',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'little',
#   'little',
#   'supportive.”',
#   'that',
#   'that'],
#  'much': ['for', 'better', 'chemistry.', 'shittier', 'Netflix', 'resentment,'],
#  'Um…': ['It’s'],
#  'It’s': ['a',
#   'been',
#   'OK.',
#   'coming.',
#   'really',
#   'what',
#   'like',
#   'so',
#   'all',
#   'different.',
#   'a',
#   'a',
#   'basically',
#   'like',
#   'because',
#   'very',
#   'so',
#   'a',
#   'lonely.',
#   'very',
#   'when',
#   'super',
#   'whatevs,',
#   'not'],
#  'a': ['very',
#   'very',
#   'shit',
#   'six-pack,',
#   'Ambien',
#   'Meditation',
#   'fucking',
#   'ghost',
#   'self-help',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictator’s',
#   'shovel',
#   'climax',
#   'Texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'grown-ass',
#   'mattress',
#   'kitchen.',
#   'very',
#   'catch.',
#   'secret',
#   'public',
#   'hipster?',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'Yoko',
#   'white',
#   'white',
#   'Wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin.',
#   'slip',
#   'Jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend.',
#   'shitty',
#   'new',
#   'man',
#   'Pinterest',
#   'Saturday.',
#   'completely',
#   'lot',
#   'genius.”',
#   'housewife,',
#   'great',
#   'lot.',
#   'great',
#   'office',
#   'office',
#   'office.',
#   'day,',
#   'sad-ass',
#   'MacGyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'disgusting',
#   'pervert.',
#   'gross',
#   'very',
#   'young',
#   'idiot,',
#   'result,',
#   'little',
#   'second',
#   'conqueror.',
#   'little–',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife,',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk,',
#   'quarter,',
#   'princess.',
#   'Vietnam',
#   'half',
#   'female',
#   'baby,',
#   'week',
#   'little',
#   'sudden.',
#   'frozen',
#   'lot',
#   'lot',
#   'kid.',
#   'kid?',
#   'lot',
#   'kid,',
#   'kid?',
#   'Asian',
#   'billion.',
#   'turtle',
#   'right',
#   'U-turn!”',
#   'O-turn!”',
#   'car',
#   'mess.',
#   'full',
#   'century',
#   'living.',
#   'fuck.',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smoker’s',
#   'side',
#   'sandwich.',
#   'way',
#   'doctor.',
#   'kid,',
#   'lot',
#   'lot',
#   'while,',
#   'bunch',
#   'dictatorship,',
#   'hand',
#   'man',
#   'zombie,',
#   'half',
#   'miscarriage,',
#   'lot',
#   'miscarriage.',
#   'third',
#   'pair',
#   'reason.',
#   'heartbeat.”',
#   'miscarriage.',
#   'month',
#   'bike',
#   'doula.',
#   'doula',
#   'white',
#   'soft',
#   'baby',
#   'child',
#   'marriage,',
#   'eyeball,',
#   'foot?',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye.',
#   'Minion.',
#   'year,',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good'],
#  'very': ['exciting',
#   'exciting',
#   'unusual',
#   'confusing…',
#   'picturesque',
#   'underrated.',
#   'well',
#   'surprised',
#   'soft,',
#   'nurturing',
#   'domestic.',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing,',
#   'clinical.',
#   'universal',
#   'grateful',
#   'common.',
#   'early.',
#   'much.',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'and',
#   'was',
#   'jobs,',
#   'long.',
#   'looks',
#   'since.',
#   'long.',
#   'on'],
#  'me.': ['It’s',
#   'I',
#   'And',
#   '‘Cause',
#   'When–',
#   'OK?”',
#   'You',
#   'Because',
#   'Like,',
#   'That’s',
#   'And',
#   '“Oh,',
#   'I',
#   'Oh,',
#   'How'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'Ali'],
#  'year': ['for', 'I'],
#  'turned': ['33'],
#  '33': ['this', 'and…'],
#  'year.': ['Yes!', 'Uh,'],
#  'Yes!': ['Thank'],
#  'five': ['people.', 'years,', 'years,'],
#  'people.': ['I', 'It’s…', 'Like,', 'I', 'That’s'],
#  'appreciate': ['that.'],
#  'that.': ['Uh,', 'Uh,', 'They', 'Don’t', 'I’m', 'They’re', 'I'],
#  'Uh,': ['I', 'this', 'we'],
#  'can': ['tell',
#   'also',
#   'I',
#   'I',
#   'never',
#   'you',
#   'be',
#   'tell,',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk,',
#   'comfortably',
#   'tell,',
#   'just',
#   'think',
#   'I',
#   'I',
#   'I',
#   'already',
#   'really',
#   'you',
#   'already',
#   'see,',
#   'find'],
#  'tell': ['that',
#   'that',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'you',
#   'because',
#   'you'],
#  'that': ['I’m',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'I',
#   'I’m',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'I’m',
#   'he',
#   'your',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement…',
#   'for',
#   'you',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'he',
#   'you’re',
#   'I',
#   'I',
#   'so',
#   'he’d',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'we’ll',
#   'fucking',
#   'housewife,',
#   'horrible',
#   'one-ply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'I',
#   'if',
#   'he’s',
#   'and',
#   'you',
#   'if',
#   'then,',
#   'they’re',
#   'fear.',
#   'fear',
#   'he',
#   'we',
#   'I’m',
#   'I',
#   'woman',
#   'now,',
#   'Whole',
#   'was',
#   'was',
#   'everybody',
#   'it’s',
#   'came',
#   'she’s',
#   '’cause',
#   'to',
#   'you',
#   'snail-trail',
#   'my',
#   'were',
#   'it',
#   'it’s',
#   'tell',
#   'means,',
#   'they',
#   'they',
#   'day',
#   'says,',
#   'stupid-ass',
#   'I',
#   'Harvard',
#   'I',
#   'shit',
#   'is?',
#   'you’re',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'he’s',
#   'goes',
#   'they',
#   'the',
#   'the',
#   'I’m',
#   'my'],
#  'I’m': ['getting',
#   'straight',
#   'jealous,',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'half-Chinese',
#   'half-Chinese',
#   'a',
#   'very',
#   'like,',
#   "done.'”",
#   'done.',
#   'not',
#   'a–',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'just',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed,',
#   'still',
#   'just',
#   'older,',
#   'not',
#   'only',
#   'only',
#   'gonna',
#   '33,',
#   'very',
#   '33.',
#   'from,',
#   'scared',
#   'very,',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked.',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older,', 'older,', 'busy', 'massages'],
#  'older,': ['because,', 'because', 'when'],
#  'because,': ['now,', 'usually,', 'last'],
#  'now,': ['when', 'because', 'instead', 'and', 'if'],
#  'when': ['I',
#   'they',
#   'a',
#   'you’re',
#   'she',
#   'we',
#   'you',
#   'you',
#   'I',
#   'you’re',
#   'a',
#   'our',
#   'you',
#   'we',
#   'I',
#   'I',
#   'I',
#   'I',
#   'you',
#   'he',
#   'I',
#   'that',
#   'you',
#   'you’re',
#   'they',
#   'I',
#   'I’m',
#   'I',
#   'I',
#   'my',
#   'you',
#   'trying',
#   'I',
#   'everything',
#   'I',
#   'the',
#   'it’s',
#   'it',
#   'they',
#   'I',
#   'he',
#   'a',
#   'they',
#   'they',
#   'you’re',
#   'they',
#   'I',
#   'they’re',
#   'you’re',
#   'you',
#   'he',
#   'you',
#   'I',
#   'it',
#   'it’s'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'who’s',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'Beyoncé.',
#   'how',
#   'how',
#   'if',
#   'me'],
#  'an': ['18-year-old', 'ATM', 'impression', 'investment'],
#  '18-year-old': ['girl,', 'girls,'],
#  'girl,': ['my', 'because'],
#  'my': ['automatic',
#   'body',
#   'Kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life.',
#   'generation.',
#   'time.',
#   'mom',
#   'optimum',
#   'husband,',
#   'league,',
#   'God,',
#   'God,',
#   'part.',
#   'generation.',
#   'Volvo.',
#   'pussy.',
#   'God.',
#   'God.',
#   'bed',
#   'husband',
#   'God!',
#   'Pinterest',
#   'best',
#   'wedding',
#   'husband,',
#   'personality',
#   'heart.',
#   'financial',
#   'friends,',
#   'co-workers.',
#   'toilet',
#   'fingers',
#   'co-workers',
#   'co-workers',
#   'shit',
#   'husband',
#   'life?',
#   'destiny.',
#   'last',
#   'mom,',
#   'dad,',
#   'grandma.”',
#   '20s,',
#   'God!',
#   'God!',
#   'husband',
#   'Asian-American',
#   'female',
#   'friends',
#   'husband',
#   'mind,',
#   'mind',
#   'God,',
#   'face',
#   'husband',
#   'destiny,',
#   'body',
#   'God,',
#   'fault.',
#   '20s,',
#   'uterus',
#   'progesterone',
#   'writing',
#   'co-workers,',
#   'underwear,',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers?',
#   'fingers?',
#   'fingers?”',
#   'husband',
#   'God,',
#   'husband',
#   'face',
#   'God.',
#   'mom–',
#   'six-week',
#   'God,',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband.',
#   'husband',
#   'doctor’s',
#   'God.',
#   'blood',
#   'husband',
#   'pussy’s',
#   'pussy’s',
#   'body’s',
#   'husband,',
#   'league,',
#   'God,',
#   'dreams',
#   'beautiful,',
#   'hard-earned',
#   'ass.'],
#  'automatic': ['thought…'],
#  'thought…': ['is'],
#  'is': ['“Fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'that?”',
#   'a',
#   'a',
#   'Asian.',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like,',
#   'always,',
#   'called',
#   'the',
#   'a',
#   'to',
#   'that…',
#   'doo',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   '80,',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious!”',
#   'so',
#   'it'],
#  '“Fuck': ['you.”', 'you.'],
#  'you.”': ['“Fuck', 'My'],
#  'you.': ['I', 'A', 'Don’t', 'There’s–', 'Ghostbusters!”', 'You'],
#  'don’t': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta…',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'wanna',
#   'wanna',
#   'worry,',
#   'cheat',
#   'wanna',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack.”',
#   'die.',
#   'die.',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'tell',
#   'work,'],
#  'even': ['know', 'know…', 'accidentally', 'effective.', 'have', 'come'],
#  'know': ['you,',
#   'what',
#   'that',
#   'when',
#   'what',
#   'when',
#   'what’s',
#   'why',
#   'the',
#   'anything',
#   'what',
#   'that',
#   'how',
#   'how',
#   'you',
#   'that',
#   'I',
#   'you',
#   'you’ve',
#   'what',
#   'if',
#   'what’s',
#   'the',
#   'why',
#   'what’s',
#   'what',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'that.',
#   'that'],
#  'but': ['fuck', 'I', 'it’s', 'I', 'I’m', 'my'],
#  'fuck': ['you!”', 'they', 'up!', 'down.', 'one', 'him', 'up.”', 'I'],
#  'you!”': ['‘Cause'],
#  '‘Cause': ['I’m', 'he', 'I', 'it’s', 'if', 'she', 'I'],
#  'straight': ['up', 'up', 'up'],
#  'up': ['jealous.',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards.',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'don’t',
#   'about',
#   'to',
#   'a',
#   'to',
#   'with',
#   'there',
#   'on',
#   'the',
#   'myself',
#   'from',
#   'your',
#   'soldier'],
#  'jealous.': ['I’m'],
#  'jealous,': ['first'],
#  'first': ['and', 'met', 'thing', 'dates,', 'and', 'lady', 'WebMD.', 'home'],
#  'foremost,': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them.',
#   'men',
#   'two',
#   'HPV.',
#   'Wolverine,',
#   'Grey,',
#   'Tidying',
#   'success.',
#   'all',
#   'my',
#   'shit.',
#   'my',
#   'a',
#   'you',
#   'my',
#   'success.”',
#   'losers.',
#   'losers.',
#   'skaters.',
#   'my',
#   'my',
#   'people',
#   'opinions,',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'Los',
#   'all,',
#   'bleach,',
#   'your',
#   'this',
#   'Asian',
#   'us',
#   'the',
#   'my',
#   'Facebook,',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence.',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   '“No!',
#   'the',
#   'control,',
#   'control',
#   'being',
#   'her,',
#   'saying,',
#   'saying:',
#   'income',
#   'one.',
#   'them.',
#   'shit.',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere.',
#   'their',
#   'her',
#   'those',
#   'longevity.',
#   'change.',
#   'mother',
#   'science',
#   'that…',
#   'my',
#   'the',
#   'people',
#   'fuckin’?”',
#   'the',
#   'that,',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him…',
#   'this',
#   'that',
#   'me.',
#   'women',
#   'women',
#   'shoes.',
#   'poppy',
#   'me',
#   'Craigslist.',
#   'childbirth.',
#   'women',
#   'the',
#   'your',
#   'life,',
#   'how',
#   'my',
#   'the',
#   'survival,',
#   'another',
#   'those',
#   'body',
#   'losers.',
#   'my',
#   'white-collar'],
#  'their': ['metabolism.',
#   'feet',
#   'whole',
#   'house.',
#   'communist',
#   'shit,',
#   'doo',
#   'hallways',
#   'iPad',
#   'eyebrows,',
#   'prostate.',
#   'fame',
#   'existence.',
#   'big-ass',
#   'Darth',
#   'arch-nemesis,',
#   'eyes',
#   'eyes.',
#   'eyes',
#   'head',
#   'eyelids.',
#   'face…',
#   '20s',
#   'husbands'],
#  'metabolism.': ['Because'],
#  'Because': ['18-year-old', 'according', 'I’m', 'I’m', 'we’re'],
#  'girls,': ['they'],
#  'they': ['could',
#   'take',
#   'put',
#   'go',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'mean.',
#   'don’t',
#   'purposely',
#   'don’t',
#   'want.',
#   'want.\nYou',
#   'say',
#   'wax',
#   'do',
#   'like',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'don’t',
#   'can',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldn’t',
#   'go',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph.',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'crush',
#   'kill',
#   'like',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'put',
#   'felt',
#   'wanted',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'waiting',
#   'keep',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding.',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'scratch',
#   'vacuum,',
#   'come',
#   'give',
#   'got',
#   'twerk,',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like',
#   'gluten-free,',
#   'all',
#   'that',
#   'it,',
#   'snacks',
#   'a',
#   'bananas.”'],
#  'like': ['shit,',
#   'to',
#   'Fifty',
#   'the',
#   '$200.',
#   'this',
#   'the',
#   'to',
#   'you’re',
#   'voting',
#   'that',
#   'I’m',
#   'making',
#   'a',
#   'loofah',
#   'responsibility.',
#   'host',
#   'Filipino',
#   'to',
#   'to',
#   'that.',
#   'free-range',
#   'we',
#   'you’re',
#   'wiping',
#   'it’s',
#   'you’re',
#   'I',
#   'I’m',
#   'a',
#   'it,',
#   'that',
#   'he’s',
#   'you’re',
#   'to',
#   'a',
#   'the',
#   'skittles.',
#   'a',
#   'everything',
#   'a',
#   'they',
#   'losing',
#   'fingers.',
#   'Whoppers',
#   'a',
#   'when'],
#  'shit,': ['and', 'too.'],
#  'then': ['they',
#   'after',
#   'also,',
#   'Asian',
#   'if',
#   'afterwards,',
#   'it',
#   'I',
#   'you',
#   'you',
#   'your',
#   'if',
#   'I',
#   'I',
#   'resist',
#   'he',
#   'I',
#   'she',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'six-pack,': ['right?'],
#  'right?': ['They', 'That’s', 'So,', 'You'],
#  'They': ['got',
#   'don’t',
#   'don’t',
#   'have',
#   'don’t',
#   'just',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'ruined',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'try',
#   'don’t',
#   'don’t',
#   'don’t',
#   'can',
#   'can',
#   'would',
#   'get',
#   'just',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'just',
#   'make',
#   'watch',
#   'were',
#   'tried'],
#  'got': ['that-that',
#   'so',
#   'married.',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married.',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'married,',
#   'pregnant,'],
#  'that-that': ['beautiful'],
#  'beautiful': ['inner'],
#  'inner': ['thigh', 'peace', 'evil,'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'I', 'the', 'the', 'I'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'now', 'to', 'when'],
#  'there’s': ['that', 'multiple'],
#  'huge': ['gap', 'unspoken', 'sit-down', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is'],
#  'with': ['the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him.',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes.',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me,',
#   'it,',
#   'you',
#   'intention,',
#   'me.',
#   'your',
#   'my'],
#  'light': ['of', 'completely.”'],
#  'potential': ['just'],
#  'radiating': ['through.\nAnd'],
#  'through.\nAnd': ['then,'],
#  'then,': ['when',
#   'all',
#   'it',
#   'you',
#   'on',
#   'at',
#   'at',
#   'a',
#   'when',
#   'because',
#   'I',
#   'you',
#   'I'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home…',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'bald…',
#   'to',
#   'time,”',
#   'through',
#   'to'],
#  'sleep,': ['they'],
#  'sleep.': ['Right?'],
#  'Right?': ['They'],
#  'insomnia': ['yet.'],
#  'yet.': ['They', 'They'],
#  'what': ['it’s',
#   'that',
#   'your',
#   'that',
#   'love',
#   'the',
#   'I',
#   'happens',
#   'he',
#   'to',
#   'I’m',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'I',
#   'that',
#   'a'],
#  'it’s': ['like',
#   'undetectable',
#   'a',
#   'very,',
#   'hot',
#   'funny,',
#   'too',
#   'probably',
#   'been',
#   'very',
#   'because',
#   'OK,',
#   'like',
#   'the',
#   'sexist',
#   'a',
#   'what',
#   'a',
#   'all',
#   'too',
#   'Easter',
#   'like,',
#   'go',
#   'not',
#   'because',
#   'different.',
#   'straight',
#   'Neosporin.'],
#  'Ambien': ['or'],
#  'or': ['download',
#   'you’re',
#   'you',
#   'for',
#   'something.',
#   'whatever.',
#   'something…'],
#  'download': ['a'],
#  'Meditation': ['Oasis'],
#  'Oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind.',
#   '30s',
#   'wealth.',
#   'butt',
#   'mom.',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'co-worker’s',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame,',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers.',
#   'first',
#   '20s,',
#   '30s,',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg,',
#   'life.',
#   'doctor’s',
#   'body'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind.': ['They'],
#  'whole': ['lives', 'manipulation', 'new', 'thing.”'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them.': ['They', 'They’re', 'Nothing', 'Once', 'They'],
#  'HPV': ['yet.', 'yet,', 'is', 'will'],
#  'sleep': ['in'],
#  'in': ['peace',
#   'men.',
#   'women’s',
#   'the',
#   'books',
#   'The',
#   'handy',
#   'San',
#   'eight',
#   'a',
#   'San',
#   'broad',
#   'the',
#   'a',
#   'America',
#   'a',
#   'my',
#   'it.',
#   'the',
#   'and',
#   'men.',
#   '2012.',
#   'my',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time!”',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed.',
#   'control',
#   'the',
#   'elementary',
#   'the',
#   'their–',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'your',
#   'such',
#   'the',
#   'Atlanta.',
#   'their',
#   'front',
#   'my',
#   'labor,',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'debt.'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night.',
#   'home',
#   'this',
#   'the',
#   'Golden',
#   'any',
#   'how,',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life,',
#   'first.',
#   'home,',
#   'any',
#   'my',
#   'Fresh',
#   'some',
#   'my',
#   'work.',
#   'him.',
#   'his'],
#  'night.': ['Everybody', 'And'],
#  'Everybody': ['has', 'has', 'has'],
#  'has': ['HPV,',
#   'it.',
#   'it.',
#   'HPV.',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'HPV,': ['OK?', 'because'],
#  'OK?': ['Everybody',
#   'I’m',
#   'That',
#   'So,',
#   'A',
#   'I',
#   'You',
#   'So,',
#   'Are',
#   'We',
#   'I',
#   'Old',
#   'Do',
#   'When',
#   'When',
#   'They',
#   'Are'],
#  'it.': ['It’s',
#   'If',
#   'You',
#   'It’s',
#   'You',
#   'Second',
#   'So,',
#   'Sheryl',
#   'I',
#   'When',
#   'Now',
#   'That’s'],
#  'OK.': ['Come', 'And'],
#  'Come': ['out'],
#  'out': ['already.',
#   'of',
#   'there',
#   'of',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first.',
#   'that',
#   'of',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'about',
#   'yet',
#   'of',
#   'of'],
#  'already.': ['Everybody'],
#  'If': ['you', 'it', 'a', 'you’re', 'you', 'it’s'],
#  'it': ['yet,',
#   'might',
#   'all',
#   'when',
#   'was',
#   'on',
#   'can',
#   'on',
#   'don’t',
#   'was',
#   'on',
#   'on',
#   'as',
#   'so',
#   'for',
#   'a',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up.',
#   'up,',
#   'interesting.',
#   'in',
#   'before,',
#   'tonight.',
#   'might',
#   'up.',
#   'was',
#   'in',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'made',
#   'gets',
#   'was',
#   'so',
#   'as',
#   'very',
#   'takes',
#   'also',
#   'easier.',
#   'was',
#   'different?”',
#   'up,',
#   'all',
#   'turns'],
#  'yet,': ['you', 'you’re'],
#  'You': ['go',
#   'don’t',
#   'wanna',
#   'homeless',
#   'go',
#   'feel',
#   'feel',
#   'know?\nBut',
#   'get',
#   'don’t',
#   'guys',
#   'mess',
#   'guys',
#   'can',
#   'gotta',
#   'guys',
#   'tell',
#   'ain’t',
#   'have',
#   'gotta',
#   'gotta',
#   'only',
#   'know',
#   'know?',
#   'know',
#   'know,',
#   'just',
#   'could',
#   'guys',
#   'pee',
#   'know',
#   'know',
#   'just',
#   'change',
#   'know,',
#   'owe'],
#  'you’re': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like,',
#   'too',
#   'like,',
#   'about',
#   'paranoid',
#   'like,',
#   'a',
#   'really',
#   'married,',
#   'gonna',
#   'fucking',
#   'the',
#   'supposed',
#   'eating',
#   'gonna',
#   'in',
#   '33,',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser,', 'housewife.', 'different', 'baby.', 'baby,'],
#  'loser,': ['all'],
#  'all': ['right?',
#   'about.',
#   'of',
#   'your',
#   'came',
#   'required',
#   'this',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day,',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'he’s',
#   'squirmy',
#   'right?',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off.'],
#  'That’s': ['what',
#   'what',
#   'where',
#   'right,',
#   'how',
#   'how',
#   'right.',
#   'the',
#   'when',
#   'not',
#   'the',
#   'not',
#   'shit',
#   'right.',
#   'so',
#   'my',
#   'why',
#   'a',
#   'the',
#   'not'],
#  'says': ['about', 'to'],
#  'about': ['you.',
#   'the',
#   'him',
#   'a',
#   'Vietnamese',
#   'it',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money.',
#   'anal.',
#   'is,',
#   'that',
#   'is,',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'A': ['lot', 'lot', 'woman', 'lot', 'lot', 'whole', 'big', 'lot'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['don’t', 'are', 'are', 'as'],
#  'because': ['it’s',
#   'my',
#   'my',
#   'you',
#   'what?',
#   'before',
#   'I',
#   'being',
#   'he’s',
#   'he’s',
#   'you',
#   'I',
#   'you',
#   'I',
#   'the',
#   'he',
#   'you',
#   'we’re',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'uh,',
#   'they’re',
#   'they’re',
#   'then',
#   'the',
#   'we’re',
#   'when',
#   'the',
#   'I',
#   'if',
#   'my–',
#   'he'],
#  'undetectable': ['in'],
#  'men.': ['It’s', 'We'],
#  'really': ['fucked',
#   'work,',
#   'meant',
#   'scared',
#   'am!”',
#   'take',
#   'am',
#   'hot,'],
#  'fucked': ['up.', 'a', 'up'],
#  'up.': ['HPV', 'A', 'You', 'She’s'],
#  'ghost': ['that'],
#  'inside': ['men’s', 'of'],
#  'men’s': ['bodies'],
#  'bodies': ['and'],
#  'says,': ['“Boo!”', '“Please,'],
#  '“Boo!”': ['in'],
#  'women’s': ['bodies.', 'intuition.'],
#  'bodies.': ['My'],
#  'My': ['doctor',
#   'husband',
#   'husband,',
#   'father-in-law',
#   'husband',
#   'Toyota',
#   'mom',
#   'nipples'],
#  'doctor': ['told', 'says', 'appointments.'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'me': ['that',
#   'that',
#   'to',
#   'something.',
#   'off?”',
#   'feel',
#   'to',
#   'feel',
#   'the',
#   'tell',
#   'about',
#   'with',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on,',
#   'and',
#   'enough',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'see',
#   'of',
#   'company',
#   'when',
#   'when',
#   'anymore.',
#   'extremely',
#   'in',
#   'while',
#   'to',
#   'a',
#   'out.',
#   'out',
#   'to',
#   'money,',
#   'in',
#   'for'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'of', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'Latina', 'sacks,', 'weeks'],
#  'strains': ['of'],
#  'HPV.': ['Either', 'Very'],
#  'Either': ['I'],
#  'kind': ['that’s', 'where', 'of', 'of', 'of', 'of'],
#  'that’s': ['gonna',
#   'right,',
#   'not',
#   'like…',
#   'not',
#   'gonna',
#   'why',
#   'the',
#   'cool…',
#   'so',
#   'like',
#   'enough'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'into': ['cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure.',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'cervical': ['cancer…'],
#  'cancer…': ['…or'],
#  '…or': ['I'],
#  'body': ['will', 'is', 'hair', 'is', 'odor.', 'was', 'when', 'where,'],
#  'will': ['heal', 'also', 'also', 'you', 'always', 'be', 'have', 'commend'],
#  'heal': ['itself.', 'from'],
#  'itself.': ['Very'],
#  'Very': ['helpful,', 'lucky'],
#  'helpful,': ['this'],
#  'doctor,': ['right?'],
#  'So,': ['basically,',
#   'you',
#   'we’re',
#   'he',
#   'you',
#   'you’re',
#   'I',
#   'when',
#   'now,',
#   'I',
#   'I',
#   'my',
#   'then',
#   'then',
#   'I',
#   'you',
#   'as'],
#  'basically,': ['either'],
#  'either': ['I’m'],
#  'die…': ['or'],
#  'presence': ['of'],
#  'Wolverine,': ['bitches.'],
#  'bitches.': ['We’ll', 'I'],
#  'We’ll': ['find'],
#  'find': ['out.', 'a', 'ways', 'a', 'it'],
#  'out.': ['Um,', 'They', 'They', 'They'],
#  'Um,': ['I', 'and'],
#  'also': ['tell', 'disappear.', 'got', 'last', 'don’t', 'decided', 'takes'],
#  'Kindle': ['is'],
#  'turning': ['into', 'into'],
#  'self-help': ['library.'],
#  'library.': ['I’m'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic,',
#   'recognize',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again!”',
#   'Rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'OK.',
#   'fuckin’.',
#   'because',
#   'doing',
#   'there.',
#   'gonna',
#   'like',
#   'the'],
#  'interested': ['in', 'in'],
#  'books': ['like'],
#  'Fifty': ['Shades'],
#  'Shades': ['of'],
#  'Grey,': ['OK?'],
#  'The': ['Life-Changing',
#   'manual.',
#   'next',
#   'advantage',
#   'fancy',
#   'images',
#   'Boat,'],
#  'Life-Changing': ['Magic'],
#  'Magic': ['of'],
#  'Tidying': ['Up.'],
#  'Up.': ['Yes.'],
#  'Yes.': ['Yes,', 'Yes.', 'Yes.', 'I', 'Because'],
#  'Yes,': ['that’s'],
#  'right,': ['how', 'Ali,', 'we', 'because', 'I’ve'],
#  'how': ['to',
#   'can',
#   'proposals',
#   'rotten',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'there’s,',
#   'it'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'all', 'and', 'together.'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success.': ['That’s'],
#  '30s': ['is'],
#  'about.': ['How'],
#  'How': ['can', 'did', 'did', 'did'],
#  'around?': ['I’m', 'Help'],
#  'horrible': ['person,', 'toilet'],
#  'person,': ['I’m'],
#  'happy': ['with'],
#  'am,': ['how'],
#  'Help': ['me,'],
#  'me,': ['Tony',
#   'he’s',
#   'this',
#   'but',
#   'I',
#   'because',
#   '“Oh,',
#   'I’m',
#   'out',
#   'with'],
#  'Tony': ['Robbins,'],
#  'Robbins,': ['help'],
#  'help': ['me!\nI', 'her', 'you', 'as'],
#  'me!\nI': ['have'],
#  'hoarding': ['problem,', 'goes', 'problem'],
#  'problem,': ['which'],
#  'which': ['I’m',
#   'is',
#   'means',
#   'would',
#   'their',
#   'is',
#   'is',
#   'means',
#   'subsequently'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems.', 'homeless', 'day.', 'shitty'],
#  'problems.': ['I’m'],
#  'if': ['the',
#   'he',
#   'you',
#   'you',
#   'I',
#   'you',
#   'you',
#   'I',
#   'you',
#   'I’m',
#   'I',
#   'he',
#   'you',
#   'I',
#   'I'],
#  'goes': ['away,', 'down'],
#  'away,': ['the'],
#  'disappear.': ['I', 'That’s'],
#  'problem': ['because'],
#  'mom': ['is', 'got', 'is', 'is'],
#  'from': ['a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Pier',
#   'Harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'holding',
#   'bacteria',
#   'Harvard'],
#  'third': ['world', 'grade,', 'world'],
#  'world': ['country', '♪', 'with', 'country,'],
#  'country': ['and', 'and'],
#  'she': ['taught', 'refused', 'was', 'wrote', 'knows', 'is', 'was', 'said,'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called'],
#  'throw': ['away', 'up.', 'up'],
#  'away': ['anything,', 'from', 'at'],
#  'anything,': ['because'],
#  'dictator’s': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth.': ['So,'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade,': ['’cause'],
#  'might': ['come', 'need', 'mean'],
#  'come': ['in', 'out,', 'up', 'out,', 'out', 'home,', 'with', 'out'],
#  'handy': ['as'],
#  'as': ['a',
#   'a',
#   'an',
#   'women',
#   'much',
#   'they',
#   'a',
#   'many',
#   'possible',
#   'the',
#   'freaky',
#   'me.',
#   'a',
#   'old',
#   'her.',
#   'wet',
#   'it',
#   'pent-up,',
#   'angry',
#   'possible.',
#   'leverage',
#   'it'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'in', 'makin’'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['and', 'hole.', 'with', 'hole', 'cheeks', 'hole.'],
#  'running': ['away'],
#  'Communists.\nThe': ['last'],
#  'last': ['time',
#   'forever.',
#   'boyfriend',
#   'time',
#   'year,',
#   'boyfriend',
#   'year,'],
#  'time': ['I', 'shitting', 'I', 'I', 'you'],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like,',
#   'like,',
#   'like,',
#   'that,',
#   'attending',
#   'like,',
#   'a',
#   'like,',
#   'living',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'Cuban',
#   'like,',
#   'like,',
#   'like,',
#   'legit,',
#   'gonna',
#   'ready.',
#   'ripe.',
#   'rotten.',
#   'free?',
#   'like,',
#   'you.',
#   'like,',
#   'like,',
#   'like,',
#   'very',
#   'magical.',
#   'to',
#   'sliced',
#   'sliced',
#   'like,',
#   'like,',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   'in',
#   'OK,',
#   'clearly',
#   'that',
#   'Easter',
#   'so',
#   'about',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   '18',
#   'like,',
#   'like,',
#   '$70,000'],
#  'San': ['Francisco,', 'Francisco,'],
#  'Francisco,': ['I', 'when'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'her': ['get',
#   'to',
#   'book',
#   'Lululemon',
#   'butt.”',
#   'nipples,',
#   'pussy',
#   'white',
#   'I'],
#  'rid': ['of'],
#  'shit.': ['Don’t', 'My', 'You’re', 'It’s'],
#  'Don’t': ['ever', 'try', 'your', 'kill', 'feel'],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know…',
#   'fancy',
#   'yoga.',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'it.',
#   'it',
#   'anything.',
#   'it!',
#   'anything.”',
#   'write',
#   'that.',
#   'whatever',
#   'that.',
#   'all',
#   'anal',
#   'it.',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'in',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   'a',
#   'it?',
#   'you'],
#  'mom.': ['It', 'People'],
#  'It': ['was',
#   'was',
#   'was',
#   'cost',
#   'could',
#   'was',
#   'happened',
#   'happened',
#   'basically',
#   'was',
#   'tells',
#   'was,',
#   'makes'],
#  'worst': ['experience', 'thing'],
#  'experience': ['of', 'some'],
#  'life.': ['It', 'And'],
#  'emotional.': ['We'],
#  'were': ['screaming',
#   'all',
#   'in',
#   'hipsters,',
#   'getting',
#   'done,',
#   'like,',
#   'discouraging',
#   'like,',
#   '18',
#   'alarmingly',
#   'suppositories,',
#   'trying',
#   'like,',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['to', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['to', 'to'],
#  'let': ['go', 'it', 'their'],
#  'Texas': ['Instruments'],
#  'Instruments': ['TI-82…'],
#  'TI-82…': ['manual.'],
#  'manual.': ['The', 'She'],
#  'She': ['don’t', 'doesn’t'],
#  'know…': ['where', 'that', 'freaked'],
#  'calculator': ['is.', 'is.', 'that'],
#  'is.': ['Those', 'It'],
#  'Those': ['of'],
#  'under': ['25'],
#  '25': ['probably'],
#  'probably': ['don’t', 'Pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation.': ['We', 'You'],
#  'required': ['to'],
#  'buy': ['it'],
#  'we': ['were',
#   'had,',
#   'had…',
#   'were',
#   'were',
#   'spend',
#   'pay',
#   'eat',
#   'eat',
#   'do…',
#   'are',
#   'have',
#   'as',
#   'better',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'live',
#   'wouldn’t',
#   'got',
#   'got',
#   'bought',
#   'die.'],
#  'eight': ['grade.'],
#  'grade.': ['It'],
#  'cost': ['like'],
#  '$200.': ['And'],
#  'And': ['everybody',
#   'my',
#   'I',
#   'the',
#   'I',
#   'I',
#   'we–',
#   'then',
#   'I',
#   'you',
#   'then',
#   'we',
#   'I',
#   'then',
#   'on',
#   'the',
#   'so,',
#   'then',
#   'look,',
#   'her',
#   'then,',
#   'they’re',
#   'they’ll',
#   'you',
#   'you’re',
#   'then',
#   'then',
#   'just',
#   'I',
#   'what',
#   'they’re',
#   'I',
#   'you',
#   'it’s',
#   'then,',
#   'I’m',
#   'I',
#   'all',
#   'their',
#   'they',
#   'you',
#   'then,',
#   'she',
#   'when',
#   'it–',
#   'it',
#   'a',
#   'I',
#   'then,',
#   'then,',
#   'I',
#   'they',
#   'then,',
#   'then,',
#   'then,',
#   'then',
#   'a',
#   'everything',
#   'the',
#   'I',
#   'then',
#   'I',
#   'most',
#   'he',
#   'I',
#   'just',
#   'it',
#   'then,',
#   'I',
#   'I',
#   'then,',
#   'me,',
#   'now,'],
#  'everybody': ['thought', 'doesn’t', 'thought'],
#  'thought': ['it', 'they', 'it'],
#  'Judy': ['Jetson’s'],
#  'Jetson’s': ['laptop'],
#  'laptop': ['from'],
#  'future.': ['All', '‘Cause'],
#  'All': ['because', 'of', 'the', 'right,'],
#  'what?': ['It'],
#  'graph.': ['It'],
#  'Tesla': ['of'],
#  'time.': ['And', 'And', 'And', 'It'],
#  'emotional': ['about'],
#  'manual': ['and'],
#  '“You': ['never', 'need', 'need', 'have', 'look.”', 'watch'],
#  'need': ['this.”',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'children',
#   'to',
#   'you',
#   'to'],
#  'this.”': ['And'],
#  '“But…': ['I'],
#  'clean': ['all'],
#  'die.”': ['“And'],
#  '“And': ['I’m', 'all'],
#  'be': ['a',
#   'a',
#   'nice',
#   'with',
#   'racist',
#   'exfoliated',
#   'providing',
#   'made',
#   'no',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'all',
#   'abused',
#   'roughed',
#   'out',
#   'sure',
#   'out',
#   'the',
#   'able',
#   'like,',
#   'there',
#   'there',
#   'one',
#   'that',
#   'storyboarding',
#   'able',
#   'like,',
#   'as',
#   'like,',
#   'like,',
#   'pregnant',
#   'seven',
#   'asked',
#   'considered',
#   'considered',
#   'one'],
#  'procrastinator': ['anymore.'],
#  'anymore.': ['Because', 'I', 'I', 'I’ve', 'Since', 'I’m', 'I’m', 'I’m'],
#  'according': ['to', 'to'],
#  'Deepak-Oprah,': ['that’s'],
#  'way': ['for', 'out', 'of', 'to…”', 'more'],
#  'success.”': ['I'],
#  'grew': ['up', 'up', 'up', 'up'],
#  'past': ['year.', 'year'],
#  'married.': ['Yeah.', 'I’m'],
#  'Yeah.': ['To', 'Yes.', 'Which', 'It’s'],
#  'To': ['a'],
#  'man': ['who', 'and', 'has', 'a', 'at', 'all', 'is'],
#  'who': ['now',
#   'is',
#   'like',
#   'are',
#   'wrote',
#   'are',
#   'have',
#   'recycles',
#   'are',
#   'have',
#   'else',
#   'tries',
#   'trapped'],
#  'now': ['has', 'for', 'we’re'],
#  'lucky': ['guy.', 'girl,'],
#  'guy.': ['He'],
#  'He': ['gave',
#   'was',
#   'was',
#   'grew',
#   'was',
#   'proposed!”',
# ...
#   'a',
#   'sure',
#   'him'],
#  'dude': ['believe', 'you', 'eats', 'and', 'named'],
#  'believe': ['that', 'that.”', 'he', 'that'],
#  'secret': ['garden.”'],
#  'garden.”': ['When,'],
#  'When,': ['really,'],
#  'really,': ['it’s', 'you', 'I'],
#  'public': ['park…'],
#  'park…': ['…that'],
#  '…that': ['has', 'blows'],
#  'hosted': ['many'],
#  'many': ['reggae', 'more', 'men'],
#  'reggae': ['fests…'],
#  'fests…': ['…and'],
#  '…and': ['has', 'half-jungle'],
#  'accidentally': ['let…'],
#  'let…': ['two'],
#  'homeless': ['people', 'or', 'friends,', 'dude!'],
#  'people': ['inside.',
#   'are',
#   'all',
#   'don’t',
#   'until',
#   'doing',
#   'were',
#   'will'],
#  'hipsters,': ['OK?'],
#  'store': ['Urban'],
#  'Urban': ['Outfitters'],
#  'Outfitters': ['has'],
#  'made': ['things', 'into', 'it,', 'me', 'you'],
#  'things': ['very', 'like'],
#  'confusing…': ['for'],
#  'hipster?': ['Is'],
#  'Is': ['that'],
#  'beard': ['for'],
#  'fashion': ['or'],
#  'warmth?': ['It'],
#  'happened': ['to…', 'in', 'to'],
#  'to…': ['It', 'Now,'],
#  'living': ['there,'],
#  'there,': ['and', 'through', 'OK?'],
#  'guy': ['in'],
#  'broad': ['daylight'],
#  'daylight': ['and'],
#  'had,': ['like,'],
#  'had…': ['We'],
#  'had': ['so',
#   'been',
#   'this',
#   'been',
#   'this',
#   'tried',
#   'it',
#   'to',
#   'a',
#   'to',
#   'the',
#   'this',
#   'a',
#   'such',
#   'this',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'a',
#   'one,',
#   'the',
#   'dated'],
#  'chemistry.': ['He'],
#  '“Hey,': ['wassup?”', 'can', 'I', 'hey!', 'can'],
#  'wassup?”': ['I'],
#  '“Wassup?”': ['And'],
#  'we–': ['The'],
#  'next': ['thing', 'century'],
#  'knew,': ['we'],
#  'back': ['of', 'out', 'in', 'of', 'in'],
#  'Volvo.': ['And'],
#  'after': ['we', 'they'],
#  'done,': ['he'],
#  'drop': ['me'],
#  'off?”': ['I'],
#  '“Where?”': ['He'],
#  '“At': ['the'],
#  'park.”': ['And'],
#  'dropped': ['him'],
#  'off': ['at', 'and', 'of'],
#  'Golden': ['Gate'],
#  'Gate': ['Park'],
#  'Park': ['and'],
#  'watched': ['him'],
#  'run': ['into', 'over'],
#  'middle': ['with'],
#  'friends,': ['and', 'when', 'dead.', 'dead.', 'dead.'],
#  'no!”': ['“I'],
#  '“I': ['just',
#   'could',
#   'did',
#   'saw',
#   'just',
#   'gotta',
#   'don’t',
#   'changed',
#   'slime',
#   'am'],
#  'dude!': ['Again!”'],
#  'Again!”': ['My'],
#  'husband': ['is',
#   'and',
#   'recently.',
#   'is',
#   'to',
#   'and',
#   'dies.”',
#   'isn’t',
#   'and',
#   'a',
#   'down',
#   'will',
#   'for',
#   'on,',
#   'was'],
#  'Asian.': ['Which', 'Yeah!'],
#  'Which': ['a', 'is…', 'means', 'is', 'is', 'he’s', 'is'],
#  'shocked': ['by,'],
#  'by,': ['because,'],
#  'usually,': ['Asian-American'],
#  'Asian-American': ['women', 'men', 'brothers'],
#  'women': ['who,',
#   'all',
#   'should',
#   'had',
#   'get',
#   'get',
#   'who',
#   'who',
#   'who',
#   'would',
#   'won’t',
#   'tried'],
#  'who,': ['like,'],
#  'know,': ['wear',
#   'because',
#   'white',
#   'it’s',
#   'just',
#   'learning',
#   'I',
#   'squeeze',
#   'it’s–',
#   'and',
#   'a',
#   'is',
#   'I–',
#   'they',
#   'I–'],
#  'wear': ['these', 'that'],
#  'these': ['kinda',
#   'bitches.',
#   'Chinese',
#   'women',
#   'boring,',
#   'other',
#   'hormone',
#   'ovulation'],
#  'kinda': ['glasses'],
#  'glasses': ['and'],
#  'opinions,': ['they'],
#  'date': ['white'],
#  'white': ['dudes.',
#   'dude',
#   'dude,',
#   'dudes,',
#   'dude.',
#   'dude',
#   'man!',
#   'people',
#   'people.',
#   'friends,',
#   'hippie'],
#  'dudes.': ['You'],
#  'any': ['hipster', 'moment,', 'real', 'sort', 'black', 'given'],
#  'hipster': ['neighborhood'],
#  'neighborhood': ['in'],
#  'major': ['city'],
#  'city': ['in'],
#  'America': ['and'],
#  'Yoko': ['Ono'],
#  'Ono': ['factory.'],
#  'factory.': ['It’s…'],
#  'It’s…': ['too', 'amazing.', 'It’s'],
#  'too': ['much.', 'nice.', 'old', 'late', 'stupid', 'funky,'],
#  'much.': ['I', 'For'],
#  'what’s': ['wrong', 'gonna', 'wrong'],
#  'wrong': ['with', 'with'],
#  'it,': ['you', 'you', 'and', 'that', 'when', 'just…'],
#  'being': ['with', 'the', 'courageous.'],
#  'feel': ['very…',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad,'],
#  'very…': ['You'],
#  'picturesque': ['when'],
#  'dude,': ['you', 'focus', 'and'],
#  'know.': ['You'],
#  'Wes': ['Anderson'],
#  'Anderson': ['movie'],
#  'movie': ['or'],
#  'dudes,': ['they'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling,': ['and'],
#  'disturbing': ['documentaries.'],
#  'documentaries.': ['They'],
#  'introduce': ['you'],
#  'very,': ['you', 'very'],
#  'hot': ['hookin’'],
#  'hookin’': ['up'],
#  'dude.': ['I', 'Do', 'That’s–'],
#  'mean,': ['nothing'],
#  'nothing': ['makes', 'for'],
#  'makes': ['me', 'me', 'sense,'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy.': ['Oh,'],
#  'Oh,': ['my', 'my', 'you', 'my', 'my', 'my'],
#  'God.': ['I', 'It’s', 'That’s', 'I'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement…': ['…you'],
#  '…you': ['know,'],
#  'right': ['there,', 'now!', 'moment', 'turn–', 'there.', 'after'],
#  'through': ['the', 'Southeast', 'and', 'a', 'it.', 'a'],
#  'money': ['hole', 'if'],
#  'hole': ['and', 'feels'],
#  'just…': ['And', 'Let’s', '“I', 'And'],
#  'also,': ['he’s'],
#  'vulnerable': ['down'],
#  'down': ['there.', 'there,', 'your', 'immediately', 'in', 'so', 'with'],
#  'there.': ['I’m,', 'I', 'But'],
#  'I’m,': ['like,', 'like,'],
#  'crush': ['your'],
#  'head': ['at', 'shredding', 'and', 'for'],
#  'moment,': ['white', 'you'],
#  'man!': ['I'],
#  'kill': ['you', 'me!'],
#  'now!': ['Crush'],
#  'Crush': ['those', 'while'],
#  'those': ['brains!', 'comments.', 'green', 'old', 'doctor', 'crazy'],
#  'brains!': ['Colonize'],
#  'Colonize': ['the'],
#  'colonizer!”': ['You'],
#  'know?\nBut': ['I'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'it’s',
#   'of',
#   'about',
#   'that’s',
#   'so.',
#   'I’m'],
#  'marriage,': ['it', 'because'],
#  'nice': ['to'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race.', 'goddamn'],
#  'race.': ['The'],
#  'advantage': ['is'],
#  'home…': ['and'],
#  'racist': ['together.'],
#  'together.': ['You', 'And,'],
#  'say': ['whatever', 'to', 'be'],
#  'whatever': ['you', 'they', 'you', 'the'],
#  'like!': ['You'],
#  'explain': ['shit.'],
#  'half-Filipino,': ['half-Japanese.'],
#  'half-Japanese.': ['I’m'],
#  'half-Chinese': ['and', 'and'],
#  'half-Vietnamese.': ['And', 'So,'],
#  'spend': ['100'],
#  '100': ['percent'],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time', 'first', 'Buddha', 'careers.', 'day', 'society', 'first'],
#  'shitting': ['on'],
#  'Korean': ['people.'],
#  'amazing.': ['It’s'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on,'],
#  'on,': ['you', 'you', 'like,'],
#  'know?\nMy': ['last'],
#  'boyfriend': ['was', 'because'],
#  'Cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'I',
#   'crash.”',
#   'simultaneously',
#   'explode.',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'Mexican': ['people', 'friends,'],
#  '“Hold': ['it.'],
#  'guys': ['aren’t', 'know', 'about', 'need', 'had.”', 'can', 'doin’'],
#  'aren’t': ['Mexican?”'],
#  'Mexican?”': ['Asian-American'],
#  'underrated.': ['I'],
#  'why': ['people', 'you', 'are', 'we’re', 'I’m'],
#  'sexiest.': ['Asian', 'They'],
#  'Asian': ['men', 'men,', 'people.', 'female', 'woman,', 'don’t', 'ladies'],
#  'no': ['body', 'body', 'job.', 'unpredictable', 'kid', 'shame.'],
#  'hair': ['from'],
#  'neck': ['down.'],
#  'down.': ['It’s', 'I', 'I', 'People'],
#  'making': ['love'],
#  'dolphin.': ['Oh,'],
#  'smooth,': ['just'],
#  'slip': ['and'],
#  'slide.': ['Just'],
#  'Just': ['black', 'sneak', 'give', 'give', 'choke', 'try'],
#  'black': ['fish,', 'friends.'],
#  'fish,': ['Tilikum,'],
#  'Tilikum,': ['all'],
#  'bed': ['every'],
#  'every': ['night,',
#   'day.”',
#   'single',
#   'day.',
#   'day.',
#   'day…',
#   'day',
#   'single'],
#  'night,': ['you', 'everybody.'],
#  'know?': ['Ooh-wee.',
#   'Maybe',
#   'I',
#   'Especially',
#   'My',
#   'Like,',
#   'I',
#   'I',
#   'I',
#   'And,',
#   'Your',
#   'And'],
#  'Ooh-wee.': ['You'],
#  'mess': ['with'],
#  'Jewish': ['dude', 'male'],
#  'afterwards.': ['It’s', 'I'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for,'],
#  'exfoliated': ['today.”'],
#  'today.”': ['“This'],
#  '“This': ['is'],
#  'J-date,': ['more'],
#  'loofah': ['date.'],
#  'date.': ['Thanks'],
#  'Thanks': ['for'],
#  'rug': ['burn,'],
#  'burn,': ['Avi.”'],
#  'Avi.”': ['And'],
#  'men,': ['no'],
#  'odor.': ['None.'],
#  'None.': ['They'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility.': ['That’s'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['from.\nI', 'out.', 'out', 'out,', 'to'],
#  'from.\nI': ['think'],
#  'unspoken': ['understanding,'],
#  'understanding,': ['uh,'],
#  'between': ['each', 'your'],
#  'each': ['other,', 'other.'],
#  'other,': ['because'],
#  'half-Filipino': ['and'],
#  'half-Japanese': ['and'],
#  'we’re': ['both', 'too', 'expected', 'so', 'such', 'trying', 'hippies,'],
#  'both': ['half-fancy', 'total,', 'are'],
#  'half-fancy': ['Asian…'],
#  'Asian…': ['…and'],
#  'half-jungle': ['Asian.'],
#  'Yeah!': ['You', 'Never'],
#  'difference.': ['The'],
#  'fancy': ['Asians', 'things'],
#  'Asians': ['are', 'host'],
#  'Chinese,': ['the'],
#  'Japanese.': ['They'],
#  'host': ['Olympics.', 'diseases.'],
#  'Olympics.': ['Jungle'],
#  'Jungle': ['Asians'],
#  'diseases.': ['It’s…'],
#  'different.': ['But', 'It’s'],
#  'East': ['Coast,'],
#  'Coast,': ['going'],
#  'going': ['to', 'to', 'back', 'through', 'through', 'to'],
#  'private': ['school,', 'school,', 'school'],
#  'school,': ['playing', 'too.'],
#  'playing': ['lacrosse,', 'chess', 'dumb', 'Candy'],
#  'lacrosse,': ['uh,'],
#  'learning': ['Latin'],
#  'Latin': ['and'],
#  'chess': ['and'],
#  'rugby.': ['He'],
#  'Filipino': ['Carlton,'],
#  'Carlton,': ['OK?'],
#  'didn’t': ['know', 'think', 'know', 'know'],
#  'anything': ['about'],
#  'Vietnamese': ['people'],
#  'dates,': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['of', 'from', 'effect'],
#  'Los': ['Angeles'],
#  'Angeles': ['called'],
#  'called': ['Pho', 'Lean', 'bossy.'],
#  'Pho': ['Show.'],
#  'Show.': ['He'],
#  '“It’s': ['authentic', 'not'],
#  'authentic': ['Vietnamese.'],
#  'Vietnamese.': ['I'],
#  'read': ['about'],
#  'Yelp!”': ['I'],
#  'authentic,': ['OK?”'],
#  'OK?”': ['You', '‘Cause', 'And', 'And'],
#  'tell,': ['first', 'but'],
#  'name,': ['’cause'],
#  'number': ['in'],
#  'Second': ['of'],
#  'all,': ['you'],
#  'bathroom.': ['If'],
#  'legit,': ['the'],
#  'bathroom': ['would'],
#  'double': ['as', 'standard'],
#  'supply': ['closet.'],
#  'closet.': ['When'],
#  'When': ['I',
#   'you',
#   'I',
#   'I’ve',
#   'can',
#   'can',
#   'my',
#   'in–',
#   'you’re',
#   'somebody',
#   'somebody',
#   'I',
#   'it’s'],
#  'pee,': ['I'],
#  'gallons': ['of'],
#  'bleach,': ['an'],
#  'ATM': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner.': ['And'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'nice.': ['We'],
#  'leave': ['this', 'without', 'you,'],
#  'deaf': ['and'],
#  'emotionally': ['abused.'],
#  'abused.': ['I'],
#  'too.': ['Him', 'We', 'But', 'They'],
#  'Him': ['and', 'and'],
#  'total,': ['like,'],
#  'school': ['Asians.'],
#  'Asians.': ['We'],
#  'big': ['hippies,', 'fantasy', 'impact'],
#  'hippies,': ['too.', 'I’d'],
#  'backpack': ['through'],
#  'Southeast': ['Asia.'],
#  'Asia.': ['We'],
#  'yoga.': ['We'],
#  'ayahuasca': ['ceremonies.'],
#  'ceremonies.': ['We'],
#  'silent': ['meditation'],
#  'meditation': ['retreats.'],
#  'retreats.': ['That’s'],
#  'pay': ['$800', 'for'],
#  '$800': ['to'],
#  'shut': ['up', 'up!”', 'the'],
#  'weekend.': ['We'],
#  'gluten-free,': ['which'],
#  'means': ['we', 'I', 'the', 'you’re'],
#  'bread': ['that', 'that’s'],
#  'tastes': ['like', 'when'],
#  'free-range': ['Chewbacca.'],
#  'Chewbacca.': ['We'],
#  'lesbian': ['bread'],
#  'like…': ['…a'],
#  '…a': ['thousand'],
#  'thousand': ['percent'],
#  'daily': ['fiber…', 'basis.', 'basis…'],
#  'fiber…': ['and'],
#  '20': ['percent'],
#  'spoken': ['word'],
#  'word': ['poetry.', '“bossy”', '“bossy,”'],
#  'poetry.': ['When'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom.'],
#  'poem': ['about…'],
#  'about…': ['…supporting'],
#  '…supporting': ['Caitlyn'],
#  'Caitlyn': ['Jenner'],
#  'Jenner': ['or'],
#  'whatever.': ['And'],
#  'so,': ['it’s', 'in', 'motherfucker,'],
#  'funny,': ['right,'],
#  'Asian,': ['too.'],
#  'sometimes,': ['all'],
#  'hippy-dippy': ['shit'],
#  'do…': ['makes'],
#  'doing': ['an', 'anything.', 'jack', 'it.'],
#  'impression': ['of'],
#  'Like,': ['we', 'you', '“I', 'I’m', '“You,'],
#  'Chinese': ['scrolls', 'ladies', 'ladies,'],
#  'scrolls': ['up'],
#  'wall…': ['and'],
#  'neither': ['of'],
#  'us': ['know', 'to,'],
#  'mean.': ['We’re'],
#  'We’re': ['like,', 'like,'],
#  'seems': ['to', 'to'],
#  'well': ['with'],
#  'Buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'Pier': ['1'],
#  '1': ['Imports.'],
#  'Imports.': ['That'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point,', 'of'],
#  'good': ['feng', 'in', 'night,'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house.': ['Him', 'Skin', '“Hey,'],
#  'four': ['years', 'days'],
#  'years': ['and', 'old,', 'old,'],
#  'I–': ['I', 'I–', 'I,', 'I,'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose…': ['because…'],
#  'because…': ['I', 'they’re'],
#  'pressuring': ['him'],
#  'wacky': ['women’s'],
#  'intuition.': ['That’s'],
#  'proposals': ['really'],
#  'work,': ['OK?', 'we'],
#  'woman': ['has', 'is', 'wants', 'who'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'man’s': ['head.', 'eye'],
#  'head.': ['First'],
#  'First': ['passively'],
#  'passively': ['and'],
#  'doesn’t': ['get', 'see', 'have', 'have', 'believe'],
#  'message,': ['extremely'],
#  'extremely': ['aggressively.', 'itchy.'],
#  'aggressively.': ['You'],
#  'threaten': ['to'],
#  'without': ['ever'],
#  'actually': ['leaving,'],
#  'leaving,': ['because'],
#  'old': ['and', 'as', 'Chinese'],
#  'late': ['to'],
#  'there': ['and', 'and', 'is', 'for', 'for', 'would'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again.': ['So,', 'And', 'It’s', 'But'],
#  '“I’m': ['just', 'gonna', 'just'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere.'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  '“Shut': ['the'],
#  'up!': ['Fine,'],
#  'Fine,': ['will'],
#  'marry': ['me?”', 'him'],
#  'me?”': ['And'],
#  'afterwards,': ['the', 'and'],
#  'always,': ['like,'],
#  'God!': ['He', 'It’s', 'And'],
#  'proposed!”': ['“It'],
#  '“It': ['came'],
#  'nowhere.': ['And', 'And'],
#  'look,': ['he'],
#  'exact': ['ring'],
#  'ring': ['I'],
#  'wanted.': ['How', 'I’m'],
#  'Maybe': ['he', 'because'],
#  'Pinterest': ['page', 'page…'],
#  'page': ['or'],
#  'something…': ['that'],
#  'sent': ['to'],
#  'best': ['friend,', 'you'],
#  'friend,': ['that'],
#  'send': ['to'],
#  'day.”': ['Let'],
#  'Let': ['me', 'me'],
#  'page…': ['he’s'],
#  'Pinterested': ['in'],
#  'engaged': ['on'],
#  'Saturday.': ['I'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['Tuesday…'],
#  'Tuesday…': ['because'],
#  'tried': ['it', 'to', 'to'],
#  '2012.': ['I'],
#  'ready.': ['I'],
#  'ripe.': ['I'],
#  'rotten.': ['I'],
#  'banana': ['bread.'],
#  'bread.': ['That’s'],
#  'rotten': ['I'],
#  'was.': ['People'],
#  'People': ['are', 'praise', 'don’t'],
#  'always': ['very', 'feel', 'catch', 'means', 'tell', 'wanted.'],
#  'surprised': ['at'],
#  'how,': ['off-stage,'],
#  'off-stage,': ['with'],
#  'completely': ['different'],
#  'different': ['person.', 'holes,', 'people.'],
#  'person.': ['You–'],
#  'You–': ['Like,'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'him.': ['With', 'But'],
#  'With': ['him,'],
#  'soft,': ['and,'],
#  'nurturing': ['and'],
#  'domestic.': ['We’ve'],
#  'We’ve': ['been'],
#  'years,': ['and', 'I’ve'],
#  'I’ve': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day.', 'night.'],
#  'day.': ['Yeah.', 'Which', 'Housewives,', 'This'],
#  'he’d': ['become'],
#  'become': ['dependent', 'the', 'a', 'this', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'School,': ['and', 'the'],
#  'work': ['anymore.',
#   'anymore.',
#   'anymore.',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymore.'],
#  'don’t.': ['I'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'Freak me from a dictator’s gonna before him, and do fancy Asians are never throw.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
bill_text = data.transcript.loc['bill']
bill_text[:200]
# Out:
# '[cheers and applause] All right, thank you! Thank you very much! Thank you. Thank you. Thank you. How are you? What’s going on? Thank you. It’s a pleasure to be here in the greater Atlanta, Georgia, a'

# %%
dave_text = data.transcript.loc['dave']
dave_text[:200]
# Out:
# 'This is Dave. He tells dirty jokes for a living. That stare is where most of his hard work happens. It signifies a profound train of thought, the alchemist’s fire that transforms fear and tragedy into'

# %%
bill_dict = markov_chain(bill_text)
bill_dict
# Out:
# {'[cheers': ['and', 'and', 'and', 'and', 'and', 'and', 'and', 'and'],
#  'and': ['applause]',
#   'all',
#   'when',
#   'causes',
#   'say',
#   'just',
#   'applause]',
#   'age.',
#   'complaining',
#   'your',
#   'complaining.',
#   'watch',
#   'the',
#   'a',
#   'applause]',
#   'some',
#   'the',
#   'hit',
#   'asked',
#   'all',
#   'listen',
#   'listen',
#   'a',
#   'it',
#   'a',
#   'living.',
#   'then',
#   'it’s',
#   'it',
#   'you',
#   'white',
#   'when',
#   'now',
#   'pound',
#   'I’m',
#   'people',
#   'applause]',
#   'make',
#   'the',
#   'he',
#   'lepers,',
#   'he’s',
#   'the',
#   'applause]',
#   'everybody',
#   'they',
#   'they’re',
#   'they',
#   'they',
#   'where',
#   'what',
#   'the',
#   'came',
#   'that',
#   'I.',
#   'other',
#   'I',
#   'applause]',
#   'all',
#   'applause]',
#   'I',
#   'over',
#   'what',
#   'that’s',
#   'then',
#   'you',
#   'now',
#   'it',
#   'help',
#   'friends',
#   'the',
#   'it',
#   'down,',
#   'down,',
#   'everything',
#   'everybody',
#   'see',
#   'be',
#   'turn',
#   'make',
#   'applause]',
#   'this',
#   'the',
#   'higher',
#   'that’s',
#   'to',
#   'when',
#   'I',
#   'it’s',
#   'I',
#   'I’ll',
#   'I’ll',
#   'I',
#   'if',
#   'then',
#   'knocked',
#   'then',
#   'go',
#   'be',
#   'just',
#   'then',
#   'you',
#   'get',
#   'they',
#   'kids.',
#   'the',
#   'the',
#   'then',
#   'he',
#   'you’re',
#   'I',
#   'a',
#   'clean',
#   'I',
#   'it’s',
#   'just',
#   'then',
#   'crackers',
#   'do',
#   'when',
#   'buy',
#   'hang',
#   'you’re',
#   'I’m',
#   'get',
#   'shit.',
#   'then',
#   'then',
#   'the',
#   'the',
#   'he',
#   'then',
#   'then',
#   'a',
#   'says,',
#   'the',
#   'he',
#   'snoring',
#   'you',
#   'he',
#   'be',
#   'regroup.',
#   'then',
#   'she',
#   'she',
#   'kind',
#   'then',
#   'they',
#   'that',
#   'rock',
#   'in',
#   'a',
#   'you’re',
#   'applause]'],
#  'applause]': ['All', 'I', 'Everybody', 'Yeah.', 'And', 'Just', 'So', 'Do'],
#  'All': ['right,',
#   'of',
#   'right?',
#   'of',
#   'right,',
#   'right?',
#   'right?',
#   'of',
#   'of',
#   'of',
#   'right.',
#   'you’re',
#   'right?',
#   'of',
#   'my',
#   'right?',
#   'right?',
#   'right,',
#   'you',
#   'right?',
#   'right?',
#   'you',
#   'right?',
#   'right,',
#   'of',
#   'of',
#   'right.',
#   'right?',
#   'right?',
#   'right?',
#   'she',
#   'right?',
#   'right,'],
#  'right,': ['thank',
#   'I’ll',
#   'put',
#   'and',
#   'I’ll',
#   'with,',
#   'just',
#   'we’ll',
#   'stay',
#   'and',
#   'all',
#   'I',
#   'you’re',
#   'Dad,',
#   'if',
#   'so',
#   'let’s',
#   'you',
#   'all',
#   'all',
#   'this',
#   'I’m'],
#  'thank': ['you!', 'God.', 'you.'],
#  'you!': ['Thank', 'This', 'You’ve', 'He'],
#  'Thank': ['you', 'you.', 'you.', 'you.', 'you.', 'you', 'you,', 'you.'],
#  'you': ['very',
#   'understand',
#   'get',
#   'know',
#   'know.',
#   'have',
#   'did',
#   'and',
#   'got,',
#   'know,',
#   'get',
#   'don’t',
#   'know,',
#   'something.',
#   'know?',
#   'telling',
#   'know,',
#   'think',
#   'guys?',
#   'ever',
#   'to',
#   'to',
#   'know,',
#   'want',
#   'know?',
#   'know?',
#   'know?',
#   'know?',
#   'think',
#   'think',
#   'go',
#   'can',
#   'understand,',
#   'people!',
#   'think',
#   'know',
#   'can',
#   'can',
#   'can',
#   'know?”',
#   'something,',
#   'by.',
#   'got,',
#   'can,',
#   'know.',
#   'get',
#   'by.',
#   'dressed',
#   'sung',
#   'had',
#   'know?',
#   'want',
#   'can',
#   'put',
#   'believe?”',
#   'seriously',
#   'think',
#   'think',
#   'thought…',
#   'know?',
#   'know?',
#   'can',
#   'repeat',
#   'get',
#   'call',
#   'please',
#   'know?',
#   'know,',
#   'know,',
#   'know?',
#   'can',
#   'clear,',
#   'know?',
#   'know?',
#   'know?',
#   'know?',
#   'call',
#   'think',
#   'die,',
#   'die,',
#   'go',
#   'made',
#   'make',
#   'have',
#   'don’t',
#   'set',
#   'got',
#   'out.”',
#   'know,',
#   'can',
#   'just',
#   'think?',
#   'to',
#   'come',
#   'gonna',
#   'die,',
#   'wrap',
#   'were',
#   'remember',
#   'know',
#   'do,',
#   'know?',
#   'land,',
#   'bring',
#   'do',
#   'up',
#   'shut',
#   'have',
#   'and',
#   'know',
#   'remember',
#   'watched',
#   'mean',
#   'had',
#   'your',
#   'know?',
#   'got',
#   'shack',
#   'when',
#   'know?',
#   'guys,',
#   'got',
#   'can',
#   'got',
#   'got',
#   'can',
#   'got',
#   'guys,',
#   'get',
#   'kids',
#   'were',
#   'gay.”',
#   'don’t',
#   'hug',
#   'start',
#   'have',
#   'have',
#   'want',
#   'want',
#   'shitty',
#   'still',
#   'shit',
#   'know',
#   'turn',
#   'grab',
#   'say',
#   'guys',
#   'don’t',
#   'got',
#   'have',
#   'redo',
#   'got',
#   'what',
#   'don’t',
#   'know',
#   'little',
#   'doing?',
#   'keep',
#   'too',
#   'want.',
#   'do.',
#   'say',
#   'sew.',
#   'understand',
#   'one.',
#   'can’t',
#   'know',
#   'go',
#   'gonna',
#   'guys',
#   'gotta',
#   'said',
#   'already',
#   'waiting',
#   'guys',
#   'go,',
#   'look',
#   'doing?',
#   'really',
#   'go',
#   'got',
#   'think?',
#   'gun',
#   'keep',
#   'do',
#   'fucking',
#   'this,',
#   'guys',
#   'ever',
#   'ever',
#   'take',
#   'put',
#   'put',
#   'guys',
#   'got',
#   'have',
#   'gun',
#   'got',
#   'barking',
#   'fucking',
#   'can’t',
#   'gonna',
#   'see',
#   'had',
#   'could',
#   'could',
#   'could',
#   'people,',
#   'actually',
#   'have',
#   'pull',
#   'are.',
#   'with',
#   'have',
#   'in',
#   'out',
#   'gonna',
#   'gonna',
#   'don’t',
#   'got',
#   'talk',
#   'get',
#   'afraid',
#   'say',
#   'onto',
#   'got',
#   'got',
#   'in',
#   'out.',
#   'got',
#   'got',
#   'got',
#   'do.',
#   'bark',
#   'got',
#   'really',
#   'doing?”',
#   'want',
#   'got',
#   'got',
#   'could',
#   'getting',
#   'stop',
#   'see',
#   'don’t',
#   'slowly',
#   'so',
#   'next'],
#  'very': ['much!', 'offensive', 'happy', 'least,', 'interesting'],
#  'much!': ['Thank'],
#  'you.': ['Thank',
#   'Thank',
#   'How',
#   'It’s',
#   'People',
#   'For',
#   'You',
#   'You',
#   'Come',
#   '“~',
#   'I’m',
#   'That',
#   'You',
#   'You',
#   'I',
#   'I’ll',
#   '“Well,',
#   'Only',
#   'I',
#   '[cheers'],
#  'How': ['are', 'would', 'does', 'come', 'you', 'did', 'is'],
#  'are': ['you?',
#   'up',
#   'you',
#   'doing',
#   'into.',
#   'into,',
#   'getting',
#   'right,',
#   'like,',
#   'fake,',
#   'cunts!',
#   'they?',
#   'you',
#   'ruining',
#   'you',
#   'cool,',
#   'all',
#   'you',
#   'you',
#   'out',
#   'gonna',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'awesome,',
#   'awesome,',
#   'you',
#   'burning,'],
#  'you?': ['What’s'],
#  'What’s': ['going',
#   'wrong?”',
#   'up,',
#   'going',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'going': ['on?',
#   'to',
#   'to',
#   'on',
#   'to',
#   'around',
#   'over',
#   'a',
#   'great.',
#   'out',
#   'to',
#   'on',
#   'to',
#   'like,',
#   'back',
#   'on?',
#   'to'],
#  'on?': ['Thank', 'We'],
#  'It’s': ['a',
#   'nice',
#   'nice',
#   'brutal.',
#   'awful.',
#   'like,',
#   'a',
#   'like',
#   'horrific',
#   'one',
#   'like,',
#   'fucking',
#   'been,',
#   'not',
#   'a',
#   'so',
#   'like',
#   'like',
#   'a',
#   'like',
#   '’cause',
#   'just',
#   'the',
#   'not',
#   'one',
#   'like,',
#   'like',
#   'fuckin’',
#   'like,',
#   'the',
#   'basically…',
#   'like',
#   'supporting'],
#  'a': ['pleasure',
#   'cold',
#   'week.',
#   'row.',
#   'democracy.',
#   'democracy.',
#   'program',
#   'multiple',
#   'pencil,',
#   'group,',
#   'shit.',
#   'group?',
#   'group,',
#   'fucking',
#   'fucking',
#   'quarterback.',
#   'graduation',
#   'member',
#   'blessing.',
#   'great',
#   'Santa',
#   'flag.',
#   'dick,',
#   'bunch',
#   'gig',
#   'piece',
#   'great',
#   'perfect',
#   'shit.',
#   'beer,',
#   'picture',
#   'sudden,',
#   'woman,',
#   'woman.',
#   'woman',
#   'minute!”',
#   'pledge',
#   'pledge',
#   'lot',
#   'Holocaust-',
#   'grandparent',
#   'sudden,',
#   'snowman',
#   'water',
#   'fuck',
#   'half',
#   'half',
#   'line',
#   'catch!',
#   'great',
#   'great',
#   'ballgame.',
#   'fence',
#   'known',
#   'shit.',
#   'castle,',
#   'hippie.',
#   'couple',
#   'serial',
#   '25-year',
#   'mike',
#   'college',
#   'senior',
#   'reference',
#   'kid,',
#   'woman',
#   'shit,',
#   'sports',
#   'really',
#   'dude,',
#   'sports',
#   'dickless',
#   'woman.',
#   'flashlight.',
#   'fucking',
#   '10%',
#   'beard',
#   'boat',
#   'swamp',
#   'little',
#   'jelly',
#   'star',
#   'big',
#   'master’s',
#   'zillion',
#   'good',
#   'boat.',
#   'group',
#   'wall',
#   'long',
#   'plane',
#   'bunch',
#   'lot',
#   'driver’s',
#   'religion.',
#   'woman',
#   'baby',
#   'spaceship',
#   'lot',
#   'tooth,',
#   'fairy.',
#   'decision,',
#   'couple',
#   'year,',
#   'team,',
#   'sudden',
#   'riot',
#   'gig',
#   'pigeon,',
#   'car,',
#   'car',
#   'real',
#   'lot',
#   'damn.',
#   'fuck!',
#   'fear',
#   'fear',
#   'sudden.',
#   'while.',
#   'while,',
#   'jet–”',
#   'little',
#   'war.',
#   'joke.',
#   'fuck,',
#   'stud',
#   'city',
#   'smaller',
#   'sudden,',
#   'sudden,',
#   'vengeance.',
#   'sudden,',
#   'female',
#   'child.',
#   '37-year-old',
#   'higher',
#   'man,',
#   'haunted',
#   'species.',
#   'safety',
#   'lion',
#   'sweater.',
#   'guy',
#   'child.',
#   'good',
#   'little',
#   'family,',
#   'touchy-feely…',
#   'marriage,',
#   'great',
#   'split',
#   'kid.',
#   'kid,',
#   'veteran',
#   'kid,',
#   'homophobic',
#   'drama',
#   'public',
#   'puddle,',
#   'lot',
#   'little',
#   'sudden,',
#   'kid,',
#   'kid,',
#   'Frisbee.',
#   'Saturday.”',
#   'face',
#   'couple',
#   'kid,',
#   'two-year-old',
#   'mitten',
#   'more',
#   'great',
#   'funny',
#   'great',
#   'sweatshop.',
#   'seat.”',
#   'cloud!',
#   'cloud!”',
#   'bowl',
#   'twofer.',
#   'flamethrower',
#   'vacuum',
#   'toaster.',
#   'big',
#   'couple',
#   'little',
#   'helicopter,',
#   'skyscraper',
#   'house,',
#   'gun',
#   'fucking',
#   'city',
#   'desert.',
#   'birdbath,',
#   'good',
#   'hover',
#   'helicopter.',
#   'place',
#   'white',
#   'nail',
#   'mattress,',
#   'sudden,',
#   'mattress',
#   'tour',
#   'couple,',
#   'tour.”',
#   'county',
#   'hero',
#   'romantic',
#   'man.',
#   'chopper,',
#   'superhero.”',
#   'fucking',
#   'burger,',
#   'beer.',
#   'county',
#   'dummy',
#   'hell',
#   'helicopter.',
#   'happy',
#   'gun.',
#   'helicopter',
#   '.22,',
#   '.22.',
#   'big',
#   'second,',
#   'five-shot',
#   'burned-out',
#   'couple',
#   'comedy',
#   'real',
#   'fucking',
#   'stranger',
#   'weapon',
#   'burned-out',
#   'gun',
#   'kick,',
#   'nightstand,',
#   'pork',
#   'fucking',
#   'sudden,',
#   'sudden,',
#   'fuckin’',
#   '.22',
#   '‘roided-up',
#   'jab',
#   'BB',
#   'fuck',
#   'BB',
#   'fact.',
#   'fact.',
#   'fight',
#   'blanket',
#   'bra,',
#   'ball',
#   'debate',
#   'normal',
#   'ledge',
#   'chain',
#   'sandwich',
#   'never-ending',
#   'fuck?',
#   'dick.',
#   'while,',
#   'little',
#   'rescue',
#   'great',
#   'good',
#   'little',
#   'lot',
#   'little',
#   'romantic',
#   'woman’s',
#   'little',
#   'woman',
#   'little',
#   'little',
#   'passed-out',
#   'while,',
#   'wall.',
#   'metaphor,',
#   'little',
#   'U-shaped',
#   'doorjamb,',
#   'porn',
#   'dick,',
#   'buck-80',
#   'naked',
#   'half-filled',
#   'great'],
#  'pleasure': ['to'],
#  'to': ['be',
#   'be',
#   'be',
#   'get',
#   'the',
#   'die',
#   'live.',
#   'get',
#   'its',
#   'survive.',
#   'come',
#   'go.”',
#   'have',
#   'bring',
#   'immediately',
#   'be',
#   'be',
#   'people',
#   'say',
#   'meetings.',
#   'improve',
#   'a',
#   'sit',
#   'thank',
#   'do',
#   'ruin',
#   '’em',
#   'tell',
#   'take',
#   'watch.',
#   'hit',
#   'open',
#   'have',
#   'have',
#   'have',
#   'use',
#   'blow',
#   'a',
#   'the',
#   'that',
#   'it.',
#   'a',
#   'Peter',
#   'Chris',
#   'God,',
#   'absorb',
#   'pay',
#   'what’s',
#   'get',
#   'your',
#   'figure',
#   'be',
#   'the',
#   'color.',
#   'switch',
#   'me,',
#   'his',
#   'fucking',
#   'Sunday',
#   'your',
#   'my',
#   'college,',
#   'be',
#   'go–',
#   'church',
#   'be',
#   'make',
#   'the',
#   'me.',
#   'in',
#   'me?',
#   'fall,',
#   'make',
#   'it,',
#   'me',
#   'town,',
#   'anybody,',
#   'believe',
#   'find',
#   'be',
#   'get',
#   'turn',
#   'fail,',
#   'now',
#   'get',
#   'look',
#   'heaven',
#   'enjoy',
#   'show',
#   'enjoy',
#   'come',
#   'be',
#   'do',
#   '35',
#   'getting',
#   'make',
#   'a',
#   'turn',
#   'join',
#   'be',
#   'getting',
#   'build',
#   'have',
#   'just',
#   'an',
#   'me.”',
#   'bake,',
#   'know,',
#   'tell',
#   'stop',
#   'do',
#   'do',
#   'find',
#   'do',
#   'fucking',
#   'life,',
#   'like',
#   'shout',
#   'think,',
#   'hug',
#   'raise',
#   'tell',
#   'some',
#   'do?',
#   'improve',
#   'keep',
#   'get',
#   'war.',
#   'like,',
#   'drama',
#   'one',
#   'the',
#   'be',
#   'the',
#   'do',
#   'find',
#   'find',
#   'my',
#   'be',
#   'start',
#   'his',
#   'death',
#   'Atlanta.',
#   'get',
#   'parties,',
#   'stop',
#   'me,',
#   'have',
#   'do,',
#   'use',
#   'get',
#   'be',
#   'adopt.',
#   'do.',
#   'piss',
#   'just',
#   'tell',
#   'do,',
#   'get.',
#   'get,',
#   'do?',
#   'rescue',
#   'the',
#   'raise?',
#   'sit',
#   'me,',
#   'be',
#   'go',
#   'say',
#   'you.',
#   'know',
#   'make',
#   'himself,',
#   'do',
#   'learn',
#   'fly',
#   'a',
#   'a',
#   'go.',
#   'fly',
#   'do',
#   'achieve?',
#   'ask?”',
#   'tell',
#   'God!”',
#   'his',
#   'give',
#   'a',
#   'this',
#   'open',
#   'do.',
#   'be',
#   'him.',
#   'get',
#   'get',
#   'pick',
#   'fly',
#   'do',
#   'the',
#   'be,',
#   'go',
#   'the',
#   'go.',
#   'squeak',
#   'go',
#   'work',
#   'you',
#   'kill',
#   'basically',
#   'somebody’s',
#   'go',
#   'get',
#   'dial',
#   'sprinkle',
#   'figure',
#   'get',
#   'sleep.',
#   'sleep.”',
#   'sleep.”',
#   'sleep!”',
#   'say',
#   'that',
#   'them,',
#   'sleep',
#   'sleep,',
#   'be',
#   'keep',
#   'have',
#   'keep',
#   'people,',
#   'people,',
#   'her.',
#   'make',
#   'feel',
#   'be',
#   'understand',
#   'get',
#   'choke',
#   'be',
#   'do',
#   'do',
#   'God,',
#   'no',
#   'the',
#   'hell',
#   'bring',
#   'make',
#   'grab',
#   'try',
#   'pick',
#   'come',
#   'do',
#   'do',
#   'try',
#   'be',
#   'God',
#   'counterbalance.',
#   'the',
#   'carry',
#   'carry',
#   'it,',
#   'your'],
#  'be': ['here',
#   'here.',
#   'here.',
#   'great',
#   'honest',
#   'arbitrary.',
#   'nice.',
#   'fuckin’',
#   'honest',
#   'a',
#   'that',
#   'a',
#   'wrong.',
#   'an',
#   'honest',
#   'honest',
#   'fair',
#   'some',
#   'that',
#   'like',
#   'open-minded.',
#   'the',
#   'even',
#   'like',
#   'honest,',
#   'in',
#   'like,',
#   'a',
#   'about',
#   'mad.”',
#   'animals,',
#   'screaming',
#   'driving',
#   'like…',
#   'in',
#   'like,',
#   'the',
#   'like,',
#   'an',
#   'bicoastal,',
#   'like,',
#   'brand-new.',
#   'amazing?',
#   'to',
#   'like,',
#   'like,',
#   'the',
#   'honest',
#   'nuts,',
#   'crazy.',
#   'like,',
#   'like,',
#   'enough',
#   'thinking,',
#   'that',
#   'a',
#   'one',
#   'shooting',
#   'ringing,',
#   'throwing',
#   'the',
#   'that',
#   'mad.”',
#   'a',
#   'safe,',
#   'getting',
#   'fun.”',
#   'a'],
#  'here': ['in',
#   'in',
#   'comes',
#   'thinking…',
#   'to',
#   'because',
#   'to',
#   'in',
#   'staring',
#   'and',
#   'downstairs,',
#   'is'],
#  'in': ['the',
#   'June.',
#   'shape,',
#   'order',
#   'order',
#   'the',
#   'a',
#   'a',
#   'a',
#   'trouble,',
#   'your',
#   'this',
#   'his',
#   'trouble,',
#   'Dallas,',
#   'their',
#   'trouble',
#   'trouble',
#   'trouble,',
#   'trouble,',
#   'ze',
#   'trouble.',
#   'trouble.',
#   'trouble.',
#   'my',
#   '1934.',
#   'to',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that.',
#   'your',
#   'trouble.',
#   'black',
#   'trouble',
#   'my',
#   'the',
#   'the',
#   'Vegas,',
#   'case.',
#   'a',
#   'the',
#   'there.',
#   'like',
#   'English',
#   'a',
#   'the',
#   'Los',
#   'my',
#   'the',
#   'theirs,',
#   'this.',
#   'curling.',
#   'fulfillment',
#   'this',
#   'any',
#   'something,',
#   'Helsinki,',
#   'the',
#   'the',
#   'you.',
#   'that',
#   'here,',
#   'here.',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'my',
#   'the',
#   'love',
#   'the',
#   'you,',
#   'love.',
#   'reality,',
#   'the',
#   'the',
#   'third',
#   'the',
#   'there?”',
#   'the',
#   'a',
#   'the',
#   'my',
#   'like',
#   'fifth',
#   'a',
#   'the',
#   'wars.',
#   'there',
#   'the',
#   'the',
#   'Los',
#   'that',
#   'a',
#   'Atlanta.',
#   'Atlanta',
#   'a',
#   'a',
#   'a',
#   'the',
#   'on',
#   'Orange',
#   'Orange',
#   'from',
#   '1903.',
#   'pain',
#   'my',
#   'an',
#   'a',
#   'the',
#   '1903.',
#   'like',
#   'the',
#   'there,',
#   'the',
#   'the',
#   'too,',
#   'the',
#   '20',
#   'the',
#   'the',
#   'through',
#   'a',
#   'this',
#   'your',
#   'my',
#   'me.',
#   'my',
#   'bed,',
#   'the',
#   'an',
#   'front',
#   'your',
#   'the',
#   'a',
#   'romantic',
#   'here,',
#   'those',
#   'a',
#   'her',
#   'the',
#   'here',
#   'your',
#   'your',
#   'your'],
#  'the': ['greater',
#   'racism',
#   'white',
#   'hell',
#   'gym,',
#   'hell',
#   'environment,',
#   'gas',
#   'atmosphere',
#   'air',
#   'balls',
#   'population',
#   'balls',
#   'votes.',
#   'sheer',
#   'fuck',
#   'same',
#   'gay',
#   'draft,',
#   'whole',
#   'next',
#   'Buffalo',
#   'same',
#   'last',
#   'entire',
#   'way',
#   'manager',
#   'manager',
#   'waitress.',
#   'dumbest',
#   '“Don’t',
#   'church',
#   'nerve',
#   'amount',
#   'cookies',
#   'Food',
#   'hell',
#   'old',
#   'Clippers',
#   'wrong',
#   'cookies,',
#   'fuck?”',
#   '“N”',
#   'weirdest,',
#   'guy',
#   'math.',
#   'color',
#   'generation',
#   'genocide',
#   'Native',
#   'Clippers,',
#   'early',
#   '1940’s,',
#   'bubble.',
#   'world.',
#   'place!',
#   'last',
#   'bubble–',
#   'sad',
#   'gig',
#   'devil.',
#   'guitar',
#   'fucking',
#   '#1',
#   'world,',
#   'shit',
#   'shock.',
#   'doubt',
#   'middle',
#   'church,',
#   'Book,',
#   'language',
#   'church.',
#   'church,',
#   'bad,',
#   'fucking',
#   'new',
#   'hell',
#   'Manchurian',
#   'queers.”',
#   'fuck',
#   'fuck',
#   'old',
#   'boat?',
#   'people',
#   'Book?',
#   'Vatican.',
#   'other',
#   'stories,',
#   'Dude',
#   'same',
#   'other',
#   'basis',
#   'Ten',
#   'fifth',
#   'murderous',
#   'ankles,',
#   'whole',
#   'whole',
#   'whole',
#   'stories',
#   'first',
#   'story',
#   'dumbest',
#   'mystery.',
#   'Scientologists,',
#   'dumbest',
#   'space',
#   'chimney,',
#   'Easter',
#   'lake?',
#   'Tooth',
#   'NBA',
#   'world',
#   'casual',
#   'time,',
#   'shit,',
#   'shooter,',
#   'ride,',
#   'two',
#   'third',
#   'Scriptures…”',
#   'DVD',
#   'most',
#   'fact',
#   'rails?',
#   'balls',
#   'engine?',
#   'battery',
#   'way',
#   'deal,',
#   'hell',
#   'worst.',
#   'guy’s',
#   'plane.',
#   'planes,',
#   'pilots.',
#   'airline',
#   'fuckin’',
#   'back,',
#   'metal',
#   'plane’s',
#   'hair',
#   'shit!',
#   'balls',
#   'fuck',
#   'day',
#   'Discovery',
#   'carburetor',
#   'car.',
#   'thing',
#   'way',
#   'females',
#   'wind',
#   'female',
#   'whole',
#   'dice.',
#   'dice',
#   'next',
#   'dude',
#   'fucking',
#   'kitchen',
#   'street,',
#   'memory',
#   'street,',
#   'shower.',
#   'shower,',
#   'shower',
#   'hot',
#   'world,',
#   'hugging',
#   'Tabernacle–”',
#   'deal.',
#   'shit',
#   'stuff',
#   'way',
#   'rain,',
#   'cafeteria,',
#   'fuck',
#   'shit',
#   'adult',
#   'principal',
#   'fucking',
#   'kid',
#   'family',
#   'big',
#   'mayoral',
#   'Middle',
#   'bullying…”',
#   'superintendent',
#   'mayoral',
#   'conversation',
#   'YouTube',
#   'raccoon',
#   'cat’s',
#   'cat',
#   'raccoon',
#   'next',
#   'kid’s',
#   'other',
#   'bottom,',
#   'kid',
#   'instant',
#   'kid',
#   'factory',
#   'States.',
#   'car,',
#   'rest',
#   'hell',
#   'greatest',
#   'couch.”',
#   'gate',
#   'second',
#   'offensive',
#   'blindside.',
#   'world',
#   'dollar',
#   'problem,',
#   'discipline',
#   'boy',
#   'sweatshop',
#   'answer.',
#   'bed,',
#   'bushes',
#   'fuck',
#   'fuckin’',
#   'window,',
#   'complete',
#   'dollar',
#   'outskirts,',
#   'helicopter.',
#   'helicopter',
#   'ultimate',
#   'situation.',
#   'street?',
#   'red',
#   'goddamn',
#   'living',
#   'shit',
#   'fan,',
#   'fuck',
#   'fuck',
#   'street',
#   'place.',
#   'same',
#   'business',
#   'American',
#   'family',
#   'family',
#   'dude',
#   'money.',
#   'tour,',
#   'dude',
#   'balloons',
#   'cake.',
#   'family',
#   'speech',
#   'helicopter.',
#   'left',
#   'aircraft,',
#   'door.',
#   'fuck?',
#   'fuck?',
#   'fuck,',
#   'fuck?!',
#   'fucking',
#   'story.',
#   'guy',
#   'decision,',
#   'land',
#   'chopper.”',
#   'dashboard.',
#   'tour.',
#   'door.',
#   'thing.',
#   'ocean,',
#   'air.',
#   'most',
#   'history',
#   'way',
#   'hospital.',
#   'balls',
#   'sly,',
#   'holster?',
#   'fucking',
#   'gun',
#   'briefcase.',
#   'end',
#   'job.',
#   'street?',
#   'joke',
#   'South.',
#   'gun',
#   'car,',
#   'trigger.',
#   'muzzle',
#   'gun.',
#   'trigger,',
#   'gun',
#   'sake',
#   'gun',
#   'bullets',
#   'thing',
#   'morning,',
#   'psycho’s',
#   'morning.',
#   'morning,',
#   'sake',
#   'covers,',
#   'morning,',
#   'living',
#   'way',
#   'floorboards.',
#   'floor',
#   'matter?',
#   'matter?',
#   'matter?',
#   'matter,',
#   'matter?',
#   'matter,',
#   'bed?',
#   'fucking',
#   '.22,',
#   'fact',
#   'gun',
#   'trigger.',
#   'fuck',
#   'toughest',
#   'very',
#   'end',
#   'douchebaggery',
#   'pilot',
#   'bowed',
#   'sugar',
#   'other',
#   'most',
#   'way?',
#   'bed',
#   'covers,',
#   'one',
#   'morning,',
#   'couch.',
#   'kitchen',
#   'couch,',
#   'back',
#   'couch.',
#   'couch,',
#   'first',
#   'window.',
#   'next',
#   'sex.',
#   'most',
#   'fucking',
#   'last',
#   'kitchen.',
#   'TV.',
#   'shit–',
#   'nerd’s',
#   'cheerleader.',
#   'love',
#   'saxophone',
#   'penetration,',
#   'other',
#   'shit',
#   'hell',
#   'first',
#   'cops',
#   'wall.',
#   'other',
#   'wall.',
#   'most',
#   'races.',
#   'movie',
#   'guy',
#   'other',
#   'movie,',
#   'bed,',
#   'bed.',
#   'way',
#   'gym,',
#   'bed,',
#   'wall,',
#   'whole'],
#  'greater': ['Atlanta,'],
#  'Atlanta,': ['Georgia,'],
#  'Georgia,': ['area,'],
#  'area,': ['this'],
#  'this': ['oasis.',
#   'thing,',
#   'cattle',
#   'day',
#   'country.',
#   'year.',
#   'slavery-themed',
#   'summer.',
#   'crazy',
#   'guy’s',
#   'fucking',
#   'like',
#   'Monica',
#   'crazy?',
#   'Y2K–',
#   'shit',
#   'old',
#   'isn’t',
#   'shit’s',
#   'redneck',
#   'scared',
#   'is',
#   'spaceship',
#   'is',
#   'shit',
#   '800-pound',
#   'fucking',
#   'right,',
#   'dude',
#   'weird',
#   'right',
#   'is',
#   'around',
#   'thing’s',
#   'great?',
#   'great?”',
#   'for',
#   'for',
#   'bus',
#   'turbulence.',
#   'dude',
#   'fuselage',
#   'guy,',
#   'bus',
#   'is',
#   'is',
#   'guy',
#   'dude,',
#   'country.',
#   'day,',
#   'is',
#   'is',
#   'tall?',
#   'shirt?',
#   'kid',
#   'sawed-off',
#   'shit!',
#   'story',
#   'guy',
#   'kid,',
#   'frequency,',
#   'guy',
#   'guy.',
#   'is',
#   'guy’s',
#   'five-shot',
#   'point',
#   'was',
#   'is',
#   'shadowy',
#   'strobe',
#   'shit.',
#   'house.',
#   'is',
#   'is',
#   'one-dimensional,',
#   'little',
#   'is',
#   'mattress,'],
#  'oasis.': ['It’s'],
#  'nice': ['to', 'to', 'in'],
#  'here.': ['I',
#   'Wasn’t',
#   'Have',
#   'Mind',
#   'What,',
#   'I',
#   'Meanwhile,',
#   'I',
#   '“Fuckin’'],
#  'I': ['don’t',
#   'came',
#   'get',
#   'been',
#   'hate',
#   'decided',
#   'can',
#   'realized',
#   'saw',
#   'guess',
#   'have',
#   'would',
#   'didn’t',
#   'look',
#   'think',
#   'want',
#   'was',
#   'got',
#   'don’t',
#   'was',
#   'am.',
#   'don’t',
#   'don’t',
#   'feel',
#   'mean–',
#   'ever',
#   'didn’t',
#   'thought',
#   'swear',
#   'bet',
#   'think',
#   'feel',
#   'don’t',
#   'can’t',
#   'had',
#   'was',
#   'gotta',
#   'was',
#   'got',
#   'guess',
#   'have',
#   'don’t',
#   'mean,',
#   'don’t',
#   'put',
#   'lasted',
#   'was',
#   'was',
#   'don’t',
#   'understand,',
#   'don’t',
#   'might',
#   'might',
#   'have',
#   'nuts?',
#   'know',
#   'know',
#   'don’t',
#   'totally',
#   'was',
#   'would',
#   'never',
#   'tried',
#   'think',
#   'don’t',
#   'don’t',
#   'go',
#   'thought',
#   'was',
#   'don’t',
#   'don’t',
#   'always',
#   'learned',
#   'think',
#   'actually',
#   'had',
#   'didn’t',
#   'didn’t',
#   'just',
#   'don’t',
#   'already',
#   'got',
#   'actually–',
#   'had',
#   'felt',
#   'did.',
#   'think',
#   'haven’t',
#   'have',
#   'think',
#   'could',
#   'see',
#   'live',
#   'heard',
#   'was',
#   'have',
#   'know',
#   'am',
#   'said',
#   'ever',
#   'was',
#   'can',
#   'think',
#   'heard',
#   'was',
#   'heard',
#   'was',
#   'heard',
#   'lost',
#   'got',
#   'was',
#   'just',
#   'gonna',
#   'gonna',
#   'gonna',
#   'kind',
#   'act',
#   'go',
#   'don’t',
#   'did',
#   'just',
#   'didn’t',
#   'just',
#   'just',
#   'haven’t',
#   'was',
#   'don’t',
#   'say',
#   'actually',
#   'made',
#   'built',
#   'wouldn’t',
#   'wouldn’t,',
#   'would',
#   'got',
#   'believe',
#   'was',
#   'supposed',
#   'didn’t',
#   'don’t',
#   'don’t',
#   'knew',
#   'knew',
#   'was',
#   'couldn’t',
#   'was',
#   'got',
#   'hate',
#   'get',
#   'have',
#   'never',
#   'don’t',
#   'just',
#   'believe',
#   'just',
#   'don’t',
#   'have',
#   'don’t',
#   'just',
#   'had',
#   'am!',
#   'noticed:',
#   'don’t',
#   'am.',
#   'am,',
#   'was',
#   'didn’t',
#   'came',
#   'came',
#   'didn’t',
#   'don’t',
#   'didn’t',
#   'think,',
#   'was',
#   'moved',
#   'drive',
#   'think',
#   'have',
#   'don’t',
#   'think',
#   'have',
#   'did',
#   'just',
#   'actually',
#   'finally',
#   'saw',
#   'finally',
#   'was',
#   'was',
#   'always',
#   'got',
#   'end',
#   'know.',
#   'don’t',
#   'figure',
#   'ever',
#   'said',
#   'won’t',
#   'wouldn’t',
#   'would',
#   'have',
#   'don’t',
#   'want',
#   'want',
#   'last',
#   'got',
#   'did.',
#   'hang',
#   'just',
#   'felt',
#   'felt',
#   'was',
#   'didn’t',
#   'would',
#   'feel',
#   'got',
#   'don’t',
#   'get',
#   'still',
#   'just',
#   'do',
#   'get',
#   'should',
#   'should',
#   'think',
#   'already',
#   'want',
#   'do.',
#   'want',
#   'would',
#   'gotta',
#   'am',
#   'don’t',
#   'can',
#   'got',
#   'got',
#   'got',
#   'feel',
#   'might',
#   'feel',
#   'could',
#   'got',
#   'just',
#   'could',
#   'figured',
#   'figure,',
#   'don’t',
#   'have',
#   'want',
#   'actually',
#   'do,',
#   'live',
#   'don’t',
#   'love',
#   'told',
#   'want',
#   'know',
#   'was',
#   'was',
#   'gonna',
#   'get',
#   'got',
#   'never',
#   'needed',
#   'bought',
#   'saw',
#   'love',
#   'gotta',
#   'read',
#   'love',
#   'love,',
#   'loved',
#   'can’t',
#   'decide.”',
#   'left',
#   'think',
#   'still',
#   'just',
#   'hope',
#   'have',
#   'mentioned,',
#   'came',
#   'wanted',
#   'do.',
#   'gave',
#   'can’t',
#   'want.',
#   'say',
#   'wanted',
#   'wanted.',
#   'don’t',
#   'had',
#   'shot',
#   'was',
#   'got',
#   'get',
#   'thought',
#   'don’t',
#   'go',
#   'bring',
#   'pull',
#   'saw',
#   'felt',
#   'never',
#   'pulled',
#   'just',
#   'shot',
#   'got',
#   'will',
#   'get',
#   'get',
#   'got',
#   'understand',
#   'understand',
#   'maintain,',
#   'don’t',
#   'could',
#   'don’t',
#   'don’t',
#   'started',
#   'caught',
#   'don’t',
#   'stand',
#   'let',
#   'couldn’t',
#   'was',
#   'sleep?”',
#   'go,',
#   'always',
#   'will',
#   'want',
#   'was',
#   'sleep',
#   'want',
#   'need',
#   'felt',
#   'don’t.',
#   'don’t',
#   'understand',
#   'just',
#   'just',
#   'am',
#   'am',
#   'occasionally',
#   'don’t',
#   'don’t',
#   'just',
#   'want',
#   'want',
#   'don’t',
#   'remember',
#   'didn’t',
#   'was',
#   'was',
#   'didn’t',
#   'thought',
#   'was',
#   'just',
#   'want',
#   'don’t',
#   'want',
#   'swear',
#   'guess',
#   'didn’t',
#   'love',
#   'saw',
#   'ruined',
#   'can’t',
#   'can',
#   'had'],
#  'don’t': ['know',
#   'know',
#   'like',
#   'understand,',
#   'see',
#   'know,',
#   'know',
#   'promote',
#   'promote',
#   'give',
#   'have',
#   'know',
#   'even',
#   'want',
#   'know.”',
#   'fucking',
#   'give',
#   'get',
#   'clap,',
#   'read,',
#   'read.',
#   'understand.',
#   'understand',
#   'they',
#   'care.',
#   'like',
#   'have',
#   'go',
#   'know',
#   'think',
#   'give',
#   'give',
#   'like',
#   'like',
#   'believe',
#   'think',
#   'get',
#   'work!”',
#   'even',
#   'know,',
#   'know',
#   'know',
#   'know',
#   'have',
#   'want',
#   'understand',
#   'understand.',
#   'understand',
#   'understand.',
#   'know.',
#   'know',
#   'know,',
#   'live',
#   'open',
#   'know',
#   'try',
#   'know.',
#   'understand',
#   'come',
#   'care',
#   'give',
#   'care.',
#   'even',
#   'tell',
#   'tell',
#   'understand.',
#   'care,',
#   'mind',
#   'like',
#   'even',
#   'know.',
#   'you',
#   'I',
#   'think',
#   'put',
#   'walk'],
#  'know': ['why',
#   'that?',
#   'anybody',
#   'how',
#   'what',
#   'what',
#   'I’m',
#   'what',
#   'what',
#   'what',
#   'what',
#   'about',
#   'what?',
#   'what',
#   'what?',
#   'that',
#   'about',
#   'what',
#   'how',
#   'he’s',
#   'they',
#   'they',
#   'those',
#   'what',
#   'what',
#   'the',
#   'why',
#   'why?',
#   'if',
#   'what',
#   'why',
#   'that',
#   'or',
#   'who’s',
#   'what’s',
#   'how',
#   'if',
#   'what',
#   'what',
#   'that.'],
#  'why': ['I', 'a', 'does', 'that', 'I', 'it', 'it', 'I'],
#  'came': ['here',
#   'in,',
#   'back',
#   'walking',
#   'down',
#   'out',
#   'to',
#   'through',
#   'in',
#   'from',
#   'through'],
#  'June.': ['It’s'],
#  'Wasn’t': ['thinking.'],
#  'thinking.': ['Fucking'],
#  'Fucking': ['ridiculously',
#   'got',
#   'stupid-ass',
#   'sense',
#   'horrific.',
#   'sitting'],
#  'ridiculously': ['hot'],
#  'hot': ['out', 'water.'],
#  'out': ['there.',
#   'and',
#   'and',
#   'there:',
#   'there,',
#   'there',
#   'with',
#   'to',
#   'of',
#   'your',
#   'with',
#   'in',
#   'of',
#   'what',
#   'what',
#   'there',
#   'of',
#   'of',
#   'in',
#   'there,',
#   'bottomless',
#   'of',
#   'afterwards?',
#   'of',
#   'of',
#   'the',
#   'like',
#   'here',
#   'of',
#   'of',
#   'of',
#   'in',
#   'for',
#   'in',
#   'of',
#   'and',
#   'with',
#   'today.”',
#   'of',
#   'there',
#   'of',
#   'of',
#   'of',
#   'in',
#   'the',
#   'here',
#   'and',
#   'and',
#   'there',
#   'the',
#   'of',
#   'the',
#   'what',
#   'like',
#   'like',
#   'like',
#   'one',
#   'over',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'at',
#   'with',
#   'of',
#   'your',
#   'of',
#   'the',
#   'of',
#   'there',
#   'the',
#   'in',
#   'of',
#   'of',
#   'my',
#   'of'],
#  'there.': ['Just',
#   'They’re',
#   'I',
#   'Over.',
#   'Mwah,',
#   'You',
#   'Put',
#   'Never',
#   'Don’t',
#   'You',
#   '[snoring]'],
#  'Just': ['miserable,',
#   'walking',
#   'brainwash',
#   'let',
#   'let',
#   'let',
#   'light',
#   'sitting',
#   'show',
#   'bring',
#   'sit',
#   'that',
#   'sitting',
#   'kept',
#   'grab',
#   'keep',
#   'everything’s'],
#  'miserable,': ['horrible.'],
#  'horrible.': ['That'],
#  'That': ['kind',
#   'is',
#   'fucks',
#   'fucking',
#   'guy',
#   'older',
#   'doesn’t',
#   'is',
#   'fuckin’',
#   'Duck',
#   'all',
#   'made',
#   'moment',
#   'rock',
#   'was',
#   'was',
#   'little',
#   'door',
#   'is',
#   'dude',
#   'stupid',
#   'whole',
#   'whole'],
#  'kind': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'of': ['heat,',
#   'those',
#   'you',
#   'you!',
#   'a',
#   'a',
#   'a',
#   'the',
#   'power.',
#   'children.',
#   'chalkboard.',
#   'that',
#   'humor',
#   'it,',
#   'a',
#   'that.',
#   'signs',
#   'those',
#   'shit,',
#   'these',
#   'old',
#   'her,',
#   'themes',
#   'the',
#   'these',
#   'a',
#   'Instagram!”',
#   'this',
#   'the',
#   'the',
#   'here!',
#   'the',
#   'mice',
#   'kids,',
#   'the',
#   'the',
#   'this.',
#   'this',
#   'them',
#   'a',
#   'my',
#   'the',
#   'a',
#   'that',
#   'nowhere,',
#   'pages?”',
#   'pedophilia',
#   'it',
#   'mulching',
#   'every',
#   'every',
#   'how',
#   'Scientologists',
#   'Scientology,',
#   'years',
#   'it',
#   'him',
#   'it.',
#   'believing',
#   'shit',
#   'shrimp',
#   'that',
#   'your',
#   'this',
#   'go,',
#   'times',
#   'the',
#   'it',
#   'them,',
#   'a',
#   'nowhere',
#   'it.',
#   'it.',
#   'the',
#   'your',
#   'choice,',
#   'shit!”',
#   'your',
#   'your',
#   'Brussels',
#   'hard',
#   'that',
#   'entitlement.”',
#   'flying',
#   'it.',
#   'a',
#   'that',
#   'people',
#   'a',
#   'nowhere,',
#   'turbulence]',
#   'a',
#   'a',
#   'a',
#   'the',
#   'your',
#   'that',
#   'them,',
#   'that',
#   'my',
#   'your',
#   'shit',
#   'myself,',
#   'the',
#   'that',
#   'those',
#   'those',
#   'him!',
#   'tomfoolery',
#   'the',
#   'the',
#   'a',
#   'natural',
#   'my',
#   'those',
#   'cold',
#   'lets',
#   'doing,',
#   'my',
#   'you',
#   'Fritos,',
#   'those',
#   'the',
#   'that',
#   'what’s',
#   'his',
#   'a',
#   'this',
#   'line',
#   'Pop',
#   'planning.',
#   'love,',
#   'annoyed',
#   'a',
#   'the',
#   'beaches',
#   'beaches.',
#   'the',
#   'pills,',
#   'his',
#   'beaches,',
#   'the',
#   'an',
#   'jumping',
#   'a',
#   'pain!',
#   'your',
#   'your',
#   'the',
#   'the',
#   'shots.”',
#   'your',
#   'argument.',
#   'these',
#   'my',
#   'argument,',
#   'a',
#   'a',
#   'five',
#   'your',
#   'the',
#   'your',
#   'the',
#   'those',
#   'couple',
#   'the',
#   'her.',
#   'the',
#   'come',
#   'sports,',
#   'her',
#   'that',
#   'that',
#   'a',
#   'scare',
#   'me',
#   'Rape,',
#   'like',
#   'up-against-the-wall',
#   'nowhere,',
#   'the',
#   'damage.',
#   'me!',
#   'it’s',
#   'time.'],
#  'heat,': ['you'],
#  'understand': ['the',
#   'that,',
#   'why',
#   'anything',
#   'cold',
#   'being',
#   'that?',
#   'what',
#   'that',
#   'that.',
#   'if',
#   'it.'],
#  'racism': ['down', 'I'],
#  'down': ['here,',
#   'this',
#   'to',
#   'the',
#   'to',
#   'here.',
#   'the',
#   'the',
#   'to,',
#   'to',
#   'to',
#   'into',
#   'to',
#   'the',
#   'on',
#   'on',
#   'to',
#   'the',
#   'in',
#   'South.',
#   'to',
#   'the',
#   'to',
#   'there.',
#   'that',
#   'the',
#   'from',
#   'but',
#   'on'],
#  'here,': ['ya',
#   'what',
#   'I',
#   'and',
#   'waiting',
#   'I’m',
#   'you',
#   'someone',
#   'Officer.'],
#  'ya': ['know?', 'know.', 'know.', 'know.', 'know.', 'know.'],
#  'know?': ['I',
#   'It’s',
#   'You',
#   'I',
#   'They’re',
#   'What',
#   '“~',
#   'Just',
#   'So',
#   '“When',
#   'I',
#   'You',
#   'I',
#   'Don’t',
#   'I',
#   'Like,',
#   'They',
#   'We–',
#   'There’s',
#   'Just',
#   '[cackles]',
#   'Jesus',
#   'You',
#   '“You',
#   'He',
#   'That’s',
#   'Think',
#   'It’s',
#   'I'],
#  'get': ['it.',
#   'along',
#   'in',
#   'its',
#   'for',
#   'too',
#   'in',
#   'back',
#   'it.',
#   'that',
#   'married,',
#   'them',
#   'the',
#   'in',
#   'old',
#   'in',
#   'the',
#   'on',
#   'a',
#   'judged,',
#   'judged',
#   'a',
#   'my',
#   'older.',
#   'any',
#   'the',
#   'yourself',
#   'up!”',
#   'there.',
#   'rid',
#   'the',
#   'weird.',
#   'some',
#   'chocolate',
#   'it,',
#   'to',
#   'to',
#   'him',
#   'like',
#   'in',
#   'to',
#   'to',
#   'my',
#   'in!”',
#   'a',
#   'one,',
#   'a',
#   'down',
#   'louder,',
#   'quieter.',
#   'crazy.”',
#   'off',
#   'it.',
#   'it',
#   'along',
#   'me',
#   'yourself',
#   'you',
#   'me',
#   'nearly'],
#  'it.': ['How',
#   'Nobody',
#   '–',
#   'We',
#   'Yeah.',
#   'What',
#   'Did',
#   'Other',
#   'Other',
#   'If',
#   'I’d',
#   'They',
#   '–',
#   'I',
#   'Like',
#   '“I’ll',
#   'I',
#   '“And',
#   'Dead,',
#   'And',
#   'The',
#   'He',
#   'It’s',
#   'They’re',
#   'Maybe',
#   'You',
#   'Yeah.',
#   'So',
#   'Didn’t',
#   'I',
#   'It’s',
#   'They',
#   'I',
#   'Why',
#   'He'],
#  'would': ['you',
#   'be–',
#   'implement',
#   'never',
#   'have',
#   'have',
#   'troubleshoot.',
#   'you',
#   'fuck',
#   'send…',
#   'come',
#   'love',
#   'love',
#   'that',
#   'love',
#   'be',
#   'be',
#   'leave.',
#   'leave.'],
#  'along': ['with', 'for', 'with'],
#  'with': ['anybody?',
#   'my',
#   'that',
#   'your',
#   'you.',
#   'them,',
#   'them,',
#   'them,',
#   '’em,',
#   '’em,',
#   'your',
#   'your',
#   'these',
#   'this',
#   'your',
#   'his',
#   'a',
#   'your',
#   'myself.',
#   'myself.',
#   'this?',
#   'that',
#   'my',
#   'your',
#   'the',
#   'a',
#   'this',
#   'a',
#   'those',
#   'his',
#   'the',
#   'people',
#   'the',
#   'a',
#   'the',
#   'an',
#   'me!”',
#   'that.',
#   'you,',
#   'the',
#   'the',
#   'him,',
#   'your',
#   'your',
#   'your',
#   'a',
#   'this',
#   'a',
#   'a',
#   'my',
#   'the',
#   'the',
#   'my',
#   'little',
#   'her',
#   'your',
#   'every'],
#  'anybody?': ['“Look'],
#  '“Look': ['at'],
#  'at': ['’em',
#   'least',
#   'people',
#   'the',
#   'no',
#   'Walt',
#   'him,',
#   'in',
#   'the',
#   'Denny’s,',
#   'math,',
#   'it,',
#   'the',
#   'a',
#   'the',
#   'you.',
#   'the',
#   'them…',
#   'the',
#   'the',
#   'that,',
#   'your',
#   'the',
#   'this',
#   'me',
#   'a',
#   'the',
#   '6:30',
#   'night,',
#   'him,',
#   'you',
#   'the',
#   'me,',
#   'you.',
#   'you.'],
#  '’em': ['just', 'like', 'down,', 'off.'],
#  'just': ['over',
#   'in',
#   'had',
#   'won’t',
#   'say,',
#   'sits',
#   'fucking',
#   'to',
#   'like,',
#   'be,',
#   'don’t',
#   'don’t',
#   'keep',
#   'stuck',
#   'keeps',
#   'coming',
#   'be',
#   'in',
#   'fuckin’',
#   'this',
#   'didn’t.',
#   'sort',
#   'about',
#   'start',
#   'the',
#   'hit',
#   'like,',
#   'floating,',
#   'had',
#   'let',
#   'sliding',
#   'sliding.',
#   'goes',
#   'keeps',
#   'stops.',
#   'let',
#   'let',
#   'floated',
#   'layin’',
#   'dead?”',
#   'settles',
#   'keep',
#   'dead.',
#   'like',
#   'don’t',
#   'don’t',
#   'wish',
#   'be',
#   'as',
#   'tried',
#   'so',
#   'be',
#   'be',
#   'think',
#   'made',
#   'be',
#   'being',
#   'like,',
#   'be',
#   'accidentally',
#   'must',
#   'leave',
#   'weird.',
#   'couldn’t',
#   'sitting',
#   'be',
#   'came',
#   'thinking',
#   'turned',
#   'turned',
#   'feel',
#   'gonna',
#   'to',
#   'turned',
#   'turned',
#   'show',
#   'there,',
#   'thought',
#   'talking',
#   'doing,',
#   'look',
#   'look',
#   'land',
#   'like,',
#   'gonna',
#   'not',
#   'gonna',
#   'gonna',
#   'gonna',
#   'like',
#   'jumped',
#   'taking',
#   'feel',
#   'get',
#   'sit',
#   'heard',
#   'say,',
#   'say',
#   'listening.',
#   'hears…',
#   'fucking',
#   'like…',
#   'see',
#   'won’t',
#   'standing',
#   'got',
#   'sleep',
#   'sleep',
#   'sleep',
#   'gonna',
#   'sit',
#   'start',
#   'saying,',
#   'want',
#   'do',
#   'don’t',
#   'so',
#   'so',
#   'kept',
#   'like,',
#   'kinda',
#   'got',
#   'lay'],
#  'over': ['there,',
#   'here,',
#   'the',
#   'the',
#   'there,',
#   'with',
#   'here?’',
#   'here?',
#   'the',
#   'the',
#   '27',
#   'the',
#   'here.',
#   'here',
#   'here?',
#   'television.',
#   'here.'],
#  'there,': ['drinkin’',
#   'bitch,',
#   'and',
#   'they’re,',
#   'J-star,',
#   'right?',
#   '“Mom,',
#   'like…!',
#   'flying',
#   'right?',
#   'loaded',
#   'same',
#   'I',
#   'use'],
#  'drinkin’': ['a'],
#  'cold': ['drink!', 'out', 'till'],
#  'drink!': ['Lemonade'],
#  'Lemonade': ['was'],
#  'was': ['made',
#   'doing',
#   'up',
#   'weird,',
#   'like',
#   'offensive',
#   'at',
#   'the',
#   'wide',
#   'born',
#   'fine!',
#   'gonna',
#   'a',
#   'considered',
#   'like,',
#   '24',
#   'born.',
#   'open-minded.',
#   'a',
#   'music!',
#   'music.”',
#   'wrong,',
#   'in',
#   'gonna',
#   'a',
#   'I’m',
#   'I',
#   'like,',
#   'alive,',
#   'working',
#   'like,',
#   'an',
#   'four',
#   'still',
#   'a',
#   'the',
#   'just',
#   'just',
#   'basically',
#   'doing',
#   'you',
#   'brought',
#   'gonna',
#   'like,',
#   'like,',
#   'basically,',
#   'standing',
#   'it,',
#   'over.',
#   'over.',
#   'just',
#   'this',
#   'hugged',
#   'your',
#   'like,',
#   'little,',
#   'it!',
#   'like',
#   'horrific.',
#   'like,',
#   'afraid',
#   'gonna',
#   'like,',
#   'your',
#   'afraid.',
#   'gonna',
#   'a',
#   'my',
#   'his',
#   'his',
#   'starting',
#   'just',
#   'eight',
#   'scratching',
#   'just',
#   'gonna',
#   'weird,',
#   '61',
#   'in',
#   'wrong',
#   'falling',
#   'trying',
#   'just',
#   'landscaping',
#   'gonna',
#   'like,',
#   'just',
#   'like,',
#   'one',
#   'doing.',
#   'just',
#   'like…',
#   'doing.',
#   'testing',
#   'just',
#   'her',
#   'her',
#   'lift',
#   'it.',
#   'off'],
#  'made': ['for',
#   'sense',
#   'total',
#   'sense.',
#   'me,',
#   'a',
#   'of,',
#   'an',
#   'of?',
#   'this'],
#  'for': ['the',
#   'me',
#   'me',
#   'the',
#   'three',
#   'some',
#   'watching',
#   'you',
#   'Jesus',
#   'Jesus.',
#   'an',
#   'a',
#   'someone',
#   'the',
#   'the',
#   'my',
#   'fucking',
#   'a',
#   'a',
#   'me',
#   'you',
#   'me.',
#   'himself.',
#   'that',
#   'you',
#   'a',
#   'me',
#   '30',
#   '30',
#   'him.',
#   'home',
#   'the',
#   'the',
#   'bear.',
#   'my',
#   'longer'],
#  'white': ['man!”', 'guy,', 'guy.', 'players.”', 'and', 'silk'],
#  'man!”': ['So…'],
#  'So…': ['What', 'Yeah.', 'Yeah…'],
#  'What': ['the',
#   'about',
#   'do',
#   'kind',
#   'do',
#   'pissed',
#   'did',
#   'did',
#   'a',
#   'a',
#   'did',
#   'happened',
#   'am',
#   'is',
#   'is',
#   'does',
#   'the',
#   'the',
#   'the',
#   'I',
#   'do',
#   'are',
#   'are',
#   'is',
#   'can',
#   'does'],
#  'hell': ['have', 'they', 'she', 'you', 'are', 'he’s', 'of', 'that', 'with'],
#  'have': ['I',
#   'to',
#   'been',
#   'the',
#   'the',
#   'everybody.',
#   'fuckin’',
#   'some',
#   'all',
#   'the',
#   'some',
#   'those',
#   'an',
#   'a',
#   'been',
#   'sex',
#   'noticed.',
#   'sex',
#   'a',
#   'time',
#   'three,',
#   'kids,',
#   'like',
#   'your',
#   'no',
#   'that',
#   'put',
#   'sometimes,',
#   'ever',
#   'eggs,',
#   'me',
#   'ate',
#   'a',
#   'never',
#   'answers.',
#   'this',
#   'empathy.',
#   'to',
#   'to',
#   'time',
#   'a',
#   'any',
#   'a',
#   'been',
#   'a',
#   'to',
#   'to',
#   'a',
#   'a',
#   'kids.',
#   'kids',
#   'a',
#   'a',
#   'to',
#   'to',
#   'to',
#   'yelled',
#   'no',
#   'been',
#   'been',
#   'gone',
#   'the',
#   'some',
#   'you',
#   'time',
#   'time.',
#   'it',
#   'to',
#   'the',
#   'to',
#   'a',
#   'no'],
#  'been': ['doing',
#   'bitching',
#   'carpet-bombed',
#   'going',
#   'able',
#   'so',
#   'something',
#   'through,',
#   'out',
#   'wearing',
#   'on',
#   'trying',
#   'going?”',
#   'rough',
#   'sleeping'],
#  'doing': ['with',
#   'that',
#   'a',
#   'when',
#   'a',
#   'it,',
#   'that',
#   'key',
#   'that,',
#   'it',
#   'it',
#   'anything?'],
#  'my': ['life?',
#   'best,',
#   'life.',
#   'property!',
#   'stylus',
#   'life.',
#   'shit',
#   'toys?',
#   'religion.',
#   'religion',
#   'wife.',
#   'bike.',
#   'life.”',
#   'story',
#   'story,',
#   'parents',
#   'last',
#   'religion.',
#   'mind,',
#   'religion',
#   'religion,',
#   'religion,',
#   'friends',
#   'family',
#   'head',
#   'entire',
#   'arms.',
#   'stories.”',
#   'mom',
#   'head.',
#   'regret',
#   'wife’s',
#   'mother',
#   'dad',
#   'dad',
#   'dad',
#   'dad,',
#   'hypothetical',
#   'hypothetical',
#   'kid,',
#   'life',
#   'age,',
#   'friends',
#   'friends',
#   'friends.',
#   'first',
#   'latest',
#   'wife',
#   'license,',
#   'God.',
#   'God.',
#   'God.',
#   'world.',
#   'God,',
#   'mind,',
#   'house',
#   'wife',
#   'relationship.',
#   'ground',
#   'life.',
#   'way.',
#   'hand,',
#   'core',
#   'fingerprints',
#   'God,',
#   'God!',
#   'wife.',
#   'back.'],
#  'life?': ['Trying'],
#  'Trying': ['to', 'to', 'to'],
#  'shape,': ['man.'],
#  'man.': ['But', '“Ah,', 'Doesn’t', 'I', '“Take'],
#  'But': ['I',
#   'other',
#   'he',
#   'I’m',
#   'that',
#   'the',
#   'just',
#   'turn',
#   'how',
#   'your',
#   'if',
#   'you!',
#   'here’s',
#   'witnesses',
#   'that',
#   'I’ve',
#   'I',
#   'they'],
#  'hate': ['going', 'how', 'when'],
#  'gym,': ['so', 'we'],
#  'so': ['I',
#   'focused',
#   'full',
#   'I',
#   'I’m',
#   'we’ll',
#   'you',
#   'dumb',
#   'I’ve',
#   'this',
#   'they',
#   'you’re',
#   'goddamn',
#   'fucking',
#   'fucking',
#   'awful',
#   'she',
#   'you',
#   'the',
#   'God',
#   'I',
#   'goddamn',
#   'what',
#   'stretch',
#   'mad',
#   'that’s',
#   'fucking',
#   'psyched',
#   'much.'],
#  'decided': ['I’d'],
#  'I’d': ['go',
#   'give',
#   'like',
#   'think,',
#   'let',
#   'just',
#   'love',
#   'love',
#   'love',
#   'probably',
#   'have'],
#  'go': ['veggie',
#   'fuck',
#   'fuck',
#   'back',
#   'back',
#   'to',
#   'back',
#   'home',
#   'home',
#   'to',
#   'after',
#   'after',
#   'all',
#   'anymore.”',
#   'of',
#   'of',
#   'of',
#   'of',
#   'up',
#   'off',
#   'get',
#   'too',
#   'to',
#   'down',
#   'out',
#   'easier',
#   'into',
#   'in',
#   'out',
#   'out',
#   'out',
#   'from',
#   'down',
#   'down',
#   'to',
#   'back',
#   'to'],
#  'veggie': ['twice'],
#  'twice': ['a'],
#  'week.': ['It’s'],
#  'brutal.': ['I'],
#  'can': ['only',
#   'hang',
#   'have',
#   'make',
#   'live',
#   'live',
#   'hang',
#   'have',
#   'pass',
#   'be',
#   'believe',
#   'go',
#   'I',
#   'hide',
#   'relate',
#   'make',
#   'literally',
#   'hug',
#   'hug',
#   'do',
#   'do',
#   'drag',
#   'take',
#   'we',
#   'just',
#   'just',
#   'sleep.',
#   'just',
#   'do?',
#   'she',
#   'do',
#   'literally'],
#  'only': ['make', 'does', 'hugged', 'the', 'did'],
#  'make': ['it',
#   'that',
#   'a',
#   'it',
#   'you',
#   'sense',
#   'a',
#   'any',
#   'whores,',
#   'it',
#   'sense.',
#   'it.',
#   'sense,',
#   'something',
#   'half…',
#   'you',
#   'us',
#   'him',
#   'a',
#   'his',
#   'the',
#   'fun',
#   'herself',
#   'her',
#   'it',
#   'some'],
#  'it': ['till',
#   'up,',
#   'feel?”',
#   'doesn’t',
#   'down.',
#   'on',
#   'was',
#   'was',
#   'went',
#   'once!',
#   'on',
#   'was',
#   'on',
#   'off',
#   'was',
#   'passes',
#   'passing',
#   'on!”',
#   'went',
#   'come',
#   'a',
#   'like',
#   '~',
#   'again,',
#   '~',
#   'again',
#   'stands',
#   'was',
#   'in',
#   'just',
#   'is?',
#   'like',
#   'didn’t',
#   'forever.',
#   'on',
#   'to',
#   'just',
#   'going,',
#   'going',
#   'has',
#   'stops,',
#   'comes',
#   'down.',
#   'down,',
#   'used',
#   'anymore?',
#   'didn’t',
#   'was',
#   'is.',
#   'on',
#   'was',
#   'was',
#   'was.',
#   'was',
#   'go',
#   'out',
#   'from',
#   'down',
#   'down',
#   'made',
#   'to',
#   'was',
#   'was',
#   'up',
#   'in!',
#   'in,',
#   'again?',
#   'down',
#   'is?',
#   'doesn’t',
#   'is?',
#   'still',
#   'by',
#   'all',
#   'up',
#   'was',
#   'looked',
#   'fucking',
#   'between',
#   'down',
#   'out',
#   'back',
#   'at',
#   'at',
#   'there.',
#   'works.',
#   'that',
#   'go.',
#   'out.',
#   'been',
#   'right',
#   'right',
#   'was',
#   'was',
#   'nice',
#   'standing',
#   'with',
#   'in',
#   'up'],
#  'till': ['about', 'you', 'they', 'you’re'],
#  'about': ['5:00.',
#   'myself,',
#   'the',
#   'that?',
#   'it.',
#   'it.”',
#   'Instagram,',
#   'Facebook?”',
#   'Facebook!',
#   'life.',
#   'the',
#   'the',
#   'every',
#   'this',
#   'animals?',
#   'animals,',
#   'you',
#   'that',
#   'me,',
#   'going',
#   'that.',
#   'marriage…',
#   'adopting.',
#   'you,',
#   'them!',
#   'him,',
#   'women.'],
#  '5:00.': ['Five'],
#  'Five': ['o’clock,', 'days', 'fucking', 'days'],
#  'o’clock,': ['that’s'],
#  'that’s': ['what',
#   'what',
#   'what',
#   'like',
#   'it,',
#   'all',
#   'it.',
#   'essentially',
#   'it.',
#   'true,',
#   'the',
#   'risky.',
#   'simple.',
#   'what’s',
#   'not',
#   'my',
#   'a',
#   'my',
#   'Orange',
#   'all',
#   'what’s',
#   'gone.',
#   'what'],
#  'what': ['I',
#   'I’m',
#   'you',
#   'kind',
#   'we’re',
#   'do',
#   'are',
#   'these',
#   'the',
#   'about',
#   'a',
#   'his',
#   'happened.',
#   'these',
#   'these',
#   'he',
#   'did',
#   'you',
#   'kills',
#   'we',
#   'they',
#   'happened?',
#   'happens',
#   'happened.',
#   'they',
#   'it',
#   'am',
#   'I',
#   'their',
#   'they',
#   'do',
#   'he’s',
#   'kills',
#   'absolutely',
#   'I',
#   'it',
#   'it',
#   'happens',
#   'do',
#   'is',
#   'I’m',
#   'you',
#   'I',
#   'I',
#   'I',
#   'other',
#   'are',
#   'the',
#   'was',
#   'I',
#   'he',
#   'you',
#   'happened?',
#   'the–',
#   'kills',
#   'are',
#   'you',
#   'she',
#   'she',
#   'she’s'],
#  'realized': ['about', 'how', 'how'],
#  'myself,': ['you', 'and'],
#  'that?': ['Something',
#   'What',
#   'You',
#   'No,',
#   'See,',
#   'What',
#   'Or',
#   'So',
#   'Walk'],
#  'Something': ['has', 'about'],
#  'has': ['to', 'the', 'nothing', 'your', 'changed', 'ever', 'a', 'the'],
#  'die': ['every', 'of'],
#  'every': ['day',
#   'word',
#   'album,',
#   'fuckin’',
#   'week,',
#   'religion.',
#   'religion',
#   'commandment',
#   'three,',
#   'time.',
#   'day.',
#   'once',
#   'pathetic',
#   'woman'],
#  'day': ['in', 'and', 'for', 'when', 'with'],
#  'order': ['for', 'for'],
#  'me': ['to',
#   'to',
#   'finish!',
#   'someone',
#   'off',
#   'tell',
#   'by.',
#   'by.',
#   'too?',
#   'one',
#   'Christmas',
#   'and',
#   'do',
#   'freedom',
#   'suck',
#   'up',
#   'out',
#   'to',
#   'finish',
#   'when',
#   'finish',
#   'handle',
#   'handle',
#   'know.',
#   'to',
#   'the',
#   'too,',
#   'too.',
#   'to',
#   'up',
#   'up',
#   'to',
#   'out,',
#   'ask',
#   'ask',
#   'just…”',
#   'like,',
#   'you',
#   'out.',
#   'where',
#   'where',
#   'is',
#   'once,',
#   'out.',
#   'down',
#   'up,',
#   'down.',
#   'breathe,',
#   'a',
#   'know',
#   'to'],
#  'live.': ['Something’s'],
#  'Something’s': ['got'],
#  'got': ['to',
#   'to',
#   'to',
#   'upset',
#   'drafted.',
#   'to',
#   'to',
#   'blinders',
#   'in',
#   'in',
#   'to',
#   'in',
#   'in',
#   'in',
#   'a',
#   'to',
#   'a',
#   'it.',
#   'here,',
#   'sick',
#   'fucked',
#   'a',
#   'the',
#   'older,',
#   'the',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'out',
#   'to',
#   'married.',
#   'married,',
#   'a',
#   'a',
#   'custom',
#   'IKEA',
#   'backup.',
#   'this',
#   'to',
#   'you',
#   'into',
#   'to',
#   'to',
#   'your',
#   'this',
#   'that',
#   'the',
#   'your',
#   'to',
#   'it,',
#   'to',
#   'so',
#   'half',
#   'to',
#   'to.',
#   'a',
#   'to',
#   'to',
#   'a',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'its': ['beak', 'feathers', 'jaw,'],
#  'beak': ['chopped'],
#  'chopped': ['off,'],
#  'off,': ['its', 'you'],
#  'feathers': ['yanked,'],
#  'yanked,': ['uppercut'],
#  'uppercut': ['to'],
#  'jaw,': ['just'],
#  'survive.': ['I’m'],
#  'I’m': ['trying!',
#   'gonna',
#   'glad',
#   'actually',
#   'not',
#   'not',
#   'gonna',
#   'telling',
#   'telling',
#   '46',
#   'like,',
#   'like',
#   'a',
#   'hearing',
#   'not',
#   'not',
#   'right.',
#   'a',
#   'telling',
#   'not',
#   'lazy.',
#   'not',
#   'paraphrasing,',
#   'paraphrasing.',
#   'in',
#   'not',
#   'like,',
#   'gonna',
#   'gonna',
#   'still',
#   'already',
#   'already',
#   'like,',
#   'getting',
#   'developing',
#   'flying',
#   'on',
#   'not',
#   'praying',
#   'not',
#   'being',
#   'in',
#   'in',
#   'gonna',
#   'sending',
#   'letting',
#   'gonna',
#   'very',
#   'married,',
#   '46',
#   'just',
#   'gonna',
#   'gonna',
#   'actually',
#   'thinking',
#   'not',
#   'just',
#   'gonna',
#   'getting',
#   'too',
#   'all',
#   'out”',
#   'still',
#   'just',
#   'just',
#   'not',
#   'just',
#   'taking',
#   'bullshitting,',
#   'not.',
#   'serious.',
#   '100%',
#   'seeing',
#   'seeing',
#   'looking',
#   'jumping',
#   'thinking',
#   'gonna',
#   'down',
#   'mowing',
#   'like,',
#   'coming',
#   'coming',
#   'coming',
#   'trying',
#   'not',
#   'keeping',
#   'not',
#   'supposed',
#   'like,',
#   'bigger',
#   'like,',
#   'gonna',
#   'not',
#   'just',
#   'learning',
#   'having',
#   'talking',
#   'like,',
#   'like,',
#   'not',
#   'out'],
#  'trying!': ['Couscous'],
#  'Couscous': ['and'],
#  'all': ['that',
#   'this',
#   'these',
#   'right?',
#   'kinds',
#   'of',
#   'of',
#   'right?',
#   'you',
#   'pissed',
#   'you',
#   'over',
#   'through',
#   'right,',
#   'comes',
#   'right?',
#   'those',
#   'of',
#   'empty,',
#   'dead.',
#   'right?',
#   'the',
#   'makes',
#   'of',
#   'the',
#   'of',
#   'night,',
#   'my',
#   'these',
#   'of',
#   'car',
#   'the',
#   'six',
#   'great',
#   'of',
#   'my',
#   'right?',
#   'he',
#   'the',
#   'got',
#   'had',
#   'right,',
#   'their',
#   'I',
#   'day,',
#   'night,',
#   'right?',
#   'right?',
#   'right?',
#   'right?',
#   'over',
#   'right',
#   'right.',
#   'right.',
#   'of',
#   'over',
#   'went',
#   'I',
#   'I',
#   'you',
#   'you',
#   'right,',
#   'I',
#   'you',
#   'the',
#   'right,',
#   'right!”',
#   'around',
#   'she’s',
#   'the'],
#  'that': ['shit.',
#   'shit.',
#   'as',
#   'it’s',
#   'shit.',
#   'joke.',
#   'joke?',
#   'joke,',
#   'get',
#   'fucked',
#   'guy?',
#   'got',
#   'makes',
#   'dude',
#   'shit.',
#   'shit',
#   'Clippers',
#   'wasn’t',
#   'bad.',
#   'whole',
#   'tape–',
#   'finished',
#   'savage',
#   'is',
#   'old',
#   'was',
#   'was',
#   'you',
#   'MMA.',
#   'shit.',
#   'I’m',
#   'Duck',
#   'homophobic',
#   'he',
#   'homophobic',
#   'all',
#   'shit?',
#   'he',
#   'shit',
#   'same',
#   'call.',
#   'religious',
#   'I',
#   'sock.',
#   'is',
#   'a',
#   'walked',
#   'make',
#   'shit',
#   'sound',
#   'made',
#   'stuff',
#   'person?',
#   'douche?',
#   'creepy',
#   'rock,',
#   'I’m',
#   'somebody’s',
#   'doesn’t',
#   'they',
#   'there,',
#   'make',
#   'is',
#   'dude',
#   'little',
#   'shit,',
#   'knows',
#   'nobody',
#   'noise',
#   'help',
#   'carburetor',
#   'one.',
#   'one.',
#   'that',
#   'fucking',
#   'guy.',
#   'shit,',
#   'you’re',
#   'shit.',
#   'hug,',
#   'stuff?”',
#   'was',
#   'my',
#   'your',
#   'worked,',
#   'didn’t',
#   'was',
#   'was,',
#   'was',
#   'he',
#   'was',
#   'I',
#   'shit',
#   'at',
#   'did',
#   'one',
#   'again,',
#   'they',
#   'I',
#   'works',
#   'be',
#   'made',
#   'kid',
#   'hell,',
#   'shit!',
#   'shit.',
#   'every',
#   'shit.',
#   'shit,',
#   'Full',
#   'way.',
#   'city,',
#   'water',
#   'came',
#   'she',
#   'shit,',
#   'for?',
#   'mean?”',
#   'old',
#   'point,',
#   'guy',
#   'Nana',
#   'helicopter',
#   'would',
#   'sounds',
#   'didn’t',
#   'dream.',
#   'person.',
#   'the',
#   'what',
#   'thing',
#   'intruder',
#   'thing',
#   'has',
#   'hall',
#   'little',
#   'gun.',
#   'fucker',
#   'it’s',
#   'a',
#   'if',
#   'might',
#   'henpecked',
#   'good,',
#   'there’s',
#   'will',
#   'shit.',
#   'is,',
#   'situation?',
#   'UFC',
#   'threat.',
#   'about',
#   'enough,',
#   'shit.',
#   'taboo',
#   'is.',
#   'was',
#   'other'],
# ...
#   'like,',
#   'got',
#   'just'],
#  'talking.': ['“Take'],
#  '“Take': ['a', 'me', 'me'],
#  'Jesus.': ['Are'],
#  'Are': ['they', 'you'],
#  'here?”': ['He'],
#  'nerve': ['to'],
#  'eyes.': ['“You'],
#  '“You': ['want',
#   'can',
#   'can',
#   'evil',
#   'think',
#   'were',
#   'ever',
#   'can',
#   'can',
#   'don’t'],
#  'popsicles?': ['Jesus'],
#  'wants': ['you', 'you'],
#  'popsicles.': ['He'],
#  'popsicles.”': ['His'],
#  'His': ['fucking', 'dad’s'],
#  'blue': ['carpet.'],
#  'carpet.': ['Yeah,'],
#  'Yeah,': ['everybody’s',
#   'Paula',
#   'she',
#   'they’re',
#   'it',
#   'that',
#   'I',
#   'I',
#   'so',
#   'now',
#   'shore',
#   'and',
#   'so',
#   'I’m',
#   'five',
#   'they',
#   'she',
#   'you’re',
#   'I',
#   'you',
#   'rub',
#   'they',
#   'I',
#   'you’re',
#   'it’s'],
#  'everybody’s': ['getting', 'doing', 'like,'],
#  'trouble': ['’cause', 'this', 'later'],
#  '’cause': ['of',
#   'she',
#   'I',
#   'all',
#   'God',
#   'I',
#   'we',
#   'I’m',
#   'my',
#   'I',
#   'I',
#   'all',
#   'it’s'],
#  'Look': ['at', 'at'],
#  'amount': ['of'],
#  'old': ['people',
#   'imagination',
#   'redneck',
#   'record',
#   'and',
#   'comic',
#   'man.',
#   'guy,',
#   'man',
#   'guy',
#   'advertising'],
#  'Old': ['people'],
#  'older': ['woman'],
#  'makes': ['the', 'a', 'sense,', 'sense.', 'them'],
#  'cookies': ['on'],
#  'Food': ['Network,'],
#  'Network,': ['right?'],
#  'Paula': ['Deen.'],
#  'Deen.': ['She'],
#  'she': ['had',
#   'did.',
#   'got',
#   'goes,',
#   'basically',
#   'did,',
#   'said',
#   'didn’t',
#   'got',
#   'was',
#   'gonna',
#   'gonna',
#   'does',
#   'says',
#   'chokes',
#   'does',
#   'can’t',
#   'can',
#   'do',
#   'comes',
#   'was',
#   'just',
#   'kept',
#   'was',
#   'was',
#   'did',
#   'bounces'],
#  'slavery-themed': ['wedding'],
#  'wedding': ['or'],
#  'did.': ['In', 'If', 'Look,', 'Very'],
#  'In': ['defense', 'the'],
#  'defense': ['of'],
#  'her,': ['you', '“How'],
#  'original': ['wedding.'],
#  'wedding.': ['There’s'],
#  'lot': ['of', 'of', 'of', 'of', 'in', 'over', 'of'],
#  'themes': ['left,'],
#  'left,': ['you'],
#  'use': ['the', 'these', 'these'],
#  'imagination': ['if'],
#  'blow': ['people'],
#  'away': ['with', 'from', 'from', 'from', 'on'],
#  'creativity,': ['right?'],
#  'actually': ['gonna',
#   'walked',
#   'resent',
#   'asked',
#   'thinking',
#   'want',
#   'want',
#   'guys',
#   'listen',
#   'been'],
#  'Holocaust-': ['themed'],
#  'themed': ['pool'],
#  'pool': ['party'],
#  'party': ['later'],
#  'later': ['on', 'on', 'from', 'died'],
#  'summer.': ['I'],
#  'am.': ['“Once', 'I'],
#  '“Once': ['everyone'],
#  'everyone': ['gets'],
#  'gets': ['in', 'all', 'his', 'on', 'a'],
#  'ze': ['pool,'],
#  'pool,': ['ja.”'],
#  'ja.”': ['“It'],
#  '“It': ['was'],
#  'weird,': ['it', 'but'],
#  'offensive': ['but', 'to', 'line.'],
#  'refreshing,': ['you'],
#  'feel': ['about',
#   'it',
#   'hopelessly',
#   'hopelessly',
#   'like',
#   'like',
#   'bad',
#   'your',
#   'you'],
#  'it.”': ['Yeah,', 'Yeah,'],
#  'trouble.': ['The', 'The', 'And', 'Yeah.'],
#  'The': ['old',
#   'owner',
#   '“N”',
#   'owner',
#   'good,',
#   'boss’s',
#   'airline',
#   'carburetor',
#   'guy',
#   'simple',
#   'deadline',
#   'most',
#   'kid',
#   'city',
#   'kid',
#   'traditional',
#   'guy',
#   'other',
#   'raciest'],
#  'redneck': ['on', 'with', 'dude'],
#  'Duck': ['Dynasty,', 'Dynasty', 'Dynasty'],
#  'Dynasty,': ['that'],
#  'dude': ['got',
#   'was',
#   'beating',
#   'had,',
#   'just',
#   'is',
#   'three',
#   'who',
#   'shows',
#   'fucking',
#   'with'],
#  'owner': ['of', 'of'],
#  'Clippers': ['got', 'guy,'],
#  'And': ['I’m',
#   'you',
#   'you',
#   'out',
#   'everybody',
#   'they’re',
#   'this',
#   'the',
#   'he',
#   'I',
#   'I',
#   'meanwhile',
#   'be',
#   'you',
#   'then',
#   'then',
#   'I',
#   'I',
#   'then',
#   'it',
#   'you',
#   'you’re',
#   'all',
#   'we',
#   'my',
#   'I',
#   'she',
#   'I',
#   'I',
#   'then',
#   'that’s',
#   'ever',
#   'then',
#   'you',
#   'he’s',
#   'you’re',
#   'you',
#   'she',
#   'finally,',
#   'it’s'],
#  'saying': ['what', 'these', 'that', 'to'],
#  'wasn’t': ['offensive.', 'that', 'alive'],
#  'offensive.': ['I’m'],
#  'sayin’': ['that'],
#  'pissed': ['me', 'off:'],
#  'off': ['was',
#   'of',
#   'the',
#   'my',
#   'in',
#   'cases',
#   'their',
#   'the',
#   'the',
#   'some',
#   'to',
#   'your',
#   'the',
#   'the',
#   'the',
#   'to',
#   'of',
#   'trying',
#   'this'],
#  'no': ['point',
#   'idea.',
#   'fat',
#   'up',
#   'way',
#   'idea.',
#   'splash,',
#   'ass-slapping,',
#   'difficulty.',
#   'problem'],
#  'point': ['during', 'in', 'it'],
#  'during': ['all'],
#  'stories': ['did', 'of', 'about'],
#  'address': ['their'],
#  'age,': ['you', 'and'],
#  'old,': ['you', 'right?', 'terminally'],
#  'thought?': ['You', 'I', 'Did'],
#  'talked': ['to'],
#  'grandparent': ['and'],
#  'asked': ['the', 'my', 'her,'],
#  'wrong': ['question', 'with'],
#  'question': ['and', 'sixty'],
#  'crazy': ['road?', 'shit'],
#  'road?': ['“Whoa,'],
#  '“Whoa,': ['whoa,'],
#  'whoa,': ['whoa!'],
#  'whoa!': ['Let’s'],
#  'Let’s': ['get', 'leave', 'not', 'just'],
#  'back': ['to',
#   'and',
#   'and',
#   'out',
#   'to',
#   'yet.',
#   'three',
#   'with',
#   'starts',
#   'in',
#   'to',
#   'on,',
#   'control',
#   'on.',
#   'in',
#   'in',
#   'outside',
#   'of',
#   'to'],
#  'cookies,': ['Grandma!'],
#  'Grandma!': ['Let’s'],
#  'leave': ['that', 'him'],
#  'fuck?”': ['Yeah,'],
#  'old.': ['What', 'Do', 'I', '“My', 'I’d', 'I’m'],
#  'mean–': ['I’m'],
#  'were': ['too',
#   'part',
#   'born,',
#   'supposed',
#   'little,',
#   'afraid?”',
#   'standing',
#   'just',
#   'out',
#   'out',
#   'doing',
#   'doing',
#   'doing',
#   'awesome.'],
#  'hard': ['on', 'to', 'on'],
#  'guy,': ['man,', 'that', 'I', 'I', 'it’s', 'marry'],
#  'man,': ['I’m', 'you', 'push', 'that’s', 'and', 'I’m', 'it’s', 'quit'],
#  'For': ['an', 'God’s'],
#  '80-year-old': ['white', 'white'],
#  'bad.': ['All'],
#  'drop': ['the', 'of…', 'down,'],
#  '“N”': ['word', 'word'],
#  'once.': ['That’s'],
#  'unbelievable': ['for'],
#  'guy.': ['The', 'Yeah,', 'I'],
#  'carpet-bombed': ['through'],
#  'through': ['that',
#   'college.',
#   'college,',
#   'the',
#   'here',
#   'his',
#   'those',
#   'town,',
#   'the'],
#  'tape.': ['He'],
#  'once!': ['If'],
#  'listen': ['to', 'to', 'to', 'to'],
#  'tape–': ['go'],
#  'Other': ['than', 'than'],
#  'Instagram,': ['he’s', 'I'],
#  'pretty': ['fucking'],
#  'liberal.': ['He’s'],
#  'hang': ['out', 'out', 'out', 'it', 'onto'],
#  'them,': ['you',
#   'just',
#   'go',
#   'is',
#   'they’re',
#   'and',
#   'let',
#   'that’s',
#   'they’ll',
#   'it’s'],
#  'sex': ['with', 'with', 'up', 'vibe’s'],
#  'promote': ['it', 'it'],
#  'Instagram.”': ['Yeah,', '“Hey,'],
#  'weirdest,': ['most'],
#  'most': ['compartmentalized,',
#   'arrogant',
#   'basic',
#   'epic',
#   'people,',
#   'arrogant',
#   'empty',
#   'difficult'],
#  'compartmentalized,': ['like,'],
#  'heard': ['in',
#   'all',
#   'the',
#   'in',
#   'while',
#   'their',
#   'my',
#   'my',
#   'the',
#   'was…',
#   'it.',
#   'in'],
#  'wide': ['open.'],
#  'open.': ['“You', 'You'],
#  'snowman': ['with'],
#  'water': ['park,', 'for'],
#  'park,': ['rub'],
#  'rub': ['your', 'one'],
#  'bellies': ['together,'],
#  'together,': ['just'],
#  '“Hey,': ['what', 'you', 'could', 'how', 'man,', 'I', 'how’s', 'hey,'],
#  'Facebook?”': ['“I'],
#  '“I': ['don’t',
#   'wanted',
#   'get',
#   'said',
#   'never',
#   'built',
#   'need',
#   'don’t',
#   'guess',
#   'fucking',
#   'don’t'],
#  'give': ['a',
#   'a',
#   'him',
#   'me',
#   'a',
#   'a',
#   'you,',
#   'a',
#   'him',
#   'him',
#   'him',
#   'a',
#   'him',
#   'a'],
#  'Facebook!': ['Keep'],
#  'Keep': ['it', 'the'],
#  'Instagram!”': ['Yeah.'],
#  'years': ['old.',
#   'before',
#   'of',
#   'to',
#   'old.',
#   'later',
#   'ago,',
#   'ago.',
#   'old,',
#   'old.',
#   'old.',
#   'old.',
#   'without',
#   'old,'],
#  'Do': ['the', 'some', 'some', 'you', 'a', 'you', 'you', 'you', 'you', 'it'],
#  'math.': ['This'],
#  'born': ['in'],
#  '1934.': ['That’s'],
#  '13': ['years'],
#  'before': ['Jackie', 'there', 'you', 'REM', 'they’re'],
#  'Jackie': ['Robinson'],
#  'Robinson': ['broke'],
#  'broke': ['the'],
#  'color': ['barrier.'],
#  'barrier.': ['First'],
#  'First': ['12', '12', 'time'],
#  '12': ['and', 'and'],
#  'half': ['years', 'years.', 'naked.', 'a'],
#  'guy’s': ['life,', 'name', 'like,', 'yard.'],
#  'life,': ['he', '’cause', 'like,', 'but', 'like,'],
#  'watched': ['all-white', 'the'],
#  'all-white': ['baseball,'],
#  'baseball,': ['and', 'white'],
#  'fine!': ['First'],
#  'years.': ['“Up', 'Here'],
#  '“Up': ['next,'],
#  'next,': ['Whitey'],
#  'Whitey': ['Willoughby!'],
#  'Willoughby!': ['There’s'],
#  'line': ['shot', 'all'],
#  'shot': ['out', 'at.', 'the', 'that', 'a', 'a', 'the'],
#  'Peter': ['Peckerwood,'],
#  'Peckerwood,': ['what'],
#  'catch!': ['Unbelievable,'],
#  'Unbelievable,': ['in'],
#  'Chris': ['Cracker!'],
#  'Cracker!': ['What'],
#  'ballgame.': ['White'],
#  'White': ['baseball,'],
#  'players.”': ['Dude,'],
#  'parents': ['were', 'come', 'did'],
#  'generation': ['that'],
#  'finished': ['off'],
#  'genocide': ['of'],
#  'Native': ['Americans,'],
#  'Americans,': ['all'],
#  'taught': ['him'],
#  'him': ['his',
#   'a',
#   'stubbing',
#   'and',
#   'like',
#   'figure',
#   'gay.”',
#   'to',
#   'do',
#   'upside',
#   'there.',
#   'upside-right,',
#   'by',
#   'and',
#   'a',
#   'sit',
#   'home.',
#   'a',
#   'out',
#   'something',
#   'in,',
#   'a',
#   'back,',
#   'a',
#   'as'],
#  'ABCs.': ['You'],
#  '“~': ['A,', 'Say', 'All'],
#  'A,': ['B,'],
#  'B,': ['C,'],
#  'C,': ['D,'],
#  'D,': ['E…'],
#  'E…': ['~'],
#  '~': ['Hey,', 'H,', '~', 'Say', '~', 'I’ll', '~', 'Now', 'Cottage', 'Then'],
#  'Hey,': ['get', 'everybody,', 'Dude,', 'let', 'what', 'where'],
#  'savage': ['off'],
#  'property!': ['Get'],
#  'Get': ['out', 'out', 'in'],
#  'here!': ['I'],
#  'thought': ['we', 'I', 'I', 'it', 'this', 'she'],
#  'killed': ['all', 'anybody', 'people.'],
#  'people!': ['Put'],
#  'Put': ['a', 'your'],
#  'fence': ['around'],
#  'around': ['them!',
#   '1969,',
#   'then,',
#   'their',
#   'asking',
#   'on',
#   'not',
#   'it.',
#   'laughing',
#   'and',
#   'and',
#   'here!”',
#   'talking',
#   'to',
#   'the',
#   'the',
#   'your',
#   'her'],
#  'them!': ['~', 'It’s'],
#  'H,': ['I,'],
#  'I,': ['J,'],
#  'J,': ['K…'],
#  'K…': ['~”'],
#  '~”': ['Yeah.', '“~', 'Right?'],
#  'happen?': ['The'],
#  'Clippers,': ['you'],
#  'big': ['crime', 'boy.”', 'thing.', 'brother,', 'gun.”'],
#  'crime': ['was?'],
#  'was?': ['He'],
#  'lived': ['too'],
#  'long.': ['He', 'You'],
#  'he’d': ['died', 'chill'],
#  'died': ['around', 'in', 'at'],
#  '1969,': ['1970,'],
#  '1970,': ['nobody'],
#  'noticed.': ['Dude,'],
#  'Walt': ['Disney,', 'Disney'],
#  'Disney,': ['Walt'],
#  'Disney': ['was'],
#  'known': ['anti-Semite.'],
#  'anti-Semite.': ['But'],
#  'early': ['’70s.', 'on,'],
#  '’70s.': ['Nobody'],
#  'him,': ['he’s', 'it’s', 'and', 'not', 'and'],
#  'castle,': ['bunch'],
#  'mice': ['running'],
#  'running': ['around.'],
#  'around.': ['Nobody', 'All', '“I’ll', 'I'],
#  'cares.': ['This'],
#  'kept': ['living.', 'seeing', 'taking', 'putting'],
#  'living.': ['Telling', 'Basically,'],
#  'Telling': ['you,'],
#  'you,': ['you',
#   'they',
#   'like,',
#   'none',
#   'that',
#   'you’re',
#   'I',
#   'fuck',
#   'just',
#   'son.',
#   'disease.',
#   'so',
#   'thank'],
#  'long,': ['I’m'],
#  'wear': ['out'],
#  'welcome.': ['I'],
#  'swear': ['to', 'to'],
#  'God,': ['this', 'this', 'it', 'it’s'],
#  'bet': ['in'],
#  '1940’s,': ['he'],
#  'considered': ['a'],
#  'hippie.': ['You'],
#  '’em,': ['you', 'man,'],
#  'know?”': ['His'],
#  'dad’s': ['getting'],
#  'off:': ['“Let'],
#  '“Let': ['me'],
#  'something,': ['see?', 'so'],
#  'see?': ['You'],
#  'stay': ['with', 'with', 'away'],
#  'own!': ['You'],
#  'own.”': ['That’s'],
#  'true,': ['though.', 'that'],
#  'Life': ['can'],
#  'pass': ['you', 'the'],
#  'by.': ['It', 'I', 'I’m', 'I’ll'],
#  'It': ['happens.', 'was', 'isn’t.', 'has', 'was', 'always'],
#  'happens.': ['You'],
#  'living': ['and', 'room.', 'room'],
#  'Basically,': ['I'],
#  '25,': ['30'],
#  '30': ['years', 'days.', 'years–', 'years', 'years.', 'pounds'],
#  'absorb': ['as'],
#  'much': ['as', 'as'],
#  'can,': ['and'],
#  'then': ['that’s',
#   'you',
#   'you',
#   'one',
#   'what,',
#   'one',
#   'you',
#   'maybe',
#   'I',
#   'you',
#   'he',
#   'there’s,',
#   'I',
#   'all',
#   'I',
#   'it',
#   'I’m',
#   'you',
#   'I’m',
#   'you',
#   'when',
#   'out',
#   'they'],
#  '‘Cause': ['right', 'you', 'I', 'you', 'that’s', 'they'],
#  'right': ['around',
#   'now.',
#   'here.',
#   'now.',
#   'out',
#   'now?',
#   'out',
#   'before',
#   'in',
#   'here.'],
#  'then,': ['you'],
#  'married,': ['and', 'they', 'so'],
#  'over,': ['right?', '’cause', 'I'],
#  'couple': ['of', 'of', 'of', 'of', 'of', 'nights'],
#  'kids,': ['you’re', 'that', 'but'],
#  'sucked': ['in'],
#  'bubble.': ['You'],
#  'time': ['to',
#   'ago,',
#   'I',
#   'I’m',
#   'to',
#   'my',
#   'to',
#   'when',
#   'you',
#   'I',
#   'to',
#   'without',
#   'here.”',
#   'a'],
#  'pay': ['attention'],
#  'attention': ['to'],
#  'what’s': ['going', 'gonna', 'left', 'gonna', 'funny?', 'the'],
#  'world.': ['You’re', 'You', 'Know'],
#  'stuck': ['with', 'in'],
#  'kids.': ['“It’s', 'And', 'As', 'I', 'I', 'Most'],
#  '“It’s': ['shitting', 'an', 'like', 'been'],
#  'shitting': ['all'],
#  'place!': ['Don’t'],
#  'Don’t': ['be',
#   'touch',
#   'clap,',
#   'kill',
#   'touch',
#   'even',
#   'even',
#   'even',
#   'even',
#   'be'],
#  'serial': ['killer!'],
#  'killer!': ['Don’t'],
#  'touch': ['that!”', 'my'],
#  'that!”': ['You’re'],
#  'three,': ['four', 'four', 'four,'],
#  'four': ['kids,', 'times,', 'years', 'more'],
#  '25-year': ['sentence,'],
#  'sentence,': ['trying'],
#  'trying': ['to', 'to', 'to', 'to', 'not', 'to', 'to', 'to', 'to', 'to'],
#  'them': ['all',
#   'are',
#   'three,',
#   'up,',
#   'know',
#   'a',
#   'and',
#   'honest.',
#   'calm.',
#   'calm,',
#   'up'],
#  'college.': ['Society'],
#  'Society': ['just'],
#  'keeps': ['fucking', 'going,'],
#  'going.': ['You', 'The'],
#  'college,': ['step', 'you'],
#  'step': ['back'],
#  'bubble–': ['You'],
#  'happened.': ['You’re', 'He'],
#  'paying': ['attention.'],
#  'attention.': ['You'],
#  'record': ['collection.'],
#  'collection.': ['[scatting]'],
#  '[scatting]': ['Someone'],
#  'Someone': ['sticks'],
#  'sticks': ['a'],
#  'mike': ['in'],
#  'face,': ['you’re'],
#  'sad': ['things'],
#  'things': ['about', 'I’ve'],
#  'passes': ['you'],
#  'passing': ['me', 'me'],
#  '46': ['years', 'years'],
#  'anymore.': ['I', 'You'],
#  'college': ['gig'],
#  'coming': ['up,',
#   'to',
#   'out',
#   'back.',
#   'down',
#   'walking',
#   'home',
#   'up',
#   'in',
#   'back',
#   'around',
#   'across,',
#   'back,',
#   'back!”'],
#  'figure': ['out', 'out', 'if', 'it', 'out', 'it'],
#  'kids': ['are', 'when', 'are'],
#  'into.': ['I'],
#  '24': ['when'],
#  'senior': ['was'],
#  'born.': ['I'],
#  'dudes': ['are'],
#  'into,': ['so', 'you’re', 'but'],
#  'into': ['like,',
#   'that',
#   'the',
#   'that',
#   'Albany,',
#   'a',
#   'some',
#   'land',
#   'it,',
#   'the',
#   'the',
#   'a',
#   'that',
#   'shit.'],
#  'DJ': ['music'],
#  'music': ['or'],
#  'I’ll': ['watch',
#   'get',
#   'say',
#   'say',
#   'just',
#   'just',
#   'just',
#   'just',
#   'whittle',
#   'get',
#   'break',
#   'do',
#   'hang',
#   'watch',
#   'see'],
#  'this.': ['You', 'Why', 'And', 'It’s'],
#  'reference': ['or'],
#  'two.': ['I'],
#  'comic': ['coming'],
#  '“What’s': ['up', 'with', 'the'],
#  'Monica': ['Lewinsky?'],
#  'Lewinsky?': ['Is'],
#  'Is': ['this', 'my', 'there', 'the', 'that', 'that', 'he'],
#  'crazy?': ['I'],
#  'mean,': ['this'],
#  'Y2K–': ['Is'],
#  'stylus': ['gonna'],
#  'work?': ['I'],
#  'know.”': ['So'],
#  'on.': ['Dude,', 'Established'],
#  'lasted': ['90'],
#  '90': ['seconds.'],
#  'seconds.': ['Ninety', 'I'],
#  'Ninety': ['seconds.', 'seconds'],
#  'open-minded.': ['“All', 'I'],
#  '“All': ['right,',
#   'right,',
#   'right,',
#   'right,',
#   'right,',
#   'right,',
#   'right,',
#   'right.',
#   'right,',
#   'right,'],
#  'on!”': ['Ninety'],
#  'seconds': ['later,', 'of', 'before'],
#  'later,': ['I’m', 'this'],
#  '“Ah,': ['this', 'son,'],
#  'isn’t': ['music!”'],
#  'music!”': ['You'],
#  '“When': ['I'],
#  'kid,': ['you',
#   'what',
#   'I’ll',
#   'tip',
#   'just',
#   'which',
#   'I’m',
#   'that',
#   'right?',
#   'five',
#   'he'],
#  'dressed': ['like'],
#  'sung': ['about'],
#  'devil.': ['Now,'],
#  'Now,': ['that'],
#  'music!': ['And'],
#  'ballad': ['every'],
#  'album,': ['started'],
#  'started': ['off', 'to', 'shooting', 'having'],
#  'black': ['and'],
#  'guitar': ['solo'],
#  'solo': ['came'],
#  'color.': ['Yeah,'],
#  'music.”': ['Yeah.'],
#  'shit’s': ['passing'],
#  'Transgender': ['athletes?'],
#  'athletes?': ['I'],
#  'switch': ['around,'],
#  'sports': ['fan.', 'bra,'],
#  'fan.': ['That’s'],
#  'really': ['new', 'goes', 'need–”', 'must', 'wanted'],
#  'new': ['concept', 'duck', 'fears.'],
#  'concept': ['to'],
#  'me,': ['that',
#   'that',
#   'so',
#   'what',
#   'is',
#   'I',
#   'like,',
#   'I',
#   '170',
#   'she',
#   'but',
#   'maybe',
#   'it’s'],
#  'Ranked': ['80th'],
#  '80th': ['in'],
#  'dick': ['cut', 'like', 'sitting'],
#  'cut': ['off,', 'off'],
#  'bra,': ['and', 'you'],
#  ...}

# %%
dave_dict = markov_chain(dave_text)
dave_dict
# Out:
# {'This': ['is',
#   'happens',
#   'woman',
#   'is',
#   'guy',
#   'was',
#   'is',
#   'is',
#   'was',
#   'was',
#   'country',
#   'guy’s',
#   'is',
#   'guy',
#   'motherfucker',
#   'is',
#   'is'],
#  'is': ['Dave.',
#   'where',
#   'very',
#   'also',
#   'broken.',
#   'going',
#   'outside',
#   'gonna',
#   'not',
#   'in',
#   'because,',
#   'fucking',
#   'fucked',
#   'like,',
#   'about',
#   'a',
#   'what',
#   'blessed',
#   'he',
#   'that',
#   'not',
#   'what',
#   'Asian.',
#   'still',
#   'not',
#   'gayer,',
#   'the',
#   'like',
#   'sometimes',
#   'scary',
#   'right',
#   'this',
#   'why',
#   'taking',
#   'the',
#   'just',
#   'a',
#   'older',
#   'Top',
#   'when',
#   'suffering.',
#   'wrong',
#   'wrong?',
#   'just',
#   'a',
#   'Kevin',
#   'when',
#   'the',
#   'directly',
#   'this:',
#   'not',
#   'right',
#   'too',
#   'a',
#   'your'],
#  'Dave.': ['He'],
#  'He': ['tells',
#   'refused',
#   'said,',
#   'was',
#   'said,',
#   'said,',
#   'said,',
#   'said,',
#   'said,',
#   'was',
#   'goes,',
#   'was',
#   'keeps',
#   'was',
#   'beats',
#   'said,',
#   'stopped,',
#   'leaned',
#   'looked',
#   'always',
#   'said,',
#   'told',
#   'was',
#   'was',
#   'was',
#   'was',
#   'said,',
#   'was',
#   'was',
#   'said,',
#   'said,',
#   'said,',
#   'goes,',
#   'goes,',
#   'was',
#   'said,',
#   'goes,',
#   'gave',
#   'rapes,',
#   'had',
#   'was'],
#  'tells': ['dirty'],
#  'dirty': ['jokes'],
#  'jokes': ['for'],
#  'for': ['a',
#   'a',
#   'a',
#   'their',
#   'this',
#   'the',
#   'a',
#   'some',
#   'some',
#   'them',
#   'a',
#   'alarm.',
#   'you',
#   'it.”',
#   'everybody.',
#   'her',
#   'him',
#   'his',
#   'you',
#   'a',
#   'a',
#   'the',
#   'you',
#   'the',
#   'the',
#   'saving',
#   'truth,',
#   'no',
#   'the',
#   'over',
#   'gay',
#   '“Tough',
#   'themselves,',
#   'America.',
#   'the',
#   'minutes,',
#   'your',
#   'a',
#   'like,',
#   'a',
#   'abortions?',
#   'people',
#   'you.',
#   'us,',
#   'the',
#   'the',
#   'shoelaces',
#   'a',
#   'the',
#   '12',
#   'the',
#   'sure.\nYeah,',
#   'Syracuse.',
#   'like,',
#   'saying',
#   'me,',
#   'Bill',
#   'me,',
#   'years,',
#   'a',
#   'the',
#   '“Shut',
#   'thousands',
#   'a',
#   'the',
#   'the',
#   'A',
#   'that',
#   'Phife!',
#   'the'],
#  'a': ['living.',
#   'profound',
#   'seat,',
#   'wonderful',
#   'very',
#   'difficult',
#   'long',
#   'fucking',
#   'comedy',
#   'black',
#   'Ford',
#   'weird',
#   'conservative',
#   'long',
#   'woman',
#   'mousetrap',
#   'tough',
#   'few',
#   'lot',
#   'good',
#   'second?”',
#   'traffic',
#   'situation',
#   'ride',
#   'noise.',
#   'black',
#   'day',
#   'lot',
#   'Murderer?',
#   'justice',
#   'Murderer',
#   'black',
#   'single',
#   'black',
#   'black',
#   'show,',
#   'long',
#   'nutshell.',
#   'few',
#   'wedge',
#   'charity',
#   'lot',
#   'tremendous',
#   'lot',
#   'ticket',
#   'fucking',
#   'tuxedo',
#   'couple',
#   'quick',
#   'boycott',
#   'wonderful',
#   'money',
#   'superhero',
#   'gay',
#   'gay',
#   'radioactive',
#   'lot.”',
#   'gay',
#   'superhero',
#   'woman’s',
#   'long',
#   'couple',
#   'handsome',
#   'couple',
#   'lot',
#   'young',
#   'restaurant',
#   'deal',
#   'group',
#   'familiar',
#   'woman',
#   'hard',
#   'good',
#   'little',
#   'gay',
#   'huge',
#   'lot',
#   'quiet',
#   'whole',
#   'boxer',
#   'sneaker',
#   'sneaker',
#   'sneaker',
#   'walking',
#   'black',
#   'Negro,',
#   'while.',
#   'nigger',
#   'minute.',
#   'lot',
#   'lot',
#   'cat',
#   'cat',
#   'petition',
#   'white',
#   'minute.',
#   'time',
#   'decision',
#   'happy',
#   'little',
#   'fucking',
#   'transgender',
#   'comedy',
#   'thing?',
#   'white',
#   'panic.',
#   'break',
#   'minute.',
#   'different',
#   'time',
#   'television',
#   'goddamn',
#   'guy',
#   'guy',
#   'fucking',
#   'fucking',
#   'long',
#   'lot',
#   'lot',
#   'Crunch',
#   'life-changing',
#   'little-known',
#   'new',
#   'new',
#   'fucking',
#   'college',
#   'wild',
#   'lot',
#   'lot',
#   'pilot’s',
#   'tough',
#   'little',
#   'little',
#   'woman',
#   'fucking',
#   'really',
#   'lot',
#   'lot',
#   'lot',
#   'young',
#   'black',
#   'fucking',
#   'Jewish',
#   'tough',
#   '42-year-old',
#   'hero',
#   'long',
#   'terrible',
#   'fucking',
#   'box',
#   'Drake',
#   'lot',
#   'girl',
#   'loan',
#   'valuable',
#   'cartoon',
#   'television',
#   'clinical',
#   'television',
#   'dream,',
#   'PA',
#   'very',
#   'party',
#   'familiar',
#   'unicorn.',
#   'familiar',
#   'picture.”',
#   'picture',
#   'fucking',
#   'poem',
#   'studio',
#   'really',
#   'lot',
#   'note',
#   'breath'],
#  'living.': ['That'],
#  'That': ['stare',
#   'was',
#   'motherfucker',
#   'is',
#   'should',
#   'building’s',
#   'guy',
#   'worked',
#   'shit',
#   'we'],
#  'stare': ['is', 'at', 'at'],
#  'where': ['most', 'I', 'an', 'nobody', 'their'],
#  'most': ['of', 'famous,', 'difficult'],
#  'of': ['his',
#   'thought,',
#   'it',
#   'weed,',
#   'weed,',
#   'racial',
#   'it.',
#   'Detroit,',
#   'the',
#   'dollars–',
#   'bubble',
#   'black',
#   'one',
#   'those',
#   'mine.',
#   'my',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'L.A.',
#   'money',
#   'shots.',
#   'the',
#   'that',
#   'the',
#   'those',
#   'this',
#   'black',
#   'weeks',
#   'the',
#   'black',
#   'people',
#   'all',
#   'ideas.”',
#   'powers.',
#   'pats.”',
#   'pats!’',
#   'lives.',
#   'the',
#   'probably',
#   'women',
#   'the',
#   'the',
#   'them',
#   'disgust',
#   'know',
#   'an',
#   'lady-boys',
#   'our',
#   'kids',
#   'women',
#   'the',
#   'homosexuals?”',
#   'the',
#   'civil',
#   'Education',
#   'gay',
#   'gay',
#   'their',
#   'gay',
#   'the',
#   'the',
#   'the',
#   'you',
#   'all',
#   'them',
#   'that',
#   'her',
#   'the',
#   'them',
#   'Chappelle’s',
#   'the',
#   'the',
#   'the',
#   'the',
#   'three',
#   'all',
#   'your',
#   'spin.',
#   'teddy-bear',
#   'beings.',
#   'their',
#   'your',
#   'black',
#   'those',
#   'them',
#   'the',
#   'France,',
#   'American',
#   'that,',
#   'thought',
#   'the',
#   'peace.',
#   'everyone',
#   'rapes,',
#   'rape.',
#   'rapes.',
#   'these',
#   'sleep',
#   'rape.',
#   'the',
#   'men',
#   'men',
#   'men',
#   'those',
#   'all,',
#   'people.',
#   'here.”',
#   'Kevin’s',
#   'custom-made',
#   'them.',
#   'them',
#   'African-Americans',
#   'millions',
#   'dollars',
#   'higher',
#   'black',
#   'the',
#   'Garry',
#   'the',
#   'fresh'],
#  'his': ['hard',
#   'legal',
#   'soon-to-be-slain',
#   'shift',
#   'wildest',
#   'outfit.',
#   'powers',
#   'eyes',
#   'shoes',
#   'motherfucking',
#   'eyes,',
#   'presence',
#   'fucking',
#   'show.”',
#   'show',
#   'knee.',
#   'door,',
#   'dressing',
#   'back',
#   'house',
#   'wife',
#   'show.',
#   'camera'],
#  'hard': ['work', 'time', 'street', 'to', 'way.'],
#  'work': ['happens.', 'out'],
#  'happens.': ['It', 'I’m', 'I'],
#  'It': ['signifies',
#   'was',
#   'was',
#   'just',
#   'was',
#   'was',
#   'all',
#   'was',
#   'was',
#   'was',
#   'wasn’t',
#   'takes',
#   'was',
#   'fucking',
#   'was',
#   'was',
#   'was',
#   'was',
#   'only',
#   'was',
#   'was',
#   'was',
#   'was'],
#  'signifies': ['a'],
#  'profound': ['train'],
#  'train': ['of'],
#  'thought,': ['the'],
#  'the': ['alchemist’s',
#   'last',
#   'agony',
#   'big',
#   'guy',
#   'show',
#   'fuck?”',
#   'ice.',
#   'attempt.',
#   'show,',
#   'money',
#   'show–',
#   'homeless',
#   'very',
#   'next',
#   'trap.',
#   'next',
#   'call.',
#   'phone.',
#   'Stars.”',
#   'keys.”',
#   'keys.”',
#   'passenger’s',
#   '10,',
#   'blue-and-whites',
#   'friend',
#   'story',
#   'car.',
#   'right',
#   'driver’s',
#   'lane.',
#   'car',
#   'rearview',
#   'arrest',
#   'radio.',
#   'radio',
#   'car.',
#   'rearview',
#   'next',
#   'back',
#   'car,',
#   'police',
#   'window.',
#   'car',
#   'vehicle,',
#   'keys.”',
#   'shit',
#   'keys',
#   'car.”',
#   'miles',
#   'lucky',
#   'same',
#   'second',
#   'tape.',
#   'history',
#   'United',
#   'United',
#   'police',
#   'game.',
#   'end',
#   'show,',
#   'last',
#   'time,',
#   'guy',
#   'club',
#   'steps,',
#   'nice',
#   'fuck',
#   'end',
#   'fuck',
#   'first',
#   'community',
#   'appalling',
#   'water',
#   'water',
#   'schedule',
#   'reason',
#   'same',
#   'Oscars.',
#   'airport',
#   'Oscars.',
#   'airport',
#   'Oscars.',
#   'movies',
#   'red',
#   'black',
#   'motherfucker',
#   'kente',
#   'fuck?',
#   'fuck',
#   'Oscars.',
#   'motherfucking',
#   'Oscars',
#   'stars.\nAnd',
#   'leader',
#   'gay',
#   'leader',
#   'talking.',
#   'game,',
#   'trash',
#   'whole',
#   'American',
#   'problem',
#   'city',
#   'dilemma',
#   'audience.',
#   'whole',
#   'celebrities',
#   'trial',
#   'century.',
#   'most',
#   'restaurant,',
#   'only',
#   'restaurant.',
#   '90’s,',
#   'man',
#   'infamous',
#   'women,',
#   'door.',
#   'corner',
#   'booth.',
#   'white',
#   'first',
#   'only',
#   'courage',
#   'deep',
#   'gay',
#   'fuck',
#   'shoes',
#   'front?',
#   'world,',
#   'masculinity',
#   'wake',
#   'Philippines,',
#   'Philippines',
#   'Philippines',
#   'Arabian',
#   'United',
#   'number-one',
#   'Philippines’',
#   'expats',
#   'Philippines.',
#   'other',
#   'guy',
#   'back',
#   'bus.',
#   'talk',
#   'first',
#   'marching,',
#   'law',
#   'merits',
#   'party’s',
#   'way',
#   'beef,',
#   'words',
#   'law.',
#   'law?”',
#   'semantics.',
#   'fuck',
#   'casino.',
#   'wife.”',
#   'fuck',
#   '‘Q’?”',
#   'vowels.',
#   'time.',
#   '“T”',
#   'toughest',
#   '“T”',
#   'longest',
#   'street,',
#   'Kardashians,',
#   'street',
#   'long',
#   'public',
#   'media',
#   'public',
#   'media',
#   'world,',
#   'American.',
#   'black',
#   'fuck',
#   'discrimination',
#   'police',
#   'boardroom.',
#   'conference',
#   'head',
#   'conference',
#   'table.',
#   'hospital',
#   'club',
#   'second',
#   'door',
#   'green',
#   'stage.',
#   'door',
#   'green',
#   'dressing',
#   'whole',
#   'signal',
#   'green',
#   'fuck',
#   'couch.',
#   'nicest',
#   'Juice',
#   'game.',
#   'room.',
#   'door',
#   'room.”',
#   'young',
#   'phone',
#   'shit.',
#   'teacher',
#   'classroom.',
#   'space',
#   'teacher',
#   'kids',
#   'pain,',
#   'space',
#   'fuck',
#   'hallmark',
#   'most',
#   'age',
#   'fuck',
#   'designs',
#   'leader',
#   'Care',
#   'problem–',
#   'time.',
#   'next',
#   'act.',
#   'Second',
#   'United',
#   'first',
#   'Nazis',
#   'United',
#   'back',
#   'bus',
#   'South',
#   'first',
#   'workforce',
#   'millions.',
#   'men',
#   'factory.',
#   'first',
#   'men',
#   'women',
#   'same.',
#   'fuck',
#   'scenes',
#   'American',
#   'first',
#   'very',
#   'President',
#   'United',
#   'Cold',
#   'same.',
#   '’60s.',
#   'streets',
#   'Vietnam',
#   'Steph',
#   'show',
#   'back',
#   'room,',
#   'show.”',
#   'stage.',
#   'time',
#   'aisle',
#   'face.”',
#   'world.',
#   'streets,',
#   'way',
#   'fuck',
#   'difference?”',
#   'heist.',
#   'time.',
#   'Jewish',
#   'ropes,',
#   'way',
#   'fuck',
#   'man',
#   'hard',
#   'tickets?”',
#   'show.',
#   'stage.',
#   'show',
#   'madder',
#   'lights',
#   'door.',
#   'corner',
#   'corner,',
#   'local',
#   'back,',
#   'first',
#   'whole',
#   'fuck',
#   'fuck',
#   'fuck',
#   'fuck',
#   'fuck',
#   'first',
#   'first',
#   'Super',
#   'ones',
#   'kicker.',
#   'fact',
#   'steps',
#   'Lincoln',
#   'funniest',
#   'last',
#   'Juice.',
#   'Kentucky',
#   'bar,',
#   'gawkers,',
#   'crowd.',
#   'same',
#   'end.',
#   'real',
#   'family',
#   'hip-hop',
#   'building…',
#   'air',
#   'funky',
#   'rhythm',
#   'garments',
#   'obeyer',
#   'Tribe',
#   'game',
#   'player'],
#  'alchemist’s': ['fire'],
#  'fire': ['that'],
#  'that': ['transforms',
#   'look',
#   'happen,',
#   'guy',
#   'night.',
#   'shit,',
#   'was',
#   'thing.',
#   'thing',
#   'well',
#   'videotape',
#   'lady',
#   'got',
#   'shit',
#   'woman',
#   'Marcos',
#   'shit',
#   'shit',
#   'he',
#   'new',
#   'shit.',
#   'OJ',
#   'woman',
#   'was',
#   'would',
#   'was',
#   'water?',
#   'water',
#   'this',
#   'fucking',
#   'you',
#   'I',
#   'gets',
#   'motherfucker',
#   'shit',
#   'our',
#   'felt',
#   'they',
#   'group.',
#   'he',
#   'murderer?”',
#   'murderer',
#   'recently.',
#   'Manny',
#   'I',
#   'America',
#   'explains',
#   'shit.',
#   'was',
#   'was.\nBut',
#   'they',
#   'money',
#   'the',
#   'people',
#   'shit.\nYou',
#   'over',
#   'even',
#   'don’t',
#   'cereal',
#   'wear',
#   'to',
#   'he',
#   'shit.',
#   'shit.',
#   'I',
#   'technology,',
#   'I',
#   'shit',
#   'Planned',
#   'don’t',
#   'way.',
#   'shit?',
#   'was',
#   'life',
#   'and',
#   'it’s',
#   'was',
#   'no',
#   'started',
#   'was',
#   'made',
#   'stood',
#   'I',
#   'identify',
#   'in',
#   'in',
#   'it’s',
#   'shit',
#   'motherfucker',
#   'I',
#   'rape',
#   'maybe',
#   'technically',
#   'your',
#   'chocolate',
#   'Kevin',
#   'would',
#   'would',
#   'motherfucker',
#   'shit',
#   'box,',
#   'on.”',
#   'was',
#   'shit.',
#   'a',
#   'he',
#   'I',
#   'he’s',
#   'he’s',
#   'he',
#   'got',
#   'he',
#   'there',
#   'shit.',
#   'I',
#   'when',
#   'Bill',
#   'room.',
#   'point',
#   'beautiful',
#   'flows',
#   'you’ll'],
#  'transforms': ['fear'],
#  'fear': ['and', 'in'],
#  'and': ['tragedy',
#   'livelihood.',
#   'this',
#   'backed',
#   'started',
#   'drove',
#   'handed',
#   'still',
#   'do',
#   'hang',
#   'shit.',
#   'my',
#   'he',
#   'I',
#   'we’ll',
#   'pass,',
#   'suffering.',
#   'be',
#   'the',
#   'was',
#   'he',
#   'OJ',
#   'I',
#   'gentlemen,',
#   'she',
#   'she',
#   'the',
#   'they',
#   'I',
#   'then',
#   'is',
#   'the',
#   'be',
#   'Peele',
#   'had',
#   'is',
#   'the',
#   'he',
#   'the',
#   'do',
#   'convince',
#   'he',
#   'white',
#   'embraced',
#   'they',
#   'correctly',
#   'shook',
#   'I',
#   'all',
#   'some',
#   'they’ve',
#   'shit',
#   'reinstates',
#   'blacks',
#   'I',
#   'they',
#   'wife”',
#   'get',
#   'whichever',
#   'field.',
#   'even',
#   'let',
#   'shit.',
#   'throw',
#   'cut',
#   'make',
#   'trick',
#   'the',
#   'it',
#   'I',
#   'OJ',
#   'we',
#   'levity,',
#   'wisdom.',
#   'then',
#   'I’m',
#   'the',
#   'we’re',
#   'was',
#   'then',
#   'then',
#   'another',
#   'then',
#   'that’s',
#   'they',
#   'they',
#   'everything',
#   'the',
#   'stare',
#   'I’m',
#   'would',
#   'that',
#   'fight',
#   'make',
#   'gentlemen.',
#   'these',
#   'penises',
#   'chocolate',
#   'very',
#   'sit',
#   'when',
#   '“Shut',
#   '“I',
#   'mescaline',
#   'shit',
#   'said',
#   'on.',
#   'they',
#   'gentlemen,',
#   'she',
#   'daughters',
#   'sisters',
#   'wives,',
#   'we',
#   'not',
#   'screaming',
#   'your',
#   'you',
#   'Jews',
#   'I',
#   'one',
#   'the',
#   'then',
#   'nobody’s',
#   'says,',
#   'there',
#   'on',
#   'he',
#   'grabbed',
#   'he',
#   'sing',
#   'the',
#   'noses',
#   'is',
#   'said',
#   'every',
#   'we’re',
#   'motherfuckers',
#   'Chris',
#   'Chris',
#   'friends',
#   'my',
#   'ever.'],
#  'tragedy': ['into', 'used'],
#  'into': ['levity',
#   'Vegas.',
#   'Flint,',
#   'some',
#   'fucking',
#   'the',
#   'the',
#   'it,',
#   'his',
#   'a'],
#  'levity': ['and'],
#  'livelihood.': ['Dave'],
#  'Dave': ['calls',
#   'Chappelle!”',
#   'Chappelle.',
#   'Chappelle.”',
#   'Chappelle,”',
#   'Chappelle,',
#   'Chappelle,',
#   'Chappelle?'],
#  'calls': ['that', 'me'],
#  'look': ['“the', 'at', 'at'],
#  '“the': ['trance.”'],
#  'trance.”': ['♪'],
#  '♪': ['Play',
#   '♪',
#   'Buy',
#   '♪',
#   'Workinonit',
#   '♪',
#   'Tune',
#   '♪',
#   'Tune',
#   '♪',
#   'Oh',
#   '♪',
#   'Fade',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   'Thank',
#   '♪',
#   'I',
#   '♪',
#   'I',
#   '♪',
#   'I',
#   '♪',
#   'Fuck',
#   '♪',
#   'I',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   'Wait,',
#   'Ah-ah,',
#   '♪',
#   'In',
#   '♪',
#   'Ah-ah',
#   '♪',
#   'Revolution',
#   '♪',
#   'Ah-ah,',
#   '♪',
#   'In',
#   'One',
#   'Can',
#   '♪',
#   'Yes,',
#   '♪',
#   'Can',
#   '♪',
#   'Yes,',
#   '♪',
#   'Can',
#   '♪',
#   'Yes,',
#   '♪',
#   'Well,',
#   '♪',
#   'Go',
#   '♪',
#   'Can',
#   '♪',
#   'Right',
#   '♪',
#   'At',
#   '♪',
#   'Mr.',
#   '♪',
#   'You’ll',
#   '♪',
#   'Boy,',
#   '♪',
#   'When',
#   '♪',
#   'Follow',
#   '♪',
#   'Make',
#   '',
#   'Feel',
#   '♪',
#   'Do',
#   '♪',
#   'I',
#   '♪',
#   'A',
#   '♪',
#   'Doesn’t',
#   '♪',
#   'Yes,',
#   '♪',
#   'As',
#   'I’m'],
#  'Play': ['me'],
#  'me': ['♪',
#   '♪',
#   '♪',
#   'now.',
#   'once.',
#   'on',
#   'waiting',
#   'the',
#   'was',
#   'immediately.',
#   'the',
#   'see',
#   'for',
#   'like',
#   'and',
#   'and',
#   'all',
#   'with:',
#   'on',
#   'was',
#   'the',
#   'at',
#   'a',
#   'that.',
#   'the',
#   'the',
#   'about',
#   'it’s',
#   'with',
#   'or',
#   'in',
#   'and',
#   'if',
#   'staring',
#   'and',
#   'and',
#   'right'],
#  'Buy': ['me'],
#  'Workinonit': ['♪'],
#  'Tune': ['up', '♪'],
#  'up': ['♪',
#   'here,',
#   'at',
#   'like,',
#   'suddenly.',
#   'and',
#   'sometimes.',
#   'to',
#   'to',
#   'weed.',
#   'in',
#   'in',
#   'and',
#   'shit',
#   'Mexicans',
#   'pussy.',
#   'without',
#   'every',
#   'called',
#   'and',
#   'real',
#   'in',
#   'the',
#   'to',
#   'front.',
#   'what',
#   '♪',
#   'with',
#   'in'],
#  'Oh': ['♪'],
#  'Fade': ['me'],
#  'Ah-ah,': ['ah-ah,',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah,',
#   'ah-ah',
#   'ah-ah,'],
#  'ah-ah,': ['ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah',
#   'ah-ah'],
#  'ah-ah': ['♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪'],
#  'In': ['every',
#   'every',
#   'every',
#   'every',
#   'every',
#   'every',
#   'a',
#   'fact,',
#   'every',
#   'every',
#   'every',
#   'every',
#   'every',
#   'every'],
#  'every': ['ghetto',
#   'ghetto',
#   'ghetto',
#   'ghetto',
#   'ghetto',
#   'ghetto',
#   'night!',
#   'fucking',
#   'goddamn',
#   'Thursday',
#   'ghetto',
#   'ghetto',
#   'ghetto',
#   'ghetto',
#   'athlete',
#   'ghetto',
#   'ghetto…'],
#  'ghetto': ['♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪', '♪'],
#  'Thank': ['you!', 'you', 'you', 'you,', 'you…', 'you', 'you', 'you.'],
#  'you!': ['Thank'],
#  'you': ['very',
#   'all.',
#   'can',
#   'through',
#   'might’ve',
#   'ever',
#   'saw',
#   'know',
#   'do',
#   'guys',
#   'like…',
#   'were',
#   'see',
#   'see',
#   'know',
#   'know,',
#   'guys',
#   'mind',
#   'to',
#   'to',
#   'just',
#   'drive',
#   'blow',
#   'blow',
#   'was',
#   'blow',
#   'the',
#   'haven’t',
#   'off',
#   'know,',
#   'about',
#   'got?',
#   'in',
#   'trying',
#   'thought',
#   'know,',
#   'don’t',
#   'know',
#   'for',
#   'make',
#   'hear',
#   '“brother”',
#   'a',
#   'with?”',
#   'a',
#   'mean,',
#   'can',
#   'have',
#   'would',
#   'know',
#   'don’t',
#   'shake',
#   'know,',
#   'know',
#   'gonna',
#   'look',
#   'know',
#   'see',
#   'know',
#   'know',
#   'think',
#   'say',
#   'to',
#   'this',
#   'want',
#   'want',
#   'is',
#   'guys',
#   'know',
#   'want',
#   'have,',
#   'imagine',
#   'are',
#   'what',
#   'again,',
#   'feel',
#   'young',
#   'guys',
#   'care',
#   'know',
#   'just',
#   'know',
#   'pro-choice?',
#   'anti-consequences?',
#   'something',
#   'imagine?',
#   'to',
#   'to',
#   'going',
#   'know',
#   'know',
#   'think',
#   'that',
#   'can’t',
#   'heard',
#   'found',
#   'need',
#   'believe',
#   'doing,',
#   'doing',
#   'guys',
#   'to',
#   'mad,',
#   'have',
#   'shut',
#   'understand',
#   'very',
#   'have',
#   'were',
#   'guys.',
#   'go,',
#   'guys.',
#   'for',
#   'can',
#   'can',
#   'can',
#   'please',
#   'like',
#   'to',
#   'inhale'],
#  'very': ['much!',
#   'long',
#   'strong,',
#   'mad',
#   'same',
#   'good',
#   'nice',
#   'uncomfortable.',
#   'not',
#   'loving',
#   'frivolous',
#   'hard',
#   'society',
#   'bad.',
#   'much!',
#   'long'],
#  'much!': ['Thank', 'Good'],
#  'all.': ['Oh,', 'He', 'That’s'],
#  'Oh,': ['wow.', 'it’s', 'shit!', 'that'],
#  'wow.': ['That'],
#  'was': ['exciting,',
#   'a',
#   'tough.',
#   'accustomed',
#   'booed',
#   'booed.',
#   'a',
#   'a',
#   'like,',
#   'like…',
#   'saying.',
#   'a',
#   'very',
#   'a',
#   'out',
#   'coming',
#   'wobbling',
#   'like,',
#   'fine.',
#   'driving',
#   'black,',
#   'fear',
#   'back',
#   'like,',
#   'like…',
#   'trying',
#   'so',
#   'taking',
#   'about',
#   'a',
#   'in',
#   'like,',
#   '.',
#   'like,',
#   'down',
#   'like,',
#   'very',
#   'the',
#   'gonna',
#   'supposed',
#   'supposed',
#   'on',
#   'the',
#   'on',
#   'like,',
#   'there.',
#   'excited.\nI',
#   'gonna',
#   'walking',
#   'filled',
#   'seeing.',
#   'seducing',
#   'sitting',
#   'obviously',
#   'from',
#   'definitely',
#   'like,',
#   'like,',
#   'like,',
#   'upset.',
#   'looking',
#   'like,',
#   'right',
#   'the',
#   'in',
#   'alone.',
#   'the',
#   'having',
#   'lucrative,',
#   'in',
#   'OJ',
#   'shocked.',
#   'me.',
#   'sitting',
#   'having',
#   'a',
#   'acquitted.',
#   'biblical',
#   'a',
#   'a',
#   'in.',
#   'about',
#   'like,',
#   'like,',
#   'a',
#   'amazing.',
#   'beating',
#   'on',
#   'gonna',
#   'gonna',
#   'scared.',
#   'ready.',
#   'ready.',
#   'wrong.',
#   'nice.',
#   'shocked!',
#   'a',
#   'like,',
#   'doing',
#   'playing',
#   'right',
#   'like,',
#   'a',
#   'there.',
#   'already',
#   'like,',
#   'scared.',
#   'nice',
#   'nice',
#   'filled',
#   'on',
#   '12',
#   'going',
#   'so',
#   'like…',
#   'a',
#   'Cold',
#   'for',
#   'growing',
#   'about',
#   'fucked',
#   'World',
#   'happening',
#   'the',
#   'a',
#   'LSD',
#   'a',
#   'chemically',
#   'only',
#   'gonna',
#   'gonna',
#   'gonna',
#   'never',
#   'shot',
#   'going',
#   'onstage',
#   'in',
#   'talking',
#   'saying.',
#   'rushing',
#   'horrified.',
#   'a',
#   'wrestling',
#   'involved.',
#   'a',
#   'in',
#   'going',
#   'attacking,',
#   'a',
#   'still',
#   'up',
#   'mad',
#   'as',
#   'at',
#   'furious.',
#   'fucking',
#   'maddening.',
#   'slapping',
#   'like,',
#   'scared',
#   'just',
#   'some',
#   'Tuesday',
#   'having',
#   'eating',
#   'like,',
#   'like…',
#   'a',
#   'hand-stitched,',
#   'like,',
#   'some',
#   'not',
#   'speaking',
#   'the',
#   'at',
#   'a',
#   'in',
#   'Chris',
#   'again.',
#   'like,'],
#  'exciting,': ['wasn’t'],
#  'wasn’t': ['it?', 'drunk.', 'doing', 'alone', 'a', 'gonna'],
#  'it?': ['Thank', '♪', '♪', '♪', 'To'],
#  'you,': ['guys.',
#   'it',
#   'Dave',
#   'the',
#   'that',
#   'of',
#   'young',
#   'you’d',
#   'young,',
#   'Dad.',
#   'brother.',
#   'that’s'],
#  'guys.': ['Have', 'I’m', 'It’s', 'Hey,', 'Let’s', 'My'],
#  'Have': ['a'],
#  'seat,': ['feel'],
#  'feel': ['comfortable,', 'it.”', 'safe.', 'that?', 'like…', 'like'],
#  'comfortable,': ['relax.'],
#  'relax.': ['I'],
#  'I': ['want',
#   'played',
#   'know!',
#   'know,',
#   'wasn’t',
#   'had',
#   'don’t',
#   'what',
#   'was',
#   'was',
#   'was',
#   'did',
#   'never',
#   'take',
#   'looked',
#   'was',
#   'can',
#   'knew',
#   'wasn’t',
#   'don’t',
#   'was',
#   'said,',
#   'said,',
#   'snapped',
#   'said,',
#   'get',
#   'didn’t',
#   'felt',
#   'took',
#   'said,',
#   'did?',
#   'bought',
#   'was',
#   'bomb,',
#   'had',
#   'wanted',
#   'almost',
#   'gave',
#   'decided',
#   'made',
#   'said,',
#   'haven’t',
#   'come',
#   'was',
#   'almost',
#   'was',
#   'guess',
#   'was',
#   'was',
#   'got',
#   'should',
#   'figured,',
#   'looked',
#   'looked',
#   'started',
#   'looked',
#   'knew,',
#   'thought',
#   'said,',
#   'said,',
#   'would',
#   'was',
#   'said,',
#   'said,',
#   'thought',
#   'said,',
#   'blew',
#   'said,',
#   'guess',
#   'said,',
#   'didn’t',
#   'drove',
#   'saw',
#   'watched',
#   'can’t',
#   'can’t',
#   'forgot',
#   'will',
#   'met',
#   'was',
#   'can’t',
#   'would',
#   'was',
#   'had',
#   'said,',
#   'ran',
#   'hope',
#   'was',
#   'don’t',
#   'should',
#   'whispered',
#   'didn’t',
#   'mean,',
#   'don’t',
#   'hold',
#   'was',
#   'don’t',
#   'was',
#   'know.',
#   'was',
#   'got',
#   'was',
#   'gonna',
#   'need',
#   'need',
#   'didn’t',
#   'make.',
#   'was',
#   'was',
#   'was',
#   'looked',
#   'said,',
#   'said,',
#   'said,',
#   'just',
#   'said,',
#   'haven’t',
#   'had',
#   'said.',
#   'went',
#   'went',
#   'couldn’t',
#   'was',
#   'was',
#   'don’t.',
#   'was',
#   'got',
#   'just',
#   'thought',
#   'said,',
#   'go,',
#   'don’t',
#   'said,',
#   'said,',
#   'have',
#   'have',
#   'said,',
#   'pat',
#   'know.',
#   'didn’t',
#   'met',
#   'was,',
#   'was',
#   'wasn’t',
#   'was',
#   'was',
#   'tend',
#   'was',
#   'later',
#   'watched',
#   'saw',
#   'saw.',
#   'was',
#   'didn’t',
#   'was',
#   'was',
#   'could',
#   'looked',
#   'said,',
#   'noticed',
#   'won’t',
#   'thought',
#   'mean?',
#   'mean?',
#   'mean?',
#   'mean.',
#   'mean.',
#   'mean.',
#   'say',
#   'know',
#   'take',
#   'took',
#   'don’t',
#   'don’t',
#   'thought',
#   'had',
#   'get',
#   'understand',
#   'empathize.',
#   'support',
#   'don’t',
#   'come',
#   'said,',
#   'was',
#   'didn’t',
#   'was',
#   'think–',
#   'think',
#   'see',
#   'don’t',
#   'miss',
#   'remember',
#   'ate?',
#   'didn’t',
#   'knew',
#   'heard',
#   'got',
#   'heard',
#   'was',
#   'didn’t',
#   'didn’t',
#   'was',
#   'was',
#   'was',
#   'know',
#   'used',
#   'met',
#   'met',
#   'was',
#   'was',
#   'don’t',
#   'walked',
#   'was',
#   'did',
#   'walked',
#   'looked–',
#   'saw',
#   'came',
#   'saw',
#   'was.',
#   'didn’t',
#   'didn’t',
#   'did',
#   'said,',
#   'didn’t',
#   'just',
#   'knew',
#   'walked',
#   'was',
#   'was',
#   'saw',
#   'said,',
#   'could',
#   'lived',
#   'lock',
#   'didn’t',
#   'answered',
#   'was',
#   'can’t',
#   'used',
#   'was',
#   'have',
#   'do',
#   'try',
#   'realize',
#   'was',
#   'was',
#   'was',
#   'talked',
#   'felt',
#   'was',
#   'just',
#   'didn’t',
#   'saw',
#   'just',
#   'was',
#   'said,',
#   'didn’t',
#   'said,',
#   'need',
#   'know.',
#   'need',
#   'would',
#   'started',
#   'said,',
#   'suffer.',
#   'suffer.',
#   'still',
#   'didn’t',
#   'don’t',
#   'don’t',
#   'would',
#   'didn’t',
#   'admit',
#   'like',
#   'don’t',
#   'didn’t',
#   'said,',
#   'was',
#   'know,',
#   'know.',
#   'knew',
#   'was',
#   'didn’t',
#   'found',
#   'was',
#   'need',
#   'freaked',
#   'wanted',
#   'said,',
#   'said,',
#   'said,',
#   'want',
#   'took',
#   'was',
#   'got.',
#   'do',
#   'said,',
#   'have',
#   'was',
#   'took',
#   'was',
#   'almost',
#   'haven’t',
#   'live',
#   'was',
#   'don’t',
#   'was',
#   'looked',
#   'want',
#   'got',
#   'realized–',
#   'looked',
#   'couldn’t',
#   'got',
#   'cannot',
#   'cannot',
#   'don’t',
#   'really',
#   'forgot,',
#   'got',
#   'got',
#   'have',
#   'can’t',
#   'remember',
#   'also',
#   'remember',
#   'remember',
#   'wouldn’t',
#   'heard,',
#   'heard',
#   'forgot.',
#   'met',
#   'was',
#   'quit',
#   'saw',
#   'can’t',
#   'just',
#   'need',
#   'kick',
#   'kick',
#   'kick',
#   'kick',
#   'instruct'],
#  'want': ['to',
#   'our',
#   'our',
#   'to',
#   'to',
#   'to',
#   'those',
#   'to',
#   'to',
#   'to',
#   'lunch.”',
#   'it',
#   'to',
#   'to',
#   'you'],
#  'to': ['thank',
#   'you,',
#   'say',
#   'me,',
#   'switch',
#   'break',
#   'charity.”',
#   'the',
#   'go',
#   'the',
#   'fuck',
#   'give',
#   'a',
#   'do',
#   'let',
#   'the',
#   'the',
#   'me?”',
#   'the',
#   'arrest',
#   'take',
#   'me?”',
#   'ask',
#   'step',
#   'have',
#   'get',
#   'the',
#   'go.”',
#   'court.',
#   'fight',
#   'fight.',
#   'thrive,',
#   'get',
#   'say',
#   'meet',
#   'meet',
#   'say',
#   'the',
#   'me.',
#   'you,”',
#   'get',
#   'see',
#   'see',
#   'be',
#   'raise',
#   'appear.\nUh…',
#   'the',
#   'go',
#   'Flint,',
#   'the',
#   'have',
#   'live,',
#   'the',
#   'happen.',
#   'ask',
#   'ask',
#   'watch',
#   'the',
#   'me.',
#   'pursue?”',
#   'tell',
#   'see.',
#   'run',
#   'let',
#   'save.',
#   'enjoy',
#   'say',
#   'see',
#   'voice',
#   'represent',
#   'animals.',
#   'appease',
#   'all',
#   'see',
#   'the',
#   'the',
#   'the',
#   'ask,',
#   'tone',
#   'understand.”',
#   'take',
#   'me',
#   'have',
#   'take',
#   'crap',
#   'pass',
#   'bridge.',
#   'the',
#   'feel',
#   'do',
#   'us,',
#   'the',
#   'you,',
#   'the',
#   'do?”',
#   'find',
#   'the',
#   'me–',
#   'start',
#   'OJ,',
#   'let',
#   'me.',
#   'my',
#   'be',
#   'see',
#   'the',
#   'take',
#   'break',
#   'you.',
#   'know',
#   'strike.\nI',
#   'one',
#   'five',
#   'care',
#   'care.',
#   'watch',
#   'be',
#   'shoot',
#   'be',
#   'get',
#   'think',
#   'myself,',
#   'go,',
#   'Europe',
#   'be',
#   'be',
#   'come',
#   'America',
#   'run',
#   'have',
#   'be',
#   'get',
#   'me,',
#   'know…',
#   'know.',
#   'see',
#   'take',
#   'yell',
#   'each',
#   'Egypt.”',
#   'me.',
#   'think',
#   'yourself,',
#   'rape.”',
#   'believe',
#   'destroy',
#   'something!',
#   'kill',
#   'town,',
#   'see',
#   'go',
#   'the',
#   'his',
#   'meet',
#   'knock',
#   'see',
#   'meet',
#   'eat',
#   'see',
#   'have',
#   'join',
#   'my',
#   'have',
#   'bed!”',
#   'have',
#   'tell',
#   'shut',
#   'take',
#   'ever',
#   'make',
#   'the',
#   'make',
#   'African-American',
#   'college.',
#   'remember,',
#   'see',
#   'see',
#   'survive',
#   'acknowledge',
#   'you',
#   'rap',
#   'rhythms',
#   'be'],
#  'thank': ['everyone'],
#  'everyone': ['in', 'get', 'in', 'starts'],
#  'in': ['LA',
#   'Detroit.”',
#   'a',
#   'her',
#   'the',
#   'LA,',
#   'Hollywood,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'a',
#   'this',
#   'my',
#   'my',
#   'that',
#   'LA',
#   'traffic.',
#   'her',
#   'more',
#   'the',
#   'Wisconsin.',
#   'the',
#   'the',
#   'my',
#   'Santa',
#   'your',
#   'her',
#   'a',
#   'this',
#   'Flint,',
#   'Flint.',
#   'Flint',
#   'ten',
#   'that',
#   'San',
#   'San',
#   'love',
#   'a',
#   'Beverly',
#   'the',
#   'the',
#   'the',
#   'that',
#   'the',
#   'my',
#   'his',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'traffic',
#   'federal',
#   'Hollywood.',
#   'American',
#   'the',
#   'LA.',
#   'Brooklyn–',
#   'Hollywood.',
#   'the',
#   'there,',
#   'her',
#   'life.',
#   'Miami,',
#   'his',
#   'there!',
#   'my',
#   'the',
#   'your',
#   'the',
#   'human',
#   'on',
#   'the',
#   'the',
#   'Europe–',
#   'the',
#   'Europe,',
#   'America,',
#   'a',
#   'front',
#   'Dallas.',
#   'the',
#   'the',
#   'Mississippi,',
#   'it.',
#   'Syracuse,',
#   'the',
#   'full',
#   'the',
#   'this',
#   'that.',
#   'this',
#   'the',
#   'on',
#   'Africa,”',
#   'this',
#   'several',
#   'the',
#   'television.',
#   'spectacular',
#   'that',
#   'comedy',
#   'the',
#   'the',
#   'peace',
#   'layers'],
#  'LA': ['for', 'in'],
#  'wonderful': ['week.', 'time.'],
#  'week.': ['It’s', 'So,'],
#  'It’s': ['been',
#   'been',
#   'fucked',
#   'very',
#   'good',
#   'me.',
#   'actually',
#   'called',
#   'about',
#   'true.',
#   'upsetting',
#   'for',
#   'for',
#   'easier',
#   'time',
#   'the',
#   'a',
#   'good',
#   'a'],
#  'been': ['great',
#   'ten',
#   'gone',
#   'through,',
#   'hanging',
#   'working',
#   'in!',
#   'watching',
#   'to',
#   'working',
#   'on',
#   'drawing',
#   'fucking',
#   'in'],
#  'great': ['here.', 'shit.', 'in', 'for'],
#  'here.': ['You', 'Listen…'],
#  'You': ['know',
#   'will',
#   'know',
#   'get',
#   'know',
#   'see',
#   'can',
#   'see',
#   'the',
#   'got',
#   'understand',
#   'know',
#   'know',
#   'don’t',
#   'know',
#   'know',
#   'sure',
#   'can',
#   'don’t',
#   'don’t',
#   'don’t',
#   'gotta',
#   'know,',
#   'remember',
#   'remember.',
#   'kids',
#   'didn’t',
#   'could',
#   'suffer,',
#   'was',
#   'just',
#   'suffer,',
#   'suffer,',
#   'ever',
#   'guys',
#   'know,',
#   'know',
#   'know',
#   'ready?',
#   'wouldn’t'],
#  'know': ['what?',
#   'if',
#   'if',
#   'anything',
#   'what',
#   'what',
#   'there',
#   'a',
#   'that',
#   'the',
#   'what',
#   'who',
#   'what',
#   'what–',
#   'if',
#   'this,',
#   'the',
#   'what',
#   'what',
#   'what',
#   'what',
#   'what',
#   'these',
#   'why',
#   'what’s',
#   'that',
#   'what?',
#   'shit',
#   'they’re',
#   'how',
#   'he',
#   'what?',
#   'black',
#   'if',
#   'the',
#   'I',
#   'what?',
#   'shit.',
#   'shit!',
#   'who',
#   'the',
#   'every',
#   'that',
#   'how',
#   'what',
#   'about',
#   'that',
#   'we',
#   'that',
#   'what',
#   'why?',
#   'Kevin',
#   'if',
#   'How',
#   'how'],
#  'what?': ['It’s', 'At', 'I’m', 'I', 'I’ve'],
#  'ten': ['years', 'years.', 'years.', 'or'],
#  'years': ['since', 'old,', 'old.', 'from', 'old,'],
#  'since': ['the'],
#  'last': ['time', 'nigga', 'Wednesday.', 'one', 'year,', 'time', 'thing.'],
#  'time': ['I',
#   'I',
#   'I',
#   'doing',
#   'in',
#   'I',
#   'I',
#   'to',
#   'that',
#   'in',
#   'for',
#   'I',
#   'I',
#   'is',
#   'I’d'],
#  'played': ['Los', 'Who'],
#  'Los': ['Angeles,'],
#  'Angeles,': ['if'],
#  'if': ['you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you’re',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'a',
#   'you’ve',
#   'you',
#   'I',
#   'she',
#   'you',
#   'you',
#   'you',
#   'you’d',
#   'you’re'],
#  'can': ['imagine.',
#   'feel',
#   'impound',
#   'see',
#   'look',
#   'just',
#   'fly',
#   'agree',
#   'make',
#   'believe',
#   'go',
#   'you',
#   'you',
#   '♪',
#   '♪',
#   '♪'],
#  'imagine.': ['I', 'It’d'],
#  'know!': ['I'],
#  'know,': ['I’ve',
#   'shit',
#   'I’ve',
#   'I’m',
#   'I',
#   'fuck',
#   'I',
#   'I’m',
#   'people',
#   'I',
#   'I',
#   '’cause'],
#  'I’ve': ['been',
#   'been',
#   'been',
#   'been',
#   'met',
#   'been',
#   'noticed',
#   'got',
#   'known',
#   'never',
#   'had',
#   'ever'],
#  'gone': ['for', 'horribly', '♪'],
#  'long': ['time.',
#   'bomb.',
#   'for',
#   'time.',
#   'time.',
#   'touch,',
#   'face?”',
#   'way',
#   'ago.',
#   'time.”',
#   'story.'],
#  'time.': ['And',
#   'And',
#   'The',
#   'And',
#   'And',
#   'And',
#   'I',
#   'And',
#   'I’m',
#   'It’s',
#   'You'],
#  'And': ['unbeknownst',
#   'that',
#   'in',
#   'then,',
#   'then',
#   'I',
#   'I',
#   'then,',
#   'he',
#   'I',
#   'then',
#   'the',
#   'the',
#   'then',
#   'I',
#   'it',
#   'he',
#   'this',
#   'you',
#   'before',
#   'you’re',
#   'I',
#   'I',
#   'I',
#   'then',
#   'he',
#   'he',
#   'that',
#   'he’s',
#   'he',
#   'in',
#   'suddenly,',
#   'then,',
#   'then',
#   'I',
#   'the',
#   'he',
#   'we',
#   'I',
#   'we',
#   'I',
#   'when',
#   'you',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'then',
#   'I’m',
#   'my',
#   'we',
#   'he',
#   'as',
#   'she',
#   'she',
#   'when',
#   'the',
#   'them',
#   'when',
#   'then',
#   'then',
#   'a',
#   'it’s',
#   'while',
#   'for',
#   'he',
#   'they',
#   'while',
#   'I',
#   'a',
#   'then,',
#   'I’ll',
#   'this',
#   'I',
#   'she',
#   'there',
#   'we',
#   'then',
#   'one',
#   'then',
#   'my',
#   'he',
#   'his',
#   'Beyoncé',
#   'I',
#   'he',
#   'then',
#   'we',
#   'then,',
#   'at',
#   'for'],
#  'unbeknownst': ['to'],
#  'it': ['was',
#   'was',
#   'you',
#   'was.',
#   'looks',
#   'out',
#   'and',
#   'all',
#   'was',
#   'up.',
#   'made',
#   'all',
#   'didn’t',
#   'on',
#   'out.',
#   'would’ve',
#   'bring',
#   'to',
#   'was',
#   'called?”',
#   'a',
#   'at',
#   'out',
#   'just',
#   'was',
#   'with',
#   'was–',
#   'discriminates',
#   'and',
#   'is,',
#   'on',
#   'filled',
#   'was',
#   'on',
#   'take',
#   'all',
#   'all',
#   'probably',
#   'for',
#   'at',
#   'was',
#   'all',
#   'is.',
#   'works.\nCan’t',
#   'looks',
#   'correctly,',
#   'feels',
#   'to',
#   'is.',
#   'was.',
#   'was',
#   'comes'],
#  'difficult': ['ten', 'time'],
#  'years.': ['I’m', 'What', 'They'],
#  'I’m': ['not',
#   'not',
#   'black,',
#   'also',
#   'good.”',
#   'one',
#   'just',
#   'happy,',
#   'on',
#   'sorry,',
#   'with',
#   'just',
#   'smoking,',
#   'like,',
#   'not',
#   'dropping',
#   'just',
#   'just',
#   'not',
#   'just',
#   'not',
#   '‘Q.’',
#   'saying.',
#   'sorry,',
#   '42.',
#   'just',
#   'glad',
#   'from',
#   'from',
#   'getting',
#   'crying',
#   'not',
#   'sorry,',
#   'gonna',
#   'like,',
#   'like,',
#   'like,',
#   'not',
#   'telling',
#   'saying?',
#   'just',
#   'gone',
#   'a',
#   'rich,'],
#  'not': ['gonna',
#   'leave.',
#   'only',
#   'to.',
#   'bullshitting.',
#   'bad,',
#   'gonna',
#   'supposed',
#   'a',
#   'nice',
#   'there',
#   'the',
#   'your',
#   'nice',
#   'gay,',
#   '‘G.’',
#   'believe',
#   'to',
#   'even',
#   'to',
#   'mind-controlling.',
#   'too',
#   'only',
#   'be',
#   'thinking',
#   'like',
#   'forget.',
#   'forget.',
#   'defending',
#   'one',
#   'the',
#   'acknowledge'],
#  'gonna': ['take',
#   'bomb,',
#   'give',
#   'happen',
#   'happen',
#   'have',
#   'make',
#   'come',
#   'do',
#   'get',
#   'take',
#   'like',
#   'do',
#   'do',
#   'watch',
#   'let',
#   'usher',
#   'avoid',
#   'end',
#   'kick',
#   'do'],
#  'take': ['you',
#   'two',
#   'long',
#   'the',
#   'our',
#   'the',
#   'my',
#   'your',
#   'some',
#   'a',
#   'the',
#   'a',
#   'off.”',
#   'offense.',
#   'a'],
#  'through': ['all', 'the', 'all', 'the'],
#  'all': ['the',
#   'it',
#   'week',
#   'over',
#   'worked',
#   'worked',
#   'right.',
#   'it',
#   'people,',
#   'over',
#   'the',
#   'this',
#   'gorgeous.',
#   'the',
#   'of',
#   'due',
#   'Americans,',
#   'over',
#   'those',
#   'that',
#   'their',
#   'that',
#   'the',
#   'those',
#   'I’m',
#   'that,',
#   'said,',
#   'started',
#   'looked',
#   'too',
#   'need',
#   'gonna',
#   'the',
#   'this',
#   'really',
#   'different',
#   'fucking',
#   'had',
#   'the',
#   'this',
#   'because',
#   'have',
#   'these',
#   'the',
#   'the',
#   'the',
#   'still',
#   'over',
#   'fast,',
#   'of',
#   'the',
#   'get'],
#  'agony': ['I’ve'],
#  'through,': ['but'],
#  'but': ['it',
#   'their',
#   'niggas',
#   'for',
#   'I’d',
#   'then,',
#   'I',
#   'I’m',
#   'we',
#   'the',
#   'more',
#   'he',
#   'the',
#   'I',
#   'I',
#   'it',
#   'there',
#   'nowhere',
#   'I’ll',
#   'the',
#   'if',
#   'I',
#   'they',
#   'not',
#   'just',
#   'not',
#   'I',
#   'can',
#   'you’re',
#   'haven’t',
#   'he',
#   'it'],
#  'tough.': ['Some', 'You'],
#  'Some': ['of', 'guys,', 'people', 'people'],
#  'might’ve': ['seen.\nI', 'done'],
#  'seen.\nI': ['don’t'],
#  'don’t': ['know',
#   'know',
#   'know',
#   'remember',
#   'know',
#   'know',
#   'fuck',
#   'see',
#   'know',
#   'know',
#   'have',
#   'understand.',
#   'know',
#   'have',
#   'like,',
#   'understand.',
#   'like',
#   'really',
#   'mind',
#   'understand',
#   'know',
#   'remember',
#   'know',
#   'know',
#   'plan',
#   'know.',
#   'feel',
#   'like',
#   'forget',
#   'know',
#   'have',
#   'want',
#   'know,',
#   'know',
#   'even'],
#  'ever': ['saw',
#   'been',
#   'since.',
#   'been,',
#   'met.',
#   'dreamed',
#   'spoken',
#   'forget,',
#   'played',
#   'makes',
#   'win',
#   'admired'],
#  'saw': ['on',
#   'it,',
#   'me.',
#   'that',
#   'a',
#   'my',
#   'him',
#   'recognition',
#   'with',
#   'her,',
#   'this',
#   'me',
#   'a'],
#  'on': ['TMZ',
#   'to',
#   'for',
#   'that',
#   'my',
#   'the',
#   'the',
#   'the',
#   'rush',
#   'the',
#   'Netflix,',
#   'four',
#   'the',
#   'my',
#   'my',
#   'the',
#   'strike.',
#   'his',
#   'cash.',
#   'fire.',
#   'Monday.”',
#   'planet',
#   'their',
#   'fucking',
#   'the',
#   'their',
#   'the',
#   'the',
#   'my',
#   'the',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'to',
#   'television.',
#   'board,',
#   'their',
#   'the',
#   'the',
#   'Earth',
#   'the',
#   'and',
#   'the',
#   'the',
#   'the',
#   'his',
#   'back.',
#   'the',
#   '“K-Hart”',
#   'all',
#   'Google.',
#   'his',
#   'the'],
#  'TMZ': ['the'],
#  'big': ['headline:', 'favor'],
#  'headline:': ['“Dave'],
#  '“Dave': ['Chappelle', 'Chappelle!”'],
#  'Chappelle': ['Drunk'],
#  'Drunk': ['Onstage'],
#  'Onstage': ['in'],
#  'Detroit.”': ['Well,'],
#  'Well,': ['if', 'I', 'you', 'yeah,', 'I’m'],
#  'it,': ['I',
#   'but',
#   'check',
#   'all',
#   'but',
#   'but',
#   'saw',
#   'though.',
#   'I',
#   'they’ll',
#   'I'],
#  'drunk.': ['I'],
#  'had': ['smoked',
#   'that',
#   'to',
#   'a',
#   'gone',
#   'to',
#   '$200,000',
#   'done',
#   'a',
#   'to',
#   'a',
#   'nothing',
#   'a',
#   'a',
#   'different',
#   'to',
#   'grown.',
#   'ever',
#   'raped',
#   'raped',
#   'raped',
#   'a',
#   'a',
#   'a',
#   'a',
#   'his'],
#  'smoked': ['some'],
#  'some': ['reefer…',
#   'rappers.',
#   'reason–',
#   'reason,',
#   'Vans',
#   'trouble,',
#   'shit.',
#   'outlandish',
#   'analogies',
#   'off.',
#   'advice',
#   'kind',
#   'crazy',
#   'cold',
#   'cold',
#   'reason,'],
#  'reefer…': ['with'],
#  'with': ['some',
#   'rappers,',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'me',
#   'the',
#   'The',
#   'so',
#   'the',
#   'powers',
#   'him.',
#   'this',
#   'that?”',
#   'my',
#   'my',
#   'and',
#   'the',
#   'that',
#   'all',
#   'that',
#   'no',
#   'his',
#   'my',
#   'a',
#   'pride',
#   'my',
#   'warmth',
#   'America’s',
#   'a',
#   'her?',
#   'you,',
#   'butter',
#   'black',
#   'a',
#   'one',
#   'you.”',
#   'me'],
#  'rappers.': ['Yeah.'],
#  'Yeah.': ['I', 'Yeah,', 'If', 'Yeah,', 'Well,'],
#  'anything': ['about',
#   'to',
#   'wrong.',
#   'like',
#   'like',
#   'to',
#   'when',
#   'that',
#   'was'],
#  'about': ['hanging',
#   'a',
#   'each',
#   'this',
#   'that',
#   'to',
#   'a',
#   'gay',
#   'a',
#   'to',
#   'this',
#   'it.',
#   'anything',
#   'Paris,',
#   'a',
#   'each',
#   'what',
#   'it.',
#   'Bill',
#   'him',
#   'what',
#   'discrimination?”',
#   'comparative',
#   'Egypt.”',
#   'to',
#   'to'],
#  'hanging': ['out', 'out'],
#  'out': ['with',
#   'of',
#   'to',
#   'in–',
#   'here',
#   'and',
#   'here',
#   'of',
#   'of',
#   'of',
#   'of',
#   'that',
#   'in',
#   'the',
#   'loud,',
#   'of',
#   'of',
#   'of',
#   'of',
#   '“Q”',
#   'and',
#   'of',
#   'of',
#   'of',
#   'at',
#   'of',
#   'that',
#   'of',
#   'in',
#   'to',
#   '40',
#   'the',
#   'of',
#   'for',
#   'the'],
#  'rappers,': ['but'],
#  'their': ['weed',
#   'faces',
#   'vaginas.',
#   'faces.',
#   'disgust',
#   'mothers.',
#   'money',
#   'thumbs,',
#   'wives’',
#   'manhood',
#   'leader.',
#   'character.',
#   'stomachs,',
#   'chests…',
#   'dicks',
#   'gender.',
#   'stomachs.',
#   'lips'],
#  'weed': ['is'],
#  'strong,': ['stronger', 'he'],
#  'stronger': ['than', 'than'],
#  'than': ['I',
#   'to',
#   'any',
#   'Superman',
#   'Superman.',
#   'he',
#   'Asia.',
#   'they',
#   'that.',
#   'he'],
#  'what': ['I',
#   'it',
#   'I',
#   'I',
#   'anybody',
#   'happened.',
#   'happened.',
#   'made',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'that',
#   'you',
#   'I',
#   'the',
#   'they',
#   'I',
#   'it',
#   'it',
#   'Kevin',
#   'I',
#   'I’m',
#   'you'],
#  'accustomed': ['to.'],
#  'to.': ['The', 'But', 'But', 'Security'],
#  'The': ['article',
#   'whole',
#   'old',
#   'cops',
#   'body',
#   'City',
#   'Steven',
#   'motherfucker',
#   'first',
#   'Daily',
#   'Daily',
#   'other',
#   'truth',
#   'only',
#   'Texan',
#   'Texan’s',
#   'second',
#   'restaurant',
#   'glove',
#   'glove',
#   'men,',
#   'Nike',
#   'last',
#   'third',
#   'third',
#   'Improv.',
#   'Juice.',
#   'show',
#   'conversation',
#   'Russians',
#   'age',
#   'ladies',
#   '’70s',
#   'only',
#   'lights',
#   'crowd',
#   'longer',
#   'crowd',
#   'point',
#   'fourth',
#   'fourth',
#   'Juice.'],
#  'article': ['goes'],
#  'goes': ['on', 'on.', 'fucking', 'crazy.'],
#  'say': ['I',
#   'that.',
#   'this–',
#   'that,',
#   'it',
#   'this',
#   'something',
#   'anything',
#   'nothing',
#   'that,',
#   'to'],
#  'booed': ['offstage,'],
#  'offstage,': ['which'],
#  'which': ['is', 'really', 'is'],
#  'also': ['incorrect.', 'Dave', 'remember'],
#  'incorrect.': ['I'],
#  'booed.': ['I'],
#  'did': ['not',
#   'I',
#   'give',
#   'it,',
#   'this',
#   'it,',
#   'a',
#   'all',
#   'the',
#   'niggas',
#   'that.',
#   'my',
#   'that',
#   'everyone',
#   'it.',
#   'she'],
#  'leave.': ['It'],
#  'bomb.': ['It'],
#  'fucking': ['nightmare.',
#   'money',
#   'with',
#   'poisonous.',
#   'superhero?',
#   'Key',
#   'green',
#   'sucked.',
#   'Japan,',
#   'emasculated.\nAnd',
#   'shoes',
#   'rude',
#   'war',
#   'us.',
#   'exploded!',
#   'day.',
#   'cartoon',
#   'group',
#   'just',
#   'brains',
#   'dog.',
#   'asshole',
#   'charging',
#   'horrifying',
#   'dead-end',
#   'nuts.',
#   'outstanding.',
#   'holding',
#   'sucks!”',
#   'spread.',
#   'juggernaut'],
#  'nightmare.': ['Two'],
#  'Two': ['puffs', 'puffs.'],
#  'puffs': ['of', 'of'],
#  'weed,': ['that’s', 'I'],
#  'that’s': ['all',
#   'the',
#   'what',
#   'why',
#   'the',
#   'what',
#   'fucked',
#   'a',
#   'still',
#   'over',
#   'a',
#   'too',
#   'no',
#   'what'],
#  'was.': ['Two', 'And', 'I', 'I', '“What?'],
#  'puffs.': ['I'],
#  'never': ['had',
#   'get',
#   'happen–',
#   'been',
#   'seen',
#   'seen',
#   'the',
#   'mind',
#   'met'],
#  'happen,': ['where'],
#  'two': ['puffs', 'Hollywood', 'atomic', 'mother-in-laws', 'dozen', 'fingers'],
#  'looked': ['at',
#   'at',
#   'through',
#   'good.',
#   'back',
#   'at',
#   'back,',
#   'in',
#   'back',
#   'at',
#   'at',
#   'at',
#   'over',
#   'up'],
#  'at': ['the',
#   'you',
#   'Detroit',
#   'my',
#   'it.',
#   'police',
#   'other',
#   'my',
#   'first,',
#   'all.',
#   'us.',
#   'this',
#   'my',
#   'history,',
#   'all',
#   'track',
#   'us',
#   'each',
#   'all',
#   'us.',
#   'all.',
#   'the',
#   'Kent',
#   'first,',
#   'me,',
#   'a',
#   'it',
#   'Kevin,',
#   'home',
#   'an',
#   'me',
#   'that',
#   'best.',
#   'the',
#   'this',
#   'that',
#   'the'],
#  'guy': ['next',
#   'called',
#   'stood',
#   'from',
#   'is',
#   'from',
#   'you’re',
#   'talks',
#   'your',
#   'your',
#   'on',
#   'had',
#   'to'],
#  'next': ['to', 'night', 'time.', 'thing', 'best'],
#  'me,': ['I',
#   'brother.”',
#   'brother.',
#   'sir.',
#   'I',
#   '“Women',
#   'I',
#   'the',
#   'and'],
#  'like,': ['“I’m',
#   '“What',
#   '“Hey,',
#   '“All',
#   '“We’re',
#   '“No,',
#   '“I',
#   '“Santa',
#   '“Hey,',
#   '“Hey,',
#   '“Man,',
#   '“So',
#   '“Hey,',
#   '“Sure,',
#   '“Yeah,',
#   '“Really?!',
#   '‘Same',
#   '“I',
#   '“You',
#   '“Man,',
#   '“Here’s',
#   'they’ll',
#   '“Niggas,',
#   '“What',
#   '“What?',
#   '“Man,',
#   '“How',
#   '“Hooray!”',
#   '“How',
#   '“That',
#   'three',
#   '“No”',
#   'minutes.',
#   '“Oh,',
#   '“Well,',
#   '“Man…',
#   '“Oh,',
#   '“I',
#   '“Damn,',
#   '“Man,',
#   '“Oh,',
#   '“Actually,',
#   '“Slow',
#   '“Thanks,',
#   '“Kevin,',
#   '“Dave,',
#   '“No.'],
#  '“I’m': ['gonna', 'like', 'gonna'],
#  'bomb,': ['nigga.', 'I'],
#  'nigga.': ['I', 'Let’s', 'I’m', 'I’m', 'Wu-Tang!'],
#  'it.”': ['And', 'I'],
#  'called': ['my', 'Duh!', 'my', 'Same', 'me', '“LBGTQ!”', 'Care'],
#  'my': ['name.',
#   'cha-cha,',
#   'friend',
#   'car,',
#   'fear.',
#   'friend',
#   'God.',
#   'breathalyzer–”',
#   'breathalyzer',
#   'mind',
#   'life.',
#   'shows.',
#   'guess.',
#   'own',
#   'way',
#   'way',
#   'show',
#   'God.',
#   'bluff.',
#   'attention.”',
#   'card.',
#   'agents.',
#   'agents,',
#   'black',
#   'hand.',
#   'eyes,',
#   'agents,',
#   'wife',
#   'wife',
#   'wife',
#   'couch,',
#   'wife,',
#   'motherfucking',
#   'cereal',
#   'show.',
#   'friends',
#   'own',
#   'experience,',
#   'friends.',
#   'friends',
#   'God!',
#   'God,',
#   'God.”',
#   'son',
#   'son',
#   'son',
#   'God.”',
#   'son',
#   'son.',
#   'son',
#   'career',
#   'man',
#   'Tribe',
#   'mayor?'],
#  'name.': ['“Dave'],
#  'Chappelle!”': ['Niggas', 'I'],
#  'Niggas': ['was'],
#  'like…': ['Normally,',
#   'That’s',
#   'And',
#   '“I’ll',
#   'murder',
#   '“You',
#   'Then',
#   '“♪'],
#  'Normally,': ['when'],
#  'when': ['you',
#   'someone',
#   'I',
#   'I',
#   'he’s',
#   'he',
#   'I',
#   'tragedy',
#   'you',
#   'I',
#   'shit',
#   'we',
#   'we',
#   'the',
#   'she',
#   'my',
#   'I',
#   'Martin'],
#  'do': ['a',
#   'it',
#   'it,',
#   'with',
#   'anything',
#   'about',
#   'you',
#   'my',
#   'you',
#   'all',
#   'that.',
#   'you',
#   'that.',
#   'it,',
#   'business',
#   'that',
#   'it',
#   'well',
#   'comparative',
#   'that',
#   'you',
#   'this,',
#   'that.',
#   'this'],
#  'comedy': ['show–', 'club', 'fans.', 'this'],
#  'show–': ['you', 'thousands'],
#  'guys': ['don’t', 'doing', 'were', 'knew.', 'need', 'are', 'ate,'],
#  'looks': ['like', 'very', 'back'],
#  'like': ['up',
#   'Evel',
#   'if',
#   'that:',
#   'he',
#   'OJ',
#   'you',
#   'they',
#   'a',
#   'to',
#   'to',
#   'it',
#   'that',
#   'Superman,',
#   'the',
#   'it.',
#   '’em.',
#   'the',
#   'that.',
#   'the',
#   'it.',
#   'it.',
#   'the',
#   'teddy',
#   'people,',
#   'inside.',
#   'those',
#   'that.',
#   'it.”\nAnd',
#   'that.',
#   'a',
#   'the',
#   'the',
#   'that',
#   'that',
#   'you.”',
#   'me.',
#   'us.”',
#   'your',
#   'to',
#   'chocolate',
#   'seeing',
#   'the'],
#  'here,': ['but', 'and', 'they', 'right'],
#  'niggas': ['be', 'didn’t', 'last', 'into'],
#  'be': ['just',
#   'good.”',
#   'hungry.',
#   'like',
#   'careful',
#   'fine.',
#   'called',
#   'like,',
#   'my',
#   'in',
#   'here',
#   'on',
#   'like,',
#   'out,',
#   'a',
#   'scared',
#   'horrified.',
#   'going.',
#   'like',
#   'like',
#   'angry,',
#   'real,',
#   'crass–',
#   'famous.',
#   'a',
#   'honest.',
#   'held',
#   'honest,',
#   'like,',
#   'remiss',
#   'as',
#   'like,',
#   'Katt',
#   'like,',
#   'about.',
#   'true.',
#   'like,',
#   'like…',
#   'like',
#   'my',
#   'doing',
#   'the'],
#  'just': ['looking',
#   'took',
#   'rolled',
#   'take',
#   'stepping',
#   'gonna',
#   'give',
#   'gave',
#   'how',
#   'kidding.',
#   'want',
#   'want',
#   'wondering',
#   'tell.',
#   'started',
#   'falls',
#   'a',
#   'came',
#   'can’t',
#   'telling',
#   'judging',
#   'not',
#   'sucking',
#   'be',
#   'to',
#   'walk',
#   'get',
#   'finished',
#   'gave',
#   'telling',
#   'walked',
#   'from',
#   'for',
#   'give',
#   'walked',
#   'determined',
#   'trying',
#   'to',
#   'felt',
#   'saw',
#   'not',
#   'kept',
#   'like',
#   'don’t',
#   'standing',
#   'wanted',
#   'about',
#   'remember',
#   'throw',
#   'the',
#   'wanted',
#   'shouting'],
#  'looking': ['up', 'amongst', 'at', 'mean', 'at.', 'at'],
#  'That’s': ['how',
#   'odd.',
#   'like',
#   'all',
#   'how',
#   'the',
#   'why',
#   'all',
#   'Dave',
#   'right.',
#   'the',
#   'right.',
#   'a',
#   'right.',
#   'a',
#   'how',
#   'Jay',
#   'the'],
#  'how': ['the', 'OJ', 'polarizing', 'much', 'he', 'the', 'it', 'much'],
#  'show': ['started.',
#   'sucks!”',
#   'every',
#   'went',
#   'didn’t',
#   'went',
#   'was',
#   'that'],
#  'started.': ['Didn’t'],
#  'Didn’t': ['take', 'want'],
#  'faces': ['to'],
#  'switch': ['up'],
#  '“What': ['the', 'publication', 'do', 'the'],
#  'fuck?”': ['They'],
#  'They': ['started',
#   'said,',
#   'answered',
#   'beat',
#   'didn’t',
#   'were',
#   'all',
#   'were',
#   'were',
#   'cared',
#   'all',
#   'got',
#   'were',
#   'fucked',
#   'tested',
#   'didn’t',
#   'were'],
#  'started': ['looking',
#   'chanting,',
#   'off',
#   'fucking',
#   'making',
#   'talking.',
#   'in',
#   'testing',
#   'to'],
#  'amongst': ['themselves.', 'them', 'yourselves,'],
#  'themselves.': ['So', 'Gay'],
#  'So': ['I', 'long,', 'you'],
#  'knew': ['I', 'I', 'before', 'who', 'he', 'that', 'Kevin'],
#  'doing': ['good.', 'tonight?”', 'really', 'that', 'great', 'in', 'us'],
#  'good.': ['I', 'Just'],
#  'remember': ['what',
#   'him?”',
#   'meeting',
#   'Bruce',
#   'that.',
#   'I',
#   'these',
#   'that',
#   'that',
#   'that',
#   'that',
#   'that'],
#  'saying.': ['It', 'Because', 'I'],
#  'took': ['one', 'half', 'his', 'my', 'him', 'him', 'us'],
#  'one': ['person',
#   'of',
#   'of',
#   'seemed',
#   'was',
#   'remembers',
#   'of',
#   'with',
#   'of',
#   'was',
#   'of',
#   'of',
#   'of',
#   'of',
#   'cop',
#   'happens,',
#   'happens,',
#   'happens.',
#   'of',
#   'that',
#   'opening',
#   'of',
#   'was',
#   'of',
#   'negative',
#   'another,'],
#  'person': ['to', 'in', 'in', 'live'],
#  'break': ['the', 'from', 'just'],
#  'ice.': ['It'],
#  'black': ['lady',
#   'people.',
#   'woman’s',
#   'dude,',
#   'juror.',
#   'dude',
#   'dude',
#   'people',
#   'people',
#   'people',
#   'people',
#   'celebrities',
#   'press',
#   'person',
#   'face',
#   'dude.',
#   'American,',
#   'people',
#   'dudes',
#   'people',
#   'men,',
#   'men,',
#   'man',
#   'comedian.\nObviously,',
#   'man',
#   'characters',
#   'kids'],
#  'lady': ['with', 'that'],
#  'Ford': ['Motor'],
#  'Motor': ['shirt'],
#  'shirt': ['on.'],
#  'on.': ['Stood', 'You', 'Then'],
#  'Stood': ['up'],
#  'suddenly.': ['“Fuck'],
#  '“Fuck': ['you,', 'you!”\nThis'],
#  'said,': ['“Excuse',
#   '“I',
#   '“Oh,',
#   '“I’m',
#   '“Fuck',
#   '“I’m',
#   '“Not',
#   '“That',
#   '“Oh,',
#   '“Mr.',
#   '“Excuse',
#   '“If',
#   '“Oh,',
#   '“Uh…',
#   '“Uh-oh.”',
#   '“Oh,',
#   '“I',
#   '“What?',
#   '“I',
#   '“Uh-oh.”',
#   '“I',
#   '“What',
#   '“Me?',
#   '“Daily',
#   '“Listen,',
#   '“Boycott?',
#   '“I',
#   '“Because,',
#   '“What?',
#   '“Well,',
#   '“The',
#   '“Sharon,',
#   '“Why',
#   '“Because',
#   '“Good',
#   '“Yay!”',
#   '“You',
#   '“Thanks,',
#   '“Yeah,',
#   '“No.',
#   '“Good',
#   '“Class,',
#   '“Oh,',
#   '“I',
#   '“Come',
#   '“These',
#   '“Dad,',
#   '“No,',
#   '“How',
#   '“They’re',
#   '“God',
#   '“Why',
#   '“Come',
#   '“Hey,'],
#  '“Excuse': ['me?”', 'me?”', 'me,', 'me,'],
#  'me?”': ['She', 'And', '“You’re', 'He'],
#  'She': ['said,',
#   'didn’t',
#   'was',
#   'actually',
#   'said,',
#   'goes,',
#   'has',
#   'was',
#   'didn’t',
#   'just',
#   'goes,'],
#  '“I': ['worked',
#   'am?”',
#   'think',
#   'think',
#   'just',
#   'have',
#   'like',
#   'don’t',
#   'know.”',
#   'know.”',
#   'know.”',
#   'know.”',
#   'knew',
#   'don’t'],
#  'worked': ['all', 'out.', 'out.', 'out.'],
#  'week': ['for'],
#  'this': ['shit,',
#   'show',
#   'shit',
#   'to',
#   'would',
#   'shit.”',
#   'condition.”',
#   'woman',
#   'shit.”',
# ...
#   'supposed',
#   'hungry,',
#   'welcome',
#   'minor'],
#  'listening': ['to'],
#  'radio': ['when'],
#  'someone': ['else'],
#  'else': ['is'],
#  'outside': ['of'],
#  'mirror,': ['something'],
#  'something': ['had', 'terrible', 'that', 'about', 'so'],
#  'horribly': ['wrong.'],
#  'wrong.': ['That', 'It’s', 'Seems', 'Not'],
#  'motherfucker': ['was', 'even', 'had', 'flies', 'was', 'will', 'was', 'was'],
#  'thing': ['I', 'didn’t'],
#  'knew,': ['they'],
#  'stuffing': ['him'],
#  'him': ['in',
#   'to',
#   'when',
#   'pat',
#   'as',
#   'the',
#   'know',
#   'for',
#   'to',
#   'backstage.',
#   'for',
#   'real'],
#  'thought': ['what', 'you', 'Bernie', 'maybe', 'was', 'that’s', 'that'],
#  'anybody': ['would'],
#  'think': ['in',
#   'the',
#   'you’re',
#   'of',
#   'the',
#   'the',
#   'the',
#   'to',
#   'you’ve',
#   'that',
#   'that',
#   'that'],
#  'situation': ['like'],
#  'that:': ['“Oh,'],
#  'God.': ['What', 'Dave'],
#  'happen': ['to', 'to', 'for'],
#  'police': ['walked', 'now.', 'did', 'shot'],
#  'walked': ['up',
#   'by.',
#   'by',
#   'towards',
#   'away.',
#   'out',
#   'out,',
#   'into',
#   'out',
#   'around,',
#   'right',
#   'out.'],
#  'window.': ['“Mr.'],
#  '“Mr.': ['Chappelle,', 'Chappelle,'],
#  'Chappelle,': ['we', 'your', 'I', 'the', 'the'],
#  'we': ['had',
#   'can',
#   'know',
#   'go.',
#   'can',
#   'have',
#   'need',
#   'like',
#   'just',
#   'all',
#   'said,',
#   'all',
#   'were',
#   'grew',
#   'wanted',
#   'got',
#   'found',
#   'were',
#   'were',
#   'all',
#   'want',
#   'are',
#   'was',
#   'go,',
#   'sit',
#   'haven’t',
#   'were',
#   'went',
#   'gave',
#   'wear?'],
#  'friend.': ['He'],
#  'refused': ['to'],
#  'breathalyzer': ['test.”', 'and'],
#  'test.”': ['I'],
#  '“That': ['motherfucker.', 'nigga'],
#  'motherfucker.': ['Not', 'But…'],
#  'complying?': ['That’s'],
#  'odd.': ['So,'],
#  'officer,': ['what’s'],
#  'what’s': ['gonna', 'the', 'popping', 'all', 'up,', 'happening?', 'up,'],
#  '“You’re': ['fine.'],
#  'We’re': ['just', 'gonna', 'the'],
#  'ask': ['you', 'you', 'you'],
#  'step': ['out'],
#  'impound': ['the'],
#  'vehicle,': ['and'],
#  'we’ll': ['arrange'],
#  'arrange': ['for'],
#  'ride': ['home.”', 'home,'],
#  'home.”': ['I', 'It'],
#  'well,': ['no.', 'Mr.'],
#  'no.': ['I', 'Stewart', 'Kevin'],
#  'rather': ['you'],
#  'already': ['told', 'know', 'in'],
#  'told': ['us', 'me', 'me', 'me', 'you'],
#  'us': ['he’s', 'both', 'all,', 'do', 'into', 'together.', 'a', 'for'],
#  'he’s': ['your',
#   'failed',
#   'taking',
#   'gay.',
#   'stronger',
#   'often',
#   'Asian.',
#   'the',
#   'the'],
#  'designated': ['driver.'],
#  'driver.': ['We'],
#  'can’t': ['let',
#   'even',
#   'get',
#   'believe',
#   'even',
#   'tell',
#   'do',
#   'get',
#   'keep',
#   'imagine.',
#   'just',
#   'do',
#   'not'],
#  'drive': ['in'],
#  'condition.”': ['I'],
#  '“No,': ['nigga,', 'no.', 'you'],
#  'suddenly,': ['the', 'a', 'a', 'the'],
#  'turned': ['into', 'around', 'it'],
#  'Vegas.': ['He'],
#  '“I’ll': ['let'],
#  'blow': ['for', 'in', 'in'],
#  '“If': ['you', 'you', 'your'],
#  'breathalyzer–”': ['I'],
#  'trying': ['to', 'to', 'to', 'to', 'to'],
#  'dick': ['sucked.', 'out', 'sucked'],
#  'sucked.': ['What’s', 'And'],
#  'What’s': ['the–', 'it', 'your', 'going', 'going–”', 'the', 'up,'],
#  'the–': ['Whew!'],
#  'Whew!': ['Whew!”'],
#  'Whew!”': ['“If'],
#  'pass,': ['I’ll'],
#  'I’ll': ['give', 'be', 'be', 'be'],
#  'keys': ['to'],
#  'car.”': ['I'],
#  '“Uh…': ['set'],
#  'set': ['’em', 'into'],
#  '’em': ['up,'],
#  'Let’s': ['play.”', 'go', 'not', 'not', 'just', 'all'],
#  'play.”': ['And'],
#  'blew': ['in', 'his'],
#  'thing.': ['And', 'You', 'I’ve', 'Before'],
#  'noise.': ['“Beep!”'],
#  '“Beep!”': ['I'],
#  '“Uh-oh.”': ['And', 'He'],
#  'Mr.': ['Chappelle,', 'Juice.”', 'Juice.”', 'Hart,', 'Hart.”', 'Dinkins'],
#  'free': ['to'],
#  'go.”': ['I'],
#  'am?”': ['I'],
#  'pick': ['up'],
#  'weed.': ['I'],
#  'home': ['on', 'when'],
#  'miles': ['an'],
#  'an': ['hour.', 'Asian', 'Asian', 'entire', 'American', 'empty', 'Emmy'],
#  'hour.': ['Yeah,'],
#  'out.': ['It', 'I’m', 'Steven', 'The', '“OJ!”', '“What’s', 'Oh,'],
#  'lucky': ['ones.\nIt'],
#  'ones.\nIt': ['doesn’t'],
#  'well': ['for', 'and'],
#  'everybody.': ['I', 'I’d', 'Thank'],
#  'videotape': ['of'],
#  'beat': ['up', 'a'],
#  'traffic.': ['You'],
#  'rush': ['hour'],
#  'hour': ['traffic?'],
#  'traffic?': ['They'],
#  'woman’s': ['ass.', 'vagina.'],
#  'ass.': ['This'],
#  'even': ['do',
#   'go',
#   'wrap',
#   'had',
#   'believe',
#   'activate',
#   'know',
#   'make',
#   'though',
#   'used',
#   'know',
#   'looking',
#   'bullshitting–',
#   'have',
#   'know',
#   'know'],
#  'fucked': ['up.', 'up,', 'up', 'up.', 'up,', 'up.', 'up.'],
#  'court.': ['The'],
#  'City': ['of'],
#  'L.A.': ['just'],
#  '$1.5': ['million'],
#  'million': ['for'],
#  'pain': ['and'],
#  'suffering.': ['That', 'What’s', 'If'],
#  'considering': ['that’s'],
#  'amount': ['of'],
#  'Marcos': ['Maidana'],
#  'Maidana': ['made'],
#  'fight': ['Floyd', 'Mayweather.', 'the', 'mode.'],
#  'Floyd': ['Mayweather'],
#  'Mayweather': ['the'],
#  'second': ['time.', 'time', 'season'],
#  'obviously': ['hasn’t', 'gay.', 'trying'],
#  'hasn’t': ['trained'],
#  'trained': ['a', 'to'],
#  'day': ['in', 'as'],
#  'life.': ['You', 'And', 'I’d'],
#  'tape.': ['She'],
#  'fight.': ['Her'],
#  'Her': ['guards'],
#  'guards': ['were'],
#  'low.': ['She'],
#  'taking': ['a', 'out', 'off,'],
#  'shots.': ['Everybody’s'],
#  'Everybody’s': ['mad', 'mad.'],
#  'watched': ['that–', 'them'],
#  'that–': ['You', 'We'],
#  'Netflix,': ['Making'],
#  'Making': ['a', 'a'],
#  'Murderer?': ['The'],
#  'Steven': ['Avery', 'Avery'],
#  'Avery': ['story.', 'is'],
#  'story.': ['If', 'This'],
#  'seen': ['it,', 'the', 'anything', 'anything', 'him'],
#  'check': ['it'],
#  'more': ['trouble', 'than', 'than', 'than', 'money', 'major', 'than'],
#  'trouble': ['than', 'breaks'],
#  'any': ['white', 'movie'],
#  'history': ['of', 'where'],
#  'United': ['States', 'States', 'States,', 'States', 'States.', 'States'],
#  'States': ['has', 'can', 'for', 'was'],
#  'has': ['ever', 'to', 'a', 'a', 'a', 'the', 'eight', 'a', 'a'],
#  'in!': ['In'],
#  'justice': ['system', 'and'],
#  'system': ['designed', 'that'],
#  'designed': ['for'],
#  'thrive,': ['he’s'],
#  'failed': ['miserably'],
#  'miserably': ['twice.'],
#  'twice.': ['I'],
#  'wrap': ['my'],
#  'Murderer': ['was'],
#  'dude,': ['that'],
#  'Duh!': ['Of'],
#  'Of': ['course', 'flavor'],
#  'course': ['everything'],
#  'everything': ['would', 'else.', '♪'],
#  'Seems': ['like'],
#  'right.': ['The', 'You', 'So,', 'This'],
#  '$200,000': ['for'],
#  'legal': ['defense.'],
#  'defense.': ['That'],
#  'Wisconsin.': ['That’s'],
#  'OJ': ['money.',
#   'got',
#   'show.',
#   'case',
#   'Simpson',
#   'Simpson,',
#   'Simpson’s',
#   'was',
#   'Simpson.',
#   'Simpson',
#   'Simpson,',
#   'Simpson—',
#   'Simpson,',
#   'was',
#   'Simpson–',
#   'Simpson.'],
#  'money.': ['All', 'And', 'Let’s'],
#  'All': ['he', 'the', 'right,', 'these', 'the'],
#  'needed': ['to'],
#  'single': ['black'],
#  'juror.': ['That’s'],
#  'would’ve': ['took.'],
#  'took.': ['Because'],
#  'dude': ['in', 'was', 'to'],
#  'dudes': ['and', 'that', 'in'],
#  'game.': ['That’s', 'He', 'Blacks', 'Whenever'],
#  'off.': ['I’ve', 'I'],
#  'watching': ['that'],
#  'new': ['OJ', 'to', 'school', 'era'],
#  'show.': ['I', 'Just', 'The', 'And', 'I’m', 'I'],
#  'enough': ['of'],
#  'Doesn’t': ['it', 'matter'],
#  'bring': ['back'],
#  'memories?': ['But'],
#  'forgot': ['just'],
#  'polarizing': ['that'],
#  'case': ['was.'],
#  'met': ['OJ', 'OJ', 'OJ', 'OJ', 'OJ', 'Bill', 'OJ'],
#  'Simpson': ['on', 'was'],
#  'four': ['different'],
#  'different': ['occasions',
#   'people',
#   'ethnicities.',
#   'time,',
#   'colors,',
#   'designs'],
#  'occasions': ['in'],
#  'end': ['of', 'of', 'segregation.'],
#  'each': ['of', 'other', 'other', 'one', 'other'],
#  'occasions.': ['The'],
#  'first': ['time',
#   'time,',
#   'time.',
#   'place.”',
#   'time,',
#   'time,',
#   'generation',
#   'time,',
#   'of',
#   'comedian',
#   'black',
#   'guy'],
#  'Simpson,': ['I', 'newly', 'I'],
#  'Santa': ['Monica.'],
#  'Monica.': ['-Santa'],
#  '-Santa': ['Monica!'],
#  'Monica!': ['-Yeah!'],
#  '-Yeah!': ['I'],
#  'believe': ['a',
#   'what',
#   'what',
#   'me',
#   'me.',
#   'it.',
#   'it.',
#   'that',
#   'I',
#   'that',
#   'that’s'],
#  '“Santa': ['Monica!”', 'Monica!”'],
#  'Monica!”': ['You', 'You?'],
#  'nigga': ['I', 'did', 'is'],
#  'expect': ['to'],
#  'Let': ['me'],
#  'shoes.': ['You'],
#  'Vans': ['on,'],
#  'on,': ['nigga?',
#   'man.',
#   'guys.',
#   'white',
#   'nigga?',
#   'the',
#   'and',
#   'son,',
#   'guys.',
#   'then'],
#  'nigga?': ['What', 'I', 'Is'],
#  'got?': ['“Santa'],
#  'You?': ['At'],
#  'At': ['the', 'least', 'first,', 'times,'],
#  'time,': ['I', 'in', 'young', 'go', 'women', 'there', 'but', 'we', 'me'],
#  '.': ['I'],
#  'done': ['a', 'something', 'that'],
#  'club': ['came', 'and', 'in'],
#  'Simpson’s': ['here,'],
#  'said': ['he', 'the', 'it,', 'some', 'anything', 'he'],
#  'wants': ['to', 'to'],
#  'meet': ['you.”', 'you.', 'him.”', 'him'],
#  'you.”': ['I', '“Slow', 'That’s'],
#  '“What?': ['Fuck', 'Well,', 'I’m', 'Oh,'],
#  'yeah!”': ['I'],
#  'ran': ['down', 'for'],
#  'down': ['the', 'there.', 'the', 'on', 'in'],
#  'steps,': ['and'],
#  'there.': ['He’s', 'They', 'I’m', 'And'],
#  'young': ['man.', 'man', 'man?”', 'heads', 'kids,', 'man.', 'white'],
#  'man.': ['How', 'What', 'I', 'And', 'A', 'This', 'I'],
#  'you?': ['It’s'],
#  'you.': ['And', 'I’m', 'But', 'Twos'],
#  'work,': ['and'],
#  'hope': ['good'],
#  'things': ['happen', 'that', 'because', 'take', 'on', 'went', 'out', 'like,'],
#  'life.”': ['I'],
#  '“Man,': ['thanks,', 'this', 'I', 'this'],
#  'thanks,': ['Mr.'],
#  'Juice.”': ['Standing', 'And', 'They'],
#  'Standing': ['beside'],
#  'beside': ['him,'],
#  'him,': ['was–', 'was', 'but'],
#  'was–': ['I', 'Now,'],
#  'nice': ['way', 'to', 'things', 'dudes.', 'to', 'to', 'as'],
#  'way': ['to', 'to', 'to', 'more', 'a', 'to', 'to', 'through.', 'back', 'too'],
#  'this–': ['his'],
#  'soon-to-be-slain': ['wife.'],
#  'wife.': ['Ladies'],
#  'Ladies': ['and', 'and'],
#  'gentlemen,': ['man', 'that’s'],
#  'man': ['the', 'the', 'of', 'from', 'about', 'she', 'to', 'Phife'],
#  'make': ['it',
#   'it?”',
#   'all',
#   'sense?',
#   'a',
#   'pussies',
#   'more',
#   'in',
#   'a',
#   'sure'],
#  'She’s': ['dead.', 'Filipino.'],
#  'dead.': ['We', 'Immediately', 'It'],
#  'happened.': ['We', 'I'],
#  'who': ['did', 'said', 'used', 'are', 'I', 'was', 'it'],
#  'actually': ['embraced', 'making'],
#  'embraced': ['me.', 'one'],
#  'adorable,”': ['and'],
#  'hugged': ['me.'],
#  'goes,': ['“Good',
#   '“Really?”',
#   '“Suffering',
#   '“Because',
#   '“Actually,',
#   '“If'],
#  'luck': ['to'],
#  'you,”': ['and'],
#  'held': ['me', 'back'],
#  'whispered': ['in'],
#  'ear,': ['“Bitch,'],
#  '“Bitch,': ['are', 'how'],
#  'both': ['killed?”', 'technically'],
#  'killed?”': ['I’m'],
#  'kidding.': ['I'],
#  'that,': ['but…', 'this', 'there', 'she', 'never'],
#  'but…': ['that', 'Try', 'it'],
#  'nutshell.': ['It’s'],
#  'many…': ['so'],
#  'many': ['different', 'different', 'stars,', 'transgenders'],
#  'ethnicities.': ['Very'],
#  'Very': ['diverse'],
#  'diverse': ['crowd.'],
#  'crowd.': ['Looks', 'Here'],
#  'Looks': ['like'],
#  'Bernie': ['Sanders'],
#  'Sanders': ['was'],
#  'But…': ['surprise!'],
#  'surprise!': ['It’s'],
#  'happy,': ['really,'],
#  'really,': ['to'],
#  'come.': ['A'],
#  'A': ['lot', 'couple', 'little', 'lot', 'dark', 'scuffle', 'Tribe', 'rhythm'],
#  'used': ['to.', 'to', 'to', 'to', 'to', 'to'],
#  'there’s': ['a', 'a'],
#  'reasons': ['you'],
#  'shows.': ['One'],
#  'One': ['is', 'last'],
#  'because,': ['obviously,'],
#  'obviously,': ['black'],
#  'slower': ['Internet'],
#  'Internet': ['connections.'],
#  'connections.': ['I'],
#  'mean,': ['that', 'boycott?'],
#  'guess.': ['I'],
#  'what–': ['Actually,'],
#  'Actually,': ['my'],
#  'own': ['actions', 'eyes.'],
#  'actions': ['drew'],
#  'drew': ['a'],
#  'wedge': ['between'],
#  'between': ['me'],
#  'community': ['I'],
#  'hold': ['so'],
#  'dear.': ['A'],
#  'couple': ['of', 'questions.”', 'of', 'of'],
#  'ago,': ['I'],
#  'supposed': ['to', 'to', 'to', 'to'],
#  'Flint,': ['Michigan,', 'and', 'and'],
#  'Michigan,': ['for'],
#  'charity': ['benefit', 'benefit,'],
#  'benefit': ['that'],
#  'raise': ['awareness'],
#  'awareness': ['for'],
#  'appalling': ['condition'],
#  'condition': ['of'],
#  'water': ['in', 'in', 'is', 'up!'],
#  'Flint.': ['I'],
#  'this,': ['but', 'too.”'],
#  'Flint': ['is'],
#  'poisonous.': ['It’s'],
#  'making': ['people', 'up'],
#  'sick.': ['Hollywood'],
#  'Hollywood': ['people', 'was', 'movie'],
#  '“So': ['what?', 'what,'],
#  'least': ['they'],
#  'water.”': ['But'],
#  'water–': ['this'],
#  'celebrities': ['flew', 'were'],
#  'flew': ['into'],
#  'tremendous': ['charity'],
#  'benefit,': ['and'],
#  'schedule': ['to'],
#  'appear.\nUh…': ['So,'],
#  'reason': ['a'],
#  'heard': ['about', 'things', 'he', 'that', 'that'],
#  'benefit–': ['it'],
#  'as': ['the',
#   'a',
#   'many',
#   'they',
#   'fuck.',
#   'close',
#   'you',
#   'soon',
#   'I',
#   'soon',
#   'the',
#   'nice',
#   'those',
#   'feminists.',
#   'we',
#   'this',
#   'if',
#   'successful',
#   'he'],
#  'Oscars.': ['Right,', 'Can', 'You’ve', 'So,'],
#  'Right,': ['I'],
#  'know.': ['So,', 'That’s', 'Your', 'I', 'Seriously,', 'But'],
#  'airport': ['to', 'right'],
#  'Chris': ['Rock', 'Tucker.', 'Tucker', 'were'],
#  'Rock': ['calls'],
#  'ticket': ['for'],
#  'Can': ['you', 'I', 'you', 'you', 'I', 'I', 'I', 'I'],
#  'it?”': ['And'],
#  '“Sure,': ['nigga.'],
#  'now.”': ['Come', 'And'],
#  'Come': ['on,', 'on'],
#  'am': ['I', 'I,'],
#  'water?': ['What'],
#  'I,': ['a'],
#  'superhero?': ['I'],
#  'need': ['to',
#   'to',
#   'me.',
#   'you',
#   'to',
#   'to',
#   'you',
#   'you',
#   '$250.”',
#   '$250,',
#   'everybody'],
#  'fun.': ['I'],
#  'live,': ['too!'],
#  'too!': ['I'],
#  'up!': ['Stevie', 'Twos', 'Hands', 'Twos', 'We’re'],
#  'Stevie': ['Wonder'],
#  'Wonder': ['was'],
#  'sorry,': ['everybody.', 'guys.', 'ladies'],
#  'You’ve': ['seen'],
#  'movies': ['I'],
#  'make.': ['I'],
#  'excited.\nI': ['knew'],
#  'trouble,': ['because'],
#  'because': ['when', 'he', 'my', 'it', 'in', 'your', 'we', 'I'],
#  'walking': ['on', 'shoe.', 'to'],
#  'red': ['carpet,'],
#  'carpet,': ['the'],
#  'press': ['came'],
#  'brother.”': ['When'],
#  'When': ['you', 'it'],
#  'somebody': ['call', 'trying'],
#  'call': ['you'],
#  '“brother”': ['too'],
#  'too': ['much,', 'young.', 'long', 'bad', 'far:', 'much–', 'flimsy'],
#  'much,': ['something'],
#  'terrible': ['is', 'area.”'],
#  'happen.': ['“Excuse'],
#  'brother.': ['Brother?”', 'What'],
#  'Brother?”': ['And'],
#  'back,': ['and', 'the', 'they'],
#  'tuxedo': ['with'],
#  'kente': ['cloth'],
#  'cloth': ['tie.'],
#  'tie.': ['I'],
#  'questions.”': ['I'],
#  'publication': ['are'],
#  'with?”': ['He'],
#  '“Me?': ['I’m'],
#  'Daily': ['Bongo.”', 'Bongo,”'],
#  'Bongo.”': ['I'],
#  '“Daily': ['Bongo?'],
#  'Bongo?': ['What'],
#  'fuck?': ['Who'],
#  'Who': ['the', 'Suffered'],
#  'reads': ['this?”'],
#  'this?”': ['He'],
#  '“Listen,': ['brother,'],
#  'brother,': ['I'],
#  'quick': ['question.'],
#  'question.': ['You'],
#  'understand': ['that', 'why', 'it,', 'what'],
#  'year,': ['this', 'there’d'],
#  'boycott': ['for'],
#  'wondering': ['what'],
#  'people,': ['cross', 'very', 'and'],
#  'cross': ['the'],
#  'motherfucking': ['picket', 'fist.', 'macaroons.'],
#  'picket': ['line'],
#  'line': ['and'],
#  'tonight.”': ['I'],
#  '“Boycott?': ['Nigga,'],
#  'Nigga,': ['I', 'I'],
#  'boycott?': ['I’ve'],
#  'strike.': ['Y’all'],
#  'Y’all': ['niggas'],
#  'working.': ['I'],
#  'watch': ['fucking', 'it', 'a'],
#  'Key': ['and'],
#  'Peele': ['do'],
#  'night!': ['So,', '♪'],
#  'Bongo,”': ['is'],
#  'said.': ['I', '“How'],
#  'Oscars': ['and'],
#  'green': ['room.', 'room', 'room', 'room,', 'room,'],
#  'room.': ['It', 'And', 'And', 'There’s', 'This', 'Yes.'],
#  'filled': ['with', 'me', 'with'],
#  'stars,': ['I'],
#  'couldn’t': ['even', 'believe'],
#  'seeing.': ['Hollywood', 'And'],
#  'seducing': ['me'],
#  'sitting': ['back', 'in', 'on'],
#  'smoking,': ['drinking'],
#  'drinking': ['with', 'alone.'],
#  'stars.\nAnd': ['then'],
#  'movie': ['producers', 'ideas'],
#  'producers': ['came'],
#  'over,': ['right', 'and'],
#  'Chappelle,”': ['said'],
#  'leader': ['one.', 'because', 'would'],
#  'one.': ['He', 'And'],
#  'gay.': ['Some', 'He', 'I’m', 'Like'],
#  'guys,': ['you'],
#  'tell.': ['The'],
#  'seemed': ['like'],
#  'guy.': ['Maybe'],
#  'Maybe': ['he'],
#  'Texas': ['or', 'was'],
#  'gay': ['one',
#   'superhero.”',
#   'sous-chef',
#   'kind',
#   'people.',
#   'superhero.”',
#   'community’s',
#   'people,',
#   'dude?',
#   'people',
#   'friends.',
#   'friends.',
#   'political',
#   'dudes'],
#  'definitely': ['the'],
#  'with:': ['“So,'],
#  '“So,': ['David,'],
#  'David,': ['um…'],
#  'um…': ['do'],
#  'ideas': ['that'],
#  'pursue?”': ['The'],
#  'truth': ['is,'],
#  ...}

# %%
generate_sentence(bill_dict)
# Out:
# 'Isn’t music!” You know why it is. Yeah. Absolutely, recycle. You hear the whole “Hold.'

# %%
generate_sentence(dave_dict)
# Out:
# 'Chest before. I was involved. She didn’t even know who did it. My point is.'

# %%
import random
import string
def new_generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += random.choice(list(string.punctuation))
    return(sentence)

# %%
new_generate_sentence(dave_dict)
# Out:
# 'Designed for people are young. Imagine if you know anything wrong. Not only did give\\'

# %%
generate_sentence(ali_dict)
# Out:
# 'About? I’m fucked. So, you know… where they like wiping and get sicker, and start.'
